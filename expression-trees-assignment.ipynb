# %% [markdown]
# # Programming Assignment #3: Expression Trees
#
# An expression tree is a tree where internal nodes are operators and the leaves are either variables or constants. For example, here is an expression tree that corresponds to the expression `2-3*x`:
#
#     (MINUS 2 (TIMES 3 x))
#
# In this assignment, you will
# 1. Write an evaluator for expression trees, e.g., the value of the tree above is `-28` when `x=10`.
# 2. Perform some simple optimizations, e.g., `(MINUS 2 (TIMES (PLUS 1 2) x))` simplifies to the expression above.
# 3. Show that the optimizations are correct, i.e., that they return the same values.
#
# > Note: You may know that the Java/C++/C#/whatever compiler you use **optimizes** the generated code. In this assignment you will get a feel for what an optimizing compiler does. Coincidentally, the next section introduces the ACL2 `LET*` syntax, and that turns out to be very similar to a code represerntation called *static single assignment (SSA)* that is often used in compilers for optimization. You can learn more about this if you take the compilers course!

# %% [markdown]
# ## Introducing LET*
#
# You do **not** have to use `LET*` to do this assignment, but `LET*` is a nice feature that can make it easier to write some of the functions below. Here's how it works.
#
# Suppose you want to write a complicated expression, like
#
#     (+ (* 2 3)
#        (* 2 3))
#
# Notice that the same term appears twice? `LET*` is simply a way to create a "temporary variable" that has a value and can them be used freely. To be clear, these are **not** variables in the Java or C++ sense, since they can never be changed. It's really just a way to name a value that appears more than once.
#
# The expression above can be written using `LET*` like this:
#
#     (LET* ((x (* 2 3))
#            )
#           (+ x x))
#
# Here, the common subexpression `(* 2 3)` is given the name `x`. You can define more than one variable. For example,
# consider this expression:
#
#     (+ (* 2 (+ 2 1))
#        (* 2 (+ 2 1)))
#
# This can be written using `LET*` as
#
#     (LET* ((y (+ 2 1))
#            (x (* 2 y))
#            )
#           (+ x x))
#
# It's up to you whether to use `LET*` or just ignore it. I used it in some of the definitions and not in others, just to convince myself that you could do either.

# %% [markdown]
# ## TODO-1 (10 pts)
#
# Your first task is to define a datatype for expression trees. The leaves should be either rationals or symbols (like x and y). The internal nodes are operations, which mostly take two arguments. The operations are
# * `PLUS`
# * `MINUS`
# * `TIMES`
# * `DIVIDE`
# * `UMINUS` (unary minus, so it takes only **one** argument)

# %%
(defsnapshot from-the-top)

(defsnapshot todo-1)

(defdata tree (oneof (list (oneof 'PLUS 'MINUS 'TIMES 'DIVIDE) tree tree) (list 'UMINUS tree) :rational :symbol))
# Out:
# ACL2S !>>(DEFSNAPSHOT FROM-THE-TOP)
#           20:x(DEFMACRO DEFSNAPSHOT (LABEL) ...)
#
# Summary
# Form:  ( DEFLABEL FROM-THE-TOP ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  FROM-THE-TOP
# ACL2S !>>(DEFSNAPSHOT TODO-1)
#
# Summary
# Form:  ( DEFLABEL TODO-1 ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  TODO-1
# ACL2S !>>(DEFDATA TREE
#                   (ONEOF (LIST (ONEOF 'PLUS 'MINUS 'TIMES 'DIVIDE)
#                                TREE TREE)
#                          (LIST 'UMINUS TREE)
#                          RATIONAL SYMBOL))
#  Predicate events...
# Form:  ( DEFUN TREEP ...)
# Form:  ( IN-THEORY (DISABLE* ...))
# Form:  ( IN-THEORY (ENABLE ...))
# Form:  ( TABLE ACL2::RULESET-TABLE ...)
# Form:  ( MAKE-EVENT (LET* ...))
#  Tau characterization events...
#  (TREEP ACL2::V1) <= body -- not complete.
# Reasons:
# ("The formula fails to fit any of the forms for acceptable :TAU-SYSTEM rules."
#  "Nesting i.e. (P (f ... (g x1 ...) ...) not allowed in conclusion of signature rule")
#
#  (TREEP ACL2::V1) => body -- not complete.
# Reasons:
# ("Unable to characterize (using tau rules) a non-disjoint union type")
#
# Form:  ( DEFTHM DEF=>TREE ...)
#  Enumerator events...
# Form:  ( DEFUN NTH-TREE-BUILTIN ...)
# Form:  ( DEFUN NTH-TREE/ACC-BUILTIN ...)
# Form:  ( PROGN (SET-BOGUS-DEFUN-HINTS-OK T) ...)
# Form:  ( ENCAPSULATE NIL (LOGIC) ...)
# Time:  0.92 seconds (prove: 0.80, print: 0.00, other: 0.12)
#  Registering type...
# Form:  ( DEFUN NTH-TREE ...)
# Form:  ( ENCAPSULATE (((NTH-TREE * ...) ...) ...) ...)
# Form:  ( DEFUN NTH-TREE/ACC ...)
# Form:  ( ENCAPSULATE (((NTH-TREE/ACC * ...) ...) ...) ...)
# Form:  ( DEFATTACH (NTH-TREE NTH-TREE-BUILTIN) ...)
# Form:  ( DEFATTACH (NTH-TREE/ACC NTH-TREE/ACC-BUILTIN) ...)
# Form:  ( TABLE TYPE-METADATA-TABLE ...)
# Form:  ( PROGN (LOCAL ...) ...)
# Form:  ( ENCAPSULATE NIL (LOGIC) ...)
# Time:  0.03 seconds (prove: 0.00, print: 0.00, other: 0.03)
# Form:  ( MAKE-EVENT (DEFDATA::REGISTER-TYPE-FN ...))
# Time:  0.03 seconds (prove: 0.00, print: 0.00, other: 0.03)
# Form:  ( ENCAPSULATE NIL (WITH-OUTPUT :ON ...) ...)
# Time:  0.04 seconds (prove: 0.00, print: 0.00, other: 0.04)
# Form:  ( PROGN (ENCAPSULATE NIL ...) ...)
# Time:  0.96 seconds (prove: 0.80, print: 0.00, other: 0.16)
# Form:  ( ENCAPSULATE NIL (WITH-OUTPUT :OFF ...) ...)
# Time:  1.02 seconds (prove: 0.80, print: 0.00, other: 0.22)
#  T

# %% [markdown]
# ## TODO-2 (10 pts)
#
# Soon we will be evaluating expressions like `(MINUS 2 (TIMES 3 x))`, but before we get there we have to solve the problem of variables. What we need is a data structure that maps variable names to their current values. We will implement with a list of name/value pairs, e.g.,
#
#     '((x 10)
#       (y 3)
#       (z -4)
#       (abc 50))
#
# Given that list, the value of the expression above is `-28`.
#
# Start by defining the data type `env` that maps symbols to rational numbers as above.
#
# > Note: `env` stands for "environment", though this data structure goes by various names, such as "dictionary", "map", "memory", "associative array", "content-addressible memory", "hashtable", and even "object".

# %%
(defsnapshot todo-2)

(defdata env (listof (list :symbol :rational)))
# Out:
# ACL2S !>>(DEFSNAPSHOT TODO-2)
#
# Summary
# Form:  ( DEFLABEL TODO-2 ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  TODO-2
# ACL2S !>>(DEFDATA ENV (LISTOF (LIST SYMBOL RATIONAL)))
#  Predicate events...
# Form:  ( DEFUN ENVP ...)
# Form:  ( IN-THEORY (DISABLE* ...))
# Form:  ( IN-THEORY (ENABLE ...))
# Form:  ( TABLE ACL2::RULESET-TABLE ...)
# Form:  ( MAKE-EVENT (LET* ...))
#  Alistof theory events...
# Form:  ( DEFTHM ENVP-IMPLIES-ALISTP ...)
# Form:  ( DEFTHM ENVP-IMPLIES-TLP ...)
# Form:  ( TABLE ACL2::RULESET-TABLE ...)
# Form:  ( MAKE-EVENT (LET* ...))
#  Tau characterization events...
#  (ENVP ACL2::V1) <= body -- not complete.
# Reasons:
# ("Nesting i.e. (P (f ... (g x1 ...) ...) not allowed in conclusion of signature rule")
#
#  (ENVP ACL2::V1) => body -- not complete.
# Reasons:
# ("Nesting i.e. (P (f ... (g x1 ...) ...) not allowed in conclusion of signature rule")
#
# Form:  ( DEFTHM DEF=>ENV ...)
# Form:  ( DEFTHM ENV=>DEF ...)
#  Enumerator events...
# Form:  ( DEFUN NTH-ENV-BUILTIN ...)
# Form:  ( DEFUN NTH-ENV/ACC-BUILTIN ...)
# Form:  ( PROGN (SET-BOGUS-DEFUN-HINTS-OK T) ...)
# Form:  ( ENCAPSULATE NIL (LOGIC) ...)
# Time:  0.10 seconds (prove: 0.04, print: 0.00, other: 0.06)
#  Registering type...
# Form:  ( DEFUN NTH-ENV ...)
# Form:  ( ENCAPSULATE (((NTH-ENV * ...) ...) ...) ...)
# Form:  ( DEFUN NTH-ENV/ACC ...)
# Form:  ( ENCAPSULATE (((NTH-ENV/ACC * ...) ...) ...) ...)
# Form:  ( DEFATTACH (NTH-ENV NTH-ENV-BUILTIN) ...)
# Form:  ( DEFATTACH (NTH-ENV/ACC NTH-ENV/ACC-BUILTIN) ...)
# Form:  ( TABLE TYPE-METADATA-TABLE ...)
# Form:  ( PROGN (LOCAL ...) ...)
# Form:  ( ENCAPSULATE NIL (LOGIC) ...)
# Time:  0.02 seconds (prove: 0.00, print: 0.00, other: 0.02)
# Form:  ( MAKE-EVENT (DEFDATA::REGISTER-TYPE-FN ...))
# Time:  0.02 seconds (prove: 0.00, print: 0.00, other: 0.02)
# Form:  ( ENCAPSULATE NIL (WITH-OUTPUT :ON ...) ...)
# Time:  0.03 seconds (prove: 0.00, print: 0.00, other: 0.03)
# Form:  ( PROGN (ENCAPSULATE NIL ...) ...)
# Time:  0.14 seconds (prove: 0.04, print: 0.00, other: 0.09)
# Form:  ( ENCAPSULATE NIL (WITH-OUTPUT :OFF ...) ...)
# Time:  0.17 seconds (prove: 0.04, print: 0.00, other: 0.12)
#  T

# %% [markdown]
# ## TODO-3 (10 pts)
#
# Now, define the function `(lookup var environment)` that returns the current value of the variable `var` in the given `environment`. If the variable is not given a value in the environment, return a reasonable default, e.g., `0`.

# %%
(defsnapshot todo-3)
(definec lookup (var :symbol environment :env) :rational
    (if (endp environment)
        0
        (if (equal (first (first environment)) var)
            (second (first environment))
            (lookup var (rest environment))
        )
    )
)

(check-expect (lookup 'x (list (list 'y 90) (list 'c 60) (list 'z 5) (list 'x 3) (list 'p 38))) 3)
(check-expect (lookup 'y (list (list 'y 90) (list 'c 60) (list 'z 5) (list 'x 3) (list 'p 38))) 90)
(check-expect (lookup 'c (list (list 'y 90) (list 'c 60) (list 'z 5) (list 'x 3) (list 'p 38))) 60)
(check-expect (lookup 'z (list (list 'y 90) (list 'c 60) (list 'z 5) (list 'x 3) (list 'p 38))) 5)
(check-expect (lookup 'p (list (list 'y 90) (list 'c 60) (list 'z 5) (list 'x 3) (list 'p 38))) 38)
# Out:
# ACL2S !>>(DEFSNAPSHOT TODO-3)
#
# Summary
# Form:  ( DEFLABEL TODO-3 ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  TODO-3
# ACL2S !>>(DEFINEC LOOKUP (VAR SYMBOL ENVIRONMENT ENV)
#                   RATIONAL
#                   (IF (ENDP ENVIRONMENT)
#                       0
#                       (IF (EQUAL (FIRST (FIRST ENVIRONMENT)) VAR)
#                           (SECOND (FIRST ENVIRONMENT))
#                           (LOOKUP VAR (REST ENVIRONMENT)))))
#
# Form:  ( TEST-DEFINITION LOOKUP ... )
# Form:  ( TEST-BODY-CONTRACTS LOOKUP... )
# Form:  ( TEST-FUNCTION-CONTRACT LOOKUP ...)
# Testing: Done
# Elapsed Run Time: 1.22 seconds
# Form:  ( ADMIT-DEFINITION LOOKUP ... )
# Time:  0.02 seconds (prove: 0.00, print: 0.00, other: 0.02)
# Form:  ( PROVE-FUNCTION-CONTRACT LOOKUP ... )
# Time:  0.14 seconds (prove: 0.08, print: 0.00, other: 0.06)
# Form:  ( PROVE-BODY-CONTRACTS LOOKUP ... )
# Time:  0.09 seconds (prove: 0.03, print: 0.00, other: 0.06)
# Elapsed Run Time: 0.30 seconds
# Function Name : LOOKUP
# Termination proven -------- [*]
# Function Contract proven -- [*]
# Body Contracts proven ----- [*]
#  T
# ACL2S !>>(CHECK-EXPECT (LOOKUP 'X
#                                (LIST (LIST 'Y 90)
#                                      (LIST 'C 60)
#                                      (LIST 'Z 5)
#                                      (LIST 'X 3)
#                                      (LIST 'P 38)))
#                        3)
#  :PASSED
# ACL2S !>>(CHECK-EXPECT (LOOKUP 'Y
#                                (LIST (LIST 'Y 90)
#                                      (LIST 'C 60)
#                                      (LIST 'Z 5)
#                                      (LIST 'X 3)
#                                      (LIST 'P 38)))
#                        90)
#  :PASSED
# ACL2S !>>(CHECK-EXPECT (LOOKUP 'C
#                                (LIST (LIST 'Y 90)
#                                      (LIST 'C 60)
#                                      (LIST 'Z 5)
#                                      (LIST 'X 3)
#                                      (LIST 'P 38)))
#                        60)
#  :PASSED
# ACL2S !>>(CHECK-EXPECT (LOOKUP 'Z
#                                (LIST (LIST 'Y 90)
#                                      (LIST 'C 60)
#                                      (LIST 'Z 5)
#                                      (LIST 'X 3)
#                                      (LIST 'P 38)))
#                        5)
#  :PASSED
# ACL2S !>>(CHECK-EXPECT (LOOKUP 'P
#                                (LIST (LIST 'Y 90)
#                                      (LIST 'C 60)
#                                      (LIST 'Z 5)
#                                      (LIST 'X 3)
#                                      (LIST 'P 38)))
#                        38)
#  :PASSED

# %% [markdown]
# ## TODO-4 (10 points)
#
# Now is the time! Write the function `(expr-eval tree environment)` that evaluates the given expression using the variable values in the given environment.
#
# > Note: You cannot divide by zero! If the expression performs a division by zero, just treat the result of that division as `0`, for example. (It should probably return `NIL` in that case, but returning `0` instead saves a bit of work.
#
# > Hint: Think about what using a postorder traversal.

# %%
(defsnapshot todo-4)

(definec expr-eval (tree :tree environment :env) :rational
    (if (rationalp tree)
        tree
        (if (symbolp tree)
            (lookup tree environment)
            (if (equal (first tree) 'PLUS)
                (+ (expr-eval (second tree) environment) (expr-eval (third tree) environment))
                (if (equal (first tree) 'MINUS)
                    (- (expr-eval (second tree) environment) (expr-eval (third tree) environment))
                    (if (equal (first tree) 'UMINUS)
                        (- 0 (expr-eval (second tree) environment))
                        (if (equal (first tree) 'TIMES)
                            (* (expr-eval (second tree) environment) (expr-eval (third tree) environment))
                            (if (equal (first tree) 'DIVIDE)
                                (if (equal (expr-eval (third tree) environment) 0)
                                    0
                                    (/ (expr-eval (second tree) environment) (expr-eval (third tree) environment))
                                )
                                0
                            )
                        )
                    )
                )   
            )   
        )   
    )
)

(check-expect (expr-eval  (list 'MINUS 2 (list 'TIMES (list 'PLUS 1 2) 'x)) (list (list 'x 10))) -28)
(check-expect (expr-eval  (list 'MINUS 2 (list 'TIMES 3 'x)) (list (list 'x 10))) -28)
(check-expect (expr-eval  (list 'PLUS 2 (list 'TIMES (list 'TIMES -6 15) 'y)) (list (list 'y 4))) -358)
(check-expect (expr-eval  (list 'DIVIDE (list 'MINUS (list 'UMINUS 6) 'x) 0) (list (list 'y 89))) 0)
(check-expect (expr-eval  (list 'PLUS 2 (list 'DIVIDE (list 'TIMES 88 2) 'x)) (list (list 'x 0))) 2)
# Out:
# ACL2S !>>(DEFSNAPSHOT TODO-4)
#
# Summary
# Form:  ( DEFLABEL TODO-4 ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  TODO-4
# ACL2S !>>(DEFINEC
#           EXPR-EVAL (TREE TREE ENVIRONMENT ENV)
#           RATIONAL
#           (IF
#            (RATIONALP TREE)
#            TREE
#            (IF
#             (SYMBOLP TREE)
#             (LOOKUP TREE ENVIRONMENT)
#             (IF
#               (EQUAL (FIRST TREE) 'PLUS)
#               (+ (EXPR-EVAL (SECOND TREE) ENVIRONMENT)
#                  (EXPR-EVAL (THIRD TREE) ENVIRONMENT))
#               (IF (EQUAL (FIRST TREE) 'MINUS)
#                   (- (EXPR-EVAL (SECOND TREE) ENVIRONMENT)
#                      (EXPR-EVAL (THIRD TREE) ENVIRONMENT))
#                   (IF (EQUAL (FIRST TREE) 'UMINUS)
#                       (- 0 (EXPR-EVAL (SECOND TREE) ENVIRONMENT))
#                       (IF (EQUAL (FIRST TREE) 'TIMES)
#                           (* (EXPR-EVAL (SECOND TREE) ENVIRONMENT)
#                              (EXPR-EVAL (THIRD TREE) ENVIRONMENT))
#                           (IF (EQUAL (FIRST TREE) 'DIVIDE)
#                               (IF (EQUAL (EXPR-EVAL (THIRD TREE) ENVIRONMENT)
#                                          0)
#                                   0
#                                   (/ (EXPR-EVAL (SECOND TREE) ENVIRONMENT)
#                                      (EXPR-EVAL (THIRD TREE) ENVIRONMENT)))
#                               0))))))))
#
# Form:  ( TEST-DEFINITION EXPR-EVAL ... )
# Form:  ( TEST-BODY-CONTRACTS EXPR-EVAL... )
# Form:  ( TEST-FUNCTION-CONTRACT EXPR-EVAL ...)
# Testing: Done
# Elapsed Run Time: 5.06 seconds
# Form:  ( ADMIT-DEFINITION EXPR-EVAL ... )
# Time:  4.11 seconds (prove: 4.02, print: 0.00, other: 0.09)
# Form:  ( PROVE-FUNCTION-CONTRACT EXPR-EVAL ... )
# Time:  0.10 seconds (prove: 0.04, print: 0.00, other: 0.06)
# Form:  ( PROVE-BODY-CONTRACTS EXPR-EVAL ... )
# Time:  0.23 seconds (prove: 0.09, print: 0.00, other: 0.14)
# Elapsed Run Time: 4.51 seconds
# Function Name : EXPR-EVAL
# Termination proven -------- [*]
# Function Contract proven -- [*]
# Body Contracts proven ----- [*]
#  T
# ACL2S !>>(CHECK-EXPECT (EXPR-EVAL (LIST 'MINUS
#                                         2 (LIST 'TIMES (LIST 'PLUS 1 2) 'X))
#                                   (LIST (LIST 'X 10)))
#                        -28)
#  :PASSED
# ACL2S !>>(CHECK-EXPECT (EXPR-EVAL (LIST 'MINUS 2 (LIST 'TIMES 3 'X))
#                                   (LIST (LIST 'X 10)))
#                        -28)
#  :PASSED
# ACL2S !>>(CHECK-EXPECT
#               (EXPR-EVAL (LIST 'PLUS
#                                2 (LIST 'TIMES (LIST 'TIMES -6 15) 'Y))
#                          (LIST (LIST 'Y 4)))
#               -358)
#  :PASSED
# ACL2S !>>(CHECK-EXPECT (EXPR-EVAL (LIST 'DIVIDE
#                                         (LIST 'MINUS (LIST 'UMINUS 6) 'X)
#                                         0)
#                                   (LIST (LIST 'Y 89)))
#                        0)
#  :PASSED
# ACL2S !>>(CHECK-EXPECT
#               (EXPR-EVAL (LIST 'PLUS
#                                2 (LIST 'DIVIDE (LIST 'TIMES 88 2) 'X))
#                          (LIST (LIST 'X 0)))
#               2)
#  :PASSED

# %% [markdown]
# ## Extra Credit 1 (10 points)
#
# The function `expr-eval` in TODO-4 returns 0 for the expression `(/ 1 0)`. That's OK for convenience, but it's not really right, is it? Let's write a new function `(expr-eval-nan tree environment)` that handles this case properly. The function should return either a rational or the special constant `NaN` ("Not a Number"). When the function sees a term that is trying to divide by 0, it should return `NaN`. Moreover, when it performs any arithmetic operation on a `NaN` value, it should also return `NaN`. For instance
#
#     (PLUS (TIMES 4 x) (DIVIDE 2 0))
#
# should evaluate to `NaN`, regardless of the value of `x`.

# %%
(defsnapshot ec-1)

;(or (rationalp tree) (equal tree 'NaN))


(defdata return (oneof :rational 'NaN))
(definec expr-eval-nan (tree :tree environment :env) :return
    (if (or (rationalp tree) (equal tree 'NaN))
        tree
        (if (symbolp tree)
            (lookup tree environment)
            (if (or (equal (expr-eval-nan (second tree) environment) 'NaN) (and (equal (expr-eval-nan (third tree) environment) 'NaN) (not (equal (first tree) 'UMINUS))))
                'NaN         
                (if (equal (first tree) 'PLUS)
                    (+ (expr-eval-nan (second tree) environment) (expr-eval-nan (third tree) environment))
                    (if (equal (first tree) 'MINUS)
                        (- (expr-eval-nan (second tree) environment) (expr-eval-nan (third tree) environment))
                        (if (equal (first tree) 'UMINUS)
                            (- 0 (expr-eval-nan (second tree) environment))
                            (if (equal (first tree) 'TIMES)
                                (* (expr-eval-nan (second tree) environment) (expr-eval-nan (third tree) environment))
                                (if (equal (first tree) 'DIVIDE)
                                    (if (equal (expr-eval-nan (third tree) environment) 0)
                                        'NaN
                                        (/ (expr-eval-nan (second tree) environment) (expr-eval-nan (third tree) environment))
                                    )
                                    'NaN
                                )
                            )
                        )
                    )   
                )  
            )
        )   
    )
)

(check-expect (expr-eval-nan  (list 'DIVIDE (list 'MINUS (list 'UMINUS 6) 4) 'x) (list (list 'y 89))) 'NaN)
(check-expect (expr-eval-nan (list 'PLUS (list 'TIMES 4 'x) (list 'DIVIDE 2 0)) (list (list 'x 4))) 'NaN)
(check-expect (expr-eval-nan  (list 'DIVIDE 2 (list 'DIVIDE (list 'PLUS 1 2) 'x)) (list (list 'x 10))) 20/3)
(check-expect (expr-eval-nan  (list 'MINUS 2 (list 'TIMES 3 'x)) (list (list 'x 10))) -28)
(check-expect (expr-eval-nan (list 'DIVIDE 0 0) (list (list 'x 4))) 'NaN)
# Out:
# ACL2S !>>(DEFSNAPSHOT EC-1)
#
# Summary
# Form:  ( DEFLABEL EC-1 ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  EC-1
# ACL2S !>>(DEFDATA RETURN (ONEOF RATIONAL 'NAN))
#  Predicate events...
# Form:  ( DEFUN RETURNP ...)
# Form:  ( IN-THEORY (DISABLE* ...))
# Form:  ( IN-THEORY (ENABLE ...))
# Form:  ( TABLE ACL2::RULESET-TABLE ...)
# Form:  ( MAKE-EVENT (LET* ...))
#  Tau characterization events...
# Defdata/Note: RETURNP relatively complete for Tau.
# Form:  ( DEFTHM ACL2::DEF=>RETURN ...)
# Form:  ( DEFTHM ACL2::RETURN=>DEF ...)
#  Enumerator events...
# Form:  ( DEFUN NTH-RETURN-BUILTIN ...)
# Form:  ( DEFUN NTH-RETURN/ACC-BUILTIN ...)
# Form:  ( PROGN (SET-BOGUS-DEFUN-HINTS-OK T) ...)
# Form:  ( ENCAPSULATE NIL (LOGIC) ...)
# Time:  0.05 seconds (prove: 0.01, print: 0.00, other: 0.04)
#  Registering type...
# Form:  ( DEFUN NTH-RETURN ...)
# Form:  ( ENCAPSULATE (((NTH-RETURN * ...) ...) ...) ...)
# Form:  ( DEFUN NTH-RETURN/ACC ...)
# Form:  ( ENCAPSULATE (((NTH-RETURN/ACC * ...) ...) ...) ...)
# Form:  ( DEFATTACH (NTH-RETURN NTH-RETURN-BUILTIN) ...)
# Form:  ( DEFATTACH (NTH-RETURN/ACC NTH-RETURN/ACC-BUILTIN) ...)
# Form:  ( TABLE TYPE-METADATA-TABLE ...)
# Form:  ( PROGN (LOCAL ...) ...)
# Form:  ( ENCAPSULATE NIL (LOGIC) ...)
# Time:  0.02 seconds (prove: 0.00, print: 0.00, other: 0.02)
# Form:  ( MAKE-EVENT (DEFDATA::REGISTER-TYPE-FN ...))
# Time:  0.02 seconds (prove: 0.00, print: 0.00, other: 0.02)
# Form:  ( ENCAPSULATE NIL (WITH-OUTPUT :ON ...) ...)
# Time:  0.03 seconds (prove: 0.00, print: 0.00, other: 0.03)
# Form:  ( PROGN (ENCAPSULATE NIL ...) ...)
# Time:  0.08 seconds (prove: 0.01, print: 0.00, other: 0.08)
# Form:  ( ENCAPSULATE NIL (WITH-OUTPUT :OFF ...) ...)
# Time:  0.10 seconds (prove: 0.01, print: 0.00, other: 0.10)
#  T
# ACL2S !>>(DEFINEC
#           EXPR-EVAL-NAN
#           (TREE TREE ENVIRONMENT ENV)
#           RETURN
#           (IF
#            (OR (RATIONALP TREE) (EQUAL TREE 'NAN))
#            TREE
#            (IF
#             (SYMBOLP TREE)
#             (LOOKUP TREE ENVIRONMENT)
#             (IF
#              (OR (EQUAL (EXPR-EVAL-NAN (SECOND TREE)
#                                        ENVIRONMENT)
#                         'NAN)
#                  (AND (EQUAL (EXPR-EVAL-NAN (THIRD TREE) ENVIRONMENT)
#                              'NAN)
#                       (NOT (EQUAL (FIRST TREE) 'UMINUS))))
#              'NAN
#              (IF
#               (EQUAL (FIRST TREE) 'PLUS)
#               (+ (EXPR-EVAL-NAN (SECOND TREE)
#                                 ENVIRONMENT)
#                  (EXPR-EVAL-NAN (THIRD TREE)
#                                 ENVIRONMENT))
#               (IF
#                (EQUAL (FIRST TREE) 'MINUS)
#                (- (EXPR-EVAL-NAN (SECOND TREE)
#                                  ENVIRONMENT)
#                   (EXPR-EVAL-NAN (THIRD TREE)
#                                  ENVIRONMENT))
#                (IF
#                   (EQUAL (FIRST TREE) 'UMINUS)
#                   (- 0
#                      (EXPR-EVAL-NAN (SECOND TREE)
#                                     ENVIRONMENT))
#                   (IF (EQUAL (FIRST TREE) 'TIMES)
#                       (* (EXPR-EVAL-NAN (SECOND TREE)
#                                         ENVIRONMENT)
#                          (EXPR-EVAL-NAN (THIRD TREE)
#                                         ENVIRONMENT))
#                       (IF (EQUAL (FIRST TREE) 'DIVIDE)
#                           (IF (EQUAL (EXPR-EVAL-NAN (THIRD TREE) ENVIRONMENT)
#                                      0)
#                               'NAN
#                               (/ (EXPR-EVAL-NAN (SECOND TREE)
#                                                 ENVIRONMENT)
#                                  (EXPR-EVAL-NAN (THIRD TREE)
#                                                 ENVIRONMENT)))
#                           'NAN)))))))))
#
# Form:  ( TEST-DEFINITION EXPR-EVAL-NAN ... )
# Form:  ( TEST-BODY-CONTRACTS EXPR-EVAL-NAN... )
# Form:  ( TEST-FUNCTION-CONTRACT EXPR-EVAL-NAN ...)
# Testing: Done
# Elapsed Run Time: 10.25 seconds
# Form:  ( ADMIT-DEFINITION EXPR-EVAL-NAN ... )
# Time:  2.69 seconds (prove: 2.57, print: 0.00, other: 0.13)
# Form:  ( PROVE-FUNCTION-CONTRACT EXPR-EVAL-NAN ... )
# Time:  0.34 seconds (prove: 0.28, print: 0.00, other: 0.06)
# Form:  ( PROVE-BODY-CONTRACTS EXPR-EVAL-NAN ... )
# Time:  0.35 seconds (prove: 0.12, print: 0.00, other: 0.23)
# Elapsed Run Time: 3.46 seconds
# Function Name : EXPR-EVAL-NAN
# Termination proven -------- [*]
# Function Contract proven -- [*]
# Body Contracts proven ----- [*]
#  T
# ACL2S !>>(CHECK-EXPECT (EXPR-EVAL-NAN (LIST 'DIVIDE
#                                             (LIST 'MINUS (LIST 'UMINUS 6) 4)
#                                             'X)
#                                       (LIST (LIST 'Y 89)))
#                        'NAN)
#  :PASSED
# ACL2S !>>(CHECK-EXPECT (EXPR-EVAL-NAN (LIST 'PLUS
#                                             (LIST 'TIMES 4 'X)
#                                             (LIST 'DIVIDE 2 0))
#                                       (LIST (LIST 'X 4)))
#                        'NAN)
#  :PASSED
# ACL2S !>>(CHECK-EXPECT
#               (EXPR-EVAL-NAN (LIST 'DIVIDE
#                                    2 (LIST 'DIVIDE (LIST 'PLUS 1 2) 'X))
#                              (LIST (LIST 'X 10)))
#               20/3)
#  :PASSED
# ACL2S !>>(CHECK-EXPECT (EXPR-EVAL-NAN (LIST 'MINUS 2 (LIST 'TIMES 3 'X))
#                                       (LIST (LIST 'X 10)))
#                        -28)
#  :PASSED
# ACL2S !>>(CHECK-EXPECT (EXPR-EVAL-NAN (LIST 'DIVIDE 0 0)
#                                       (LIST (LIST 'X 4)))
#                        'NAN)
#  :PASSED

# %% [markdown]
# ## TODO-5 (10 points)
#
# We'll start the process of optimizing expressions with something simple. Suppose that you see an expressions like `(PLUS x 0)` where `x` is **any** expression (not just the letter `x`). Then clearly, that expression can be replaced with `x`, which should be faster to execute. That's what we mean by optimization. Here's a concrete example:
#
#     (TIMES (PLUS (MINUS x y) 0) 3) ==> (TIMES (MINUS x y) 3)
#
# Notice that the subexpression that was optimized is not necessarily at the top-level.
#
# Write the function `(remove-plus-0 tree)` that removes **all** occurrences of `(PLUS x 0)` and `(PLUS 0 y)` from the given expression tree.
#
# > Hint: Think about what using a postorder traversal again.

# %%
(defsnapshot todo-5)

(definec remove-plus-0 (tree :tree) :tree
    (if (or (rationalp tree) (symbolp tree))
        tree
        (if (equal (first tree) 'UMINUS)
            (cons (first tree) (list (remove-plus-0 (second tree))))
            (if (equal (first tree) 'PLUS)
                (if (equal (second tree) 0)
                    (remove-plus-0 (third tree))
                    (if (equal (third tree) 0)
                        (remove-plus-0 (second tree))
                        (append (cons (first tree) (list (remove-plus-0 (second tree)))) (list (remove-plus-0 (third tree))))
                    )
                )  
                (append (cons (first tree) (list (remove-plus-0 (second tree)))) (list (remove-plus-0 (third tree))))
            )     
        ) 
    )
)


(check-expect (remove-plus-0 (list 'TIMES (list 'PLUS (list 'MINUS 'x 'y) 0) 3)) (list 'TIMES (list 'MINUS 'x 'y) 3))
(check-expect (remove-plus-0 (list 'PLUS 'A 'A)) (list 'PLUS 'A 'A))
(check-expect (remove-plus-0 (list 'PLUS 'x 0)) 'x)
(check-expect (remove-plus-0 (list 'PLUS 0 'x)) 'x)
(check-expect (remove-plus-0 (list 'TIMES (list 'PLUS (list 'PLUS 0 'y) 0) 3)) (list 'TIMES 'y 3))
# Out:
# ACL2S !>>(DEFSNAPSHOT TODO-5)
#
# Summary
# Form:  ( DEFLABEL TODO-5 ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  TODO-5
# ACL2S !>>(DEFINEC
#           REMOVE-PLUS-0 (TREE TREE)
#           TREE
#           (IF
#            (OR (RATIONALP TREE) (SYMBOLP TREE))
#            TREE
#            (IF
#               (EQUAL (FIRST TREE) 'UMINUS)
#               (CONS (FIRST TREE)
#                     (LIST (REMOVE-PLUS-0 (SECOND TREE))))
#               (IF (EQUAL (FIRST TREE) 'PLUS)
#                   (IF (EQUAL (SECOND TREE) 0)
#                       (REMOVE-PLUS-0 (THIRD TREE))
#                       (IF (EQUAL (THIRD TREE) 0)
#                           (REMOVE-PLUS-0 (SECOND TREE))
#                           (APPEND (CONS (FIRST TREE)
#                                         (LIST (REMOVE-PLUS-0 (SECOND TREE))))
#                                   (LIST (REMOVE-PLUS-0 (THIRD TREE))))))
#                   (APPEND (CONS (FIRST TREE)
#                                 (LIST (REMOVE-PLUS-0 (SECOND TREE))))
#                           (LIST (REMOVE-PLUS-0 (THIRD TREE))))))))
#
# Form:  ( TEST-DEFINITION REMOVE-PLUS-0 ... )
# Form:  ( TEST-BODY-CONTRACTS REMOVE-PLUS-0... )
# Form:  ( TEST-FUNCTION-CONTRACT REMOVE-PLUS-0 ...)
# Testing: Done
# Elapsed Run Time: 2.68 seconds
# Form:  ( ADMIT-DEFINITION REMOVE-PLUS-0 ... )
# Time:  0.62 seconds (prove: 0.58, print: 0.00, other: 0.04)
# Form:  ( PROVE-FUNCTION-CONTRACT REMOVE-PLUS-0 ... )
# Time:  0.20 seconds (prove: 0.14, print: 0.00, other: 0.06)
# Form:  ( PROVE-BODY-CONTRACTS REMOVE-PLUS-0 ... )
# Time:  0.13 seconds (prove: 0.04, print: 0.00, other: 0.08)
# Elapsed Run Time: 1.01 seconds
# Function Name : REMOVE-PLUS-0
# Termination proven -------- [*]
# Function Contract proven -- [*]
# Body Contracts proven ----- [*]
#  T
# ACL2S !>>(CHECK-EXPECT
#               (REMOVE-PLUS-0 (LIST 'TIMES
#                                    (LIST 'PLUS (LIST 'MINUS 'X 'Y) 0)
#                                    3))
#               (LIST 'TIMES (LIST 'MINUS 'X 'Y) 3))
#  :PASSED
# ACL2S !>>(CHECK-EXPECT (REMOVE-PLUS-0 (LIST 'PLUS 'A 'A))
#                        (LIST 'PLUS 'A 'A))
#  :PASSED
# ACL2S !>>(CHECK-EXPECT (REMOVE-PLUS-0 (LIST 'PLUS 'X 0))
#                        'X)
#  :PASSED
# ACL2S !>>(CHECK-EXPECT (REMOVE-PLUS-0 (LIST 'PLUS 0 'X))
#                        'X)
#  :PASSED
# ACL2S !>>(CHECK-EXPECT (REMOVE-PLUS-0 (LIST 'TIMES
#                                             (LIST 'PLUS (LIST 'PLUS 0 'Y) 0)
#                                             3))
#                        (LIST 'TIMES 'Y 3))
#  :PASSED

# %% [markdown]
# ## TODO-6 (10 points)
#
# If your code for `remove-plus-0` is correct, then the value of the original expression should be the same as the value of the optimized expression, for any given environment. Use `test?` to confirm this property.
#
# > Hint: Don't forget to have a type hypothesis for each variable.

# %%
(defsnapshot todo-6)

(test? (implies (and (treep m) (envp e)) (equal (expr-eval-nan m e) (expr-eval-nan (remove-plus-0 m) e))))
# Out:
# ACL2S !>>(DEFSNAPSHOT TODO-6)
#
# Summary
# Form:  ( DEFLABEL TODO-6 ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  TODO-6
# ACL2S !>>(TEST? (IMPLIES (AND (TREEP M) (ENVP E))
#                          (EQUAL (EXPR-EVAL-NAN M E)
#                                 (EXPR-EVAL-NAN (REMOVE-PLUS-0 M) E))))
#
# **Summary of Cgen/testing**
# We tested 3000 examples across 2 subgoals, of which 2998 (2998 unique)
# satisfied the hypotheses, and found 0 counterexamples and 2998 witnesses.
#
# Cases in which the conjecture is true include:
#  [found in : "top"]
#  -- ((E '((A -1) (BA 0))) (M '(UMINUS A)))
#  -- ((E NIL) (M 131/1759))
#  -- ((E '((ABBAAAA -1))) (M '|5|))
#
# Test? succeeded. No counterexamples were found.

# %% [markdown]
# ## TODO-7 (10 points)
#
# The test in TODO-6 should not find any counterexample. If it does find one, either there's a bug in your code (so fix it), or you did not write down the property correctly (so fix that). But if you look at the output, you will probably find that the test is not very convincing. E.g., the patter `(PLUS ... 0)` is rare enough that it never comes up in the random tests.
#
# Let's make sure the code really is working. Use `thm` to **prove** the property fro TODO-6.

# %%
(defsnapshot todo-7)

(thm (implies (and (treep m) (envp e)) (equal (expr-eval-nan m e) (expr-eval-nan (remove-plus-0 m) e))))
# Out:
# ACL2S !>>(DEFSNAPSHOT TODO-7)
#
# Summary
# Form:  ( DEFLABEL TODO-7 ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  TODO-7
# ACL2S !>>(THM (IMPLIES (AND (TREEP M) (ENVP E))
#                        (EQUAL (EXPR-EVAL-NAN M E)
#                               (EXPR-EVAL-NAN (REMOVE-PLUS-0 M) E))))
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# Name the formula above *1.
#
# Perhaps we can prove *1 by induction.  Six induction schemes are suggested
# by this conjecture.  Subsumption reduces that number to four.  These
# merge into two derived induction schemes.  However, one of these is
# flawed and so we are left with one viable candidate.
#
# We will induct according to a scheme suggested by (REMOVE-PLUS-0 M),
# but modified to accommodate (EXPR-EVAL-NAN M E).  These suggestions
# were produced using the :induction rules EXPR-EVAL-NAN,
# EXPR-EVAL-NAN-INDUCTION-SCHEME, REMOVE-PLUS-0,
# REMOVE-PLUS-0-INDUCTION-SCHEME and TREEP.  If we let (:P E M) denote
# *1 above then the induction scheme we'll use is
# (AND (IMPLIES (NOT (TREEP M)) (:P E M))
#      (IMPLIES (AND (TREEP M)
#                    (NOT (OR (RATIONALP M) (SYMBOLP M)))
#                    (NOT (EQUAL (CAR M) 'UMINUS))
#                    (NOT (EQUAL (CAR M) 'PLUS))
#                    (:P E (CADR M))
#                    (:P E (CADDR M)))
#               (:P E M))
#      (IMPLIES (AND (TREEP M)
#                    (NOT (OR (RATIONALP M) (SYMBOLP M)))
#                    (EQUAL (CAR M) 'PLUS)
#                    (NOT (EQUAL (CADR M) 0))
#                    (NOT (EQUAL (CADDR M) 0))
#                    (:P E (CADR M))
#                    (:P E (CADDR M)))
#               (:P E M))
#      (IMPLIES (AND (TREEP M)
#                    (NOT (OR (RATIONALP M) (SYMBOLP M)))
#                    (EQUAL (CAR M) 'PLUS)
#                    (NOT (EQUAL (CADR M) 0))
#                    (EQUAL (CADDR M) 0)
#                    (:P E (CADR M)))
#               (:P E M))
#      (IMPLIES (AND (TREEP M)
#                    (NOT (OR (RATIONALP M) (SYMBOLP M)))
#                    (EQUAL (CAR M) 'PLUS)
#                    (EQUAL (CADR M) 0)
#                    (:P E (CADDR M)))
#               (:P E M))
#      (IMPLIES (AND (TREEP M)
#                    (NOT (OR (RATIONALP M) (SYMBOLP M)))
#                    (EQUAL (CAR M) 'UMINUS)
#                    (:P E (CADR M)))
#               (:P E M))
#      (IMPLIES (AND (TREEP M)
#                    (OR (RATIONALP M) (SYMBOLP M)))
#               (:P E M))).
# This induction is justified by the same argument used to admit REMOVE-PLUS-0.
# When applied to the goal at hand the above induction scheme produces
# 15 nontautological subgoals.
#
# Subgoal *1/15
# (IMPLIES (AND (TREEP M)
#               (NOT (OR (RATIONALP M) (SYMBOLP M)))
#               (NOT (EQUAL (CAR M) 'UMINUS))
#               (NOT (EQUAL (CAR M) 'PLUS))
#               (EQUAL (EXPR-EVAL-NAN (CADR M) E)
#                      (EXPR-EVAL-NAN (REMOVE-PLUS-0 (CADR M))
#                                     E))
#               (EQUAL (EXPR-EVAL-NAN (CADDR M) E)
#                      (EXPR-EVAL-NAN (REMOVE-PLUS-0 (CADDR M))
#                                     E))
#               (ENVP E))
#          (EQUAL (EXPR-EVAL-NAN M E)
#                 (EXPR-EVAL-NAN (REMOVE-PLUS-0 M) E))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But simplification reduces this to T, using the :compound-recognizer
# rule ENVP-IMPLIES-TLP, the :definitions EXPR-EVAL-NAN-DEFINITION-RULE,
# REMOVE-PLUS-0-DEFINITION-RULE, SYNP and TREEP, the :executable-counterpart
# of EQUAL, primitive type reasoning, the :rewrite rules ACL2::|(* 0 x)|,
# ACL2::|(* x (if a b c))|, ACL2::|(* y x)|, ACL2::|(+ 0 x)|,
# ACL2::|(+ x (if a b c))|, ACL2::|(+ y x)|, ACL2::APPEND-OF-CONS,
# ACL2::APPEND-WHEN-NOT-CONSP, CAR-CONS, CDR-CONS, ACL2::DEFAULT-DIVIDE,
# ACL2::DEFAULT-MINUS, ACL2::DEFAULT-PLUS-1, ACL2::DEFAULT-TIMES-1,
# ACL2::DEFAULT-TIMES-2 and REMOVE-PLUS-0-CONTRACT and the :type-prescription
# rule TREEP.
#
# Subgoal *1/14
# (IMPLIES (AND (TREEP M)
#               (NOT (OR (RATIONALP M) (SYMBOLP M)))
#               (NOT (EQUAL (CAR M) 'UMINUS))
#               (NOT (EQUAL (CAR M) 'PLUS))
#               (NOT (TREEP (CADR M)))
#               (EQUAL (EXPR-EVAL-NAN (CADDR M) E)
#                      (EXPR-EVAL-NAN (REMOVE-PLUS-0 (CADDR M))
#                                     E))
#               (ENVP E))
#          (EQUAL (EXPR-EVAL-NAN M E)
#                 (EXPR-EVAL-NAN (REMOVE-PLUS-0 M) E))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But simplification reduces this to T, using the :definition TREEP.
#
# Subgoal *1/13
# (IMPLIES (AND (TREEP M)
#               (NOT (OR (RATIONALP M) (SYMBOLP M)))
#               (NOT (EQUAL (CAR M) 'UMINUS))
#               (NOT (EQUAL (CAR M) 'PLUS))
#               (EQUAL (EXPR-EVAL-NAN (CADR M) E)
#                      (EXPR-EVAL-NAN (REMOVE-PLUS-0 (CADR M))
#                                     E))
#               (NOT (TREEP (CADDR M)))
#               (ENVP E))
#          (EQUAL (EXPR-EVAL-NAN M E)
#                 (EXPR-EVAL-NAN (REMOVE-PLUS-0 M) E))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But simplification reduces this to T, using the :definition TREEP.
#
# Subgoal *1/12
# (IMPLIES (AND (TREEP M)
#               (NOT (OR (RATIONALP M) (SYMBOLP M)))
#               (NOT (EQUAL (CAR M) 'UMINUS))
#               (NOT (EQUAL (CAR M) 'PLUS))
#               (NOT (TREEP (CADR M)))
#               (NOT (TREEP (CADDR M)))
#               (ENVP E))
#          (EQUAL (EXPR-EVAL-NAN M E)
#                 (EXPR-EVAL-NAN (REMOVE-PLUS-0 M) E))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But simplification reduces this to T, using the :definition TREEP.
#
# Subgoal *1/11
# (IMPLIES (AND (TREEP M)
#               (NOT (OR (RATIONALP M) (SYMBOLP M)))
#               (EQUAL (CAR M) 'PLUS)
#               (NOT (EQUAL (CADR M) 0))
#               (NOT (EQUAL (CADDR M) 0))
#               (EQUAL (EXPR-EVAL-NAN (CADR M) E)
#                      (EXPR-EVAL-NAN (REMOVE-PLUS-0 (CADR M))
#                                     E))
#               (EQUAL (EXPR-EVAL-NAN (CADDR M) E)
#                      (EXPR-EVAL-NAN (REMOVE-PLUS-0 (CADDR M))
#                                     E))
#               (ENVP E))
#          (EQUAL (EXPR-EVAL-NAN M E)
#                 (EXPR-EVAL-NAN (REMOVE-PLUS-0 M) E))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But simplification reduces this to T, using the :compound-recognizer
# rule ENVP-IMPLIES-TLP, the :definitions EXPR-EVAL-NAN-DEFINITION-RULE,
# REMOVE-PLUS-0-DEFINITION-RULE, SYNP and TREEP, the :executable-counterpart
# of EQUAL, primitive type reasoning, the :rewrite rules ACL2::APPEND-OF-CONS,
# ACL2::APPEND-WHEN-NOT-CONSP, CAR-CONS, CDR-CONS, ACL2::DEFAULT-PLUS-1,
# ACL2::DEFAULT-PLUS-2 and REMOVE-PLUS-0-CONTRACT and the :type-prescription
# rule TREEP.
#
# Subgoal *1/10
# (IMPLIES (AND (TREEP M)
#               (NOT (OR (RATIONALP M) (SYMBOLP M)))
#               (EQUAL (CAR M) 'PLUS)
#               (NOT (EQUAL (CADR M) 0))
#               (NOT (EQUAL (CADDR M) 0))
#               (NOT (TREEP (CADR M)))
#               (EQUAL (EXPR-EVAL-NAN (CADDR M) E)
#                      (EXPR-EVAL-NAN (REMOVE-PLUS-0 (CADDR M))
#                                     E))
#               (ENVP E))
#          (EQUAL (EXPR-EVAL-NAN M E)
#                 (EXPR-EVAL-NAN (REMOVE-PLUS-0 M) E))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But simplification reduces this to T, using the :definition TREEP and
# the :executable-counterpart of EQUAL.
#
# Subgoal *1/9
# (IMPLIES (AND (TREEP M)
#               (NOT (OR (RATIONALP M) (SYMBOLP M)))
#               (EQUAL (CAR M) 'PLUS)
#               (NOT (EQUAL (CADR M) 0))
#               (NOT (EQUAL (CADDR M) 0))
#               (EQUAL (EXPR-EVAL-NAN (CADR M) E)
#                      (EXPR-EVAL-NAN (REMOVE-PLUS-0 (CADR M))
#                                     E))
#               (NOT (TREEP (CADDR M)))
#               (ENVP E))
#          (EQUAL (EXPR-EVAL-NAN M E)
#                 (EXPR-EVAL-NAN (REMOVE-PLUS-0 M) E))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But simplification reduces this to T, using the :definition TREEP and
# the :executable-counterpart of EQUAL.
#
# Subgoal *1/8
# (IMPLIES (AND (TREEP M)
#               (NOT (OR (RATIONALP M) (SYMBOLP M)))
#               (EQUAL (CAR M) 'PLUS)
#               (NOT (EQUAL (CADR M) 0))
#               (NOT (EQUAL (CADDR M) 0))
#               (NOT (TREEP (CADR M)))
#               (NOT (TREEP (CADDR M)))
#               (ENVP E))
#          (EQUAL (EXPR-EVAL-NAN M E)
#                 (EXPR-EVAL-NAN (REMOVE-PLUS-0 M) E))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But simplification reduces this to T, using the :definition TREEP and
# the :executable-counterpart of EQUAL.
#
# Subgoal *1/7
# (IMPLIES (AND (TREEP M)
#               (NOT (OR (RATIONALP M) (SYMBOLP M)))
#               (EQUAL (CAR M) 'PLUS)
#               (NOT (EQUAL (CADR M) 0))
#               (EQUAL (CADDR M) 0)
#               (EQUAL (EXPR-EVAL-NAN (CADR M) E)
#                      (EXPR-EVAL-NAN (REMOVE-PLUS-0 (CADR M))
#                                     E))
#               (ENVP E))
#          (EQUAL (EXPR-EVAL-NAN M E)
#                 (EXPR-EVAL-NAN (REMOVE-PLUS-0 M) E))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# This simplifies, using the :compound-recognizer rule ENVP-IMPLIES-TLP,
# the :definitions EXPR-EVAL-NAN-DEFINITION-RULE (if-intro),
# REMOVE-PLUS-0-DEFINITION-RULE, SYNP and TREEP (if-intro), the :executable-
# counterparts of EQUAL, NOT and TREEP, primitive type reasoning, the
# :rewrite rules ACL2::|(+ 0 x)|, ACL2::|(+ x (- x))|, ACL2::|(+ y (+ x z))|,
# ACL2::|(+ y x)|, ACL2::|(equal (if a b c) x)| (if-intro),
# ACL2::BUBBLE-DOWN-+-MATCH-1, ACL2::BUBBLE-DOWN-+-MATCH-3, DEF=>TREE,
# ACL2::DEFAULT-PLUS-1 (if-intro), ACL2::DEFAULT-PLUS-2 (if-intro),
# ACL2::NORMALIZE-ADDENDS and ACL2::SIMPLIFY-SUMS-EQUAL and the :type-
# prescription rule TREEP, to the following three conjectures.
#
# Subgoal *1/7.3
# (IMPLIES (AND (CONSP M)
#               (CONSP (CDR M))
#               (TREEP (CADR M))
#               (CONSP (CDDR M))
#               (NOT (CDDDR M))
#               (NOT (RATIONALP M))
#               (NOT (SYMBOLP M))
#               (EQUAL (CAR M) 'PLUS)
#               (NOT (EQUAL (CADR M) 0))
#               (EQUAL (CADDR M) 0)
#               (EQUAL (EXPR-EVAL-NAN (CADR M) E)
#                      (EXPR-EVAL-NAN (REMOVE-PLUS-0 (CADR M))
#                                     E))
#               (ENVP E)
#               (NOT (EQUAL (EXPR-EVAL-NAN (CADR M) E)
#                           'NAN)))
#          (NOT (EQUAL (EXPR-EVAL-NAN 0 E) 'NAN))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But simplification reduces this to T, using the :compound-recognizer
# rule ENVP-IMPLIES-TLP, the :definition EXPR-EVAL-NAN-DEFINITION-RULE
# and the :executable-counterparts of EQUAL, RATIONALP and TREEP.
#
# Subgoal *1/7.2
# (IMPLIES (AND (CONSP M)
#               (CONSP (CDR M))
#               (TREEP (CADR M))
#               (CONSP (CDDR M))
#               (NOT (CDDDR M))
#               (NOT (RATIONALP M))
#               (NOT (SYMBOLP M))
#               (EQUAL (CAR M) 'PLUS)
#               (NOT (EQUAL (CADR M) 0))
#               (EQUAL (CADDR M) 0)
#               (EQUAL (EXPR-EVAL-NAN (CADR M) E)
#                      (EXPR-EVAL-NAN (REMOVE-PLUS-0 (CADR M))
#                                     E))
#               (ENVP E)
#               (NOT (EQUAL (EXPR-EVAL-NAN (CADR M) E)
#                           'NAN)))
#          (ACL2-NUMBERP (EXPR-EVAL-NAN (CADR M) E))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But we reduce the conjecture to T, by the :executable-counterpart of
# TAU-SYSTEM.
#
# Subgoal *1/7.1
# (IMPLIES (AND (CONSP M)
#               (CONSP (CDR M))
#               (TREEP (CADR M))
#               (CONSP (CDDR M))
#               (NOT (CDDDR M))
#               (NOT (RATIONALP M))
#               (NOT (SYMBOLP M))
#               (EQUAL (CAR M) 'PLUS)
#               (NOT (EQUAL (CADR M) 0))
#               (EQUAL (CADDR M) 0)
#               (EQUAL (EXPR-EVAL-NAN (CADR M) E)
#                      (EXPR-EVAL-NAN (REMOVE-PLUS-0 (CADR M))
#                                     E))
#               (ENVP E)
#               (NOT (EQUAL (EXPR-EVAL-NAN (CADR M) E) 'NAN))
#               (ACL2-NUMBERP (EXPR-EVAL-NAN 0 E)))
#          (EQUAL (EXPR-EVAL-NAN 0 E) 0)).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But simplification reduces this to T, using the :compound-recognizer
# rule ENVP-IMPLIES-TLP, the :definition EXPR-EVAL-NAN-DEFINITION-RULE
# and the :executable-counterparts of ACL2-NUMBERP, EQUAL, RATIONALP
# and TREEP.
#
# Subgoal *1/6
# (IMPLIES (AND (TREEP M)
#               (NOT (OR (RATIONALP M) (SYMBOLP M)))
#               (EQUAL (CAR M) 'PLUS)
#               (NOT (EQUAL (CADR M) 0))
#               (EQUAL (CADDR M) 0)
#               (NOT (TREEP (CADR M)))
#               (ENVP E))
#          (EQUAL (EXPR-EVAL-NAN M E)
#                 (EXPR-EVAL-NAN (REMOVE-PLUS-0 M) E))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But simplification reduces this to T, using the :definition TREEP and
# the :executable-counterpart of EQUAL.
#
# Subgoal *1/5
# (IMPLIES (AND (TREEP M)
#               (NOT (OR (RATIONALP M) (SYMBOLP M)))
#               (EQUAL (CAR M) 'PLUS)
#               (EQUAL (CADR M) 0)
#               (EQUAL (EXPR-EVAL-NAN (CADDR M) E)
#                      (EXPR-EVAL-NAN (REMOVE-PLUS-0 (CADDR M))
#                                     E))
#               (ENVP E))
#          (EQUAL (EXPR-EVAL-NAN M E)
#                 (EXPR-EVAL-NAN (REMOVE-PLUS-0 M) E))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# This simplifies, using the :compound-recognizer rule ENVP-IMPLIES-TLP,
# the :definitions EXPR-EVAL-NAN-DEFINITION-RULE (if-intro),
# REMOVE-PLUS-0-DEFINITION-RULE, SYNP and TREEP (if-intro), the :executable-
# counterparts of EQUAL, NOT and TREEP, primitive type reasoning, the
# :rewrite rules ACL2::|(+ 0 x)|, ACL2::|(+ x (- x))|, ACL2::|(+ y (+ x z))|,
# ACL2::|(+ y x)|, ACL2::|(equal (if a b c) x)| (if-intro),
# ACL2::BUBBLE-DOWN-+-MATCH-1, DEF=>TREE, ACL2::DEFAULT-PLUS-1 (if-intro),
# ACL2::DEFAULT-PLUS-2 (if-intro), ACL2::NORMALIZE-ADDENDS and
# ACL2::SIMPLIFY-SUMS-EQUAL and the :type-prescription rule TREEP, to
# the following three conjectures.
#
# Subgoal *1/5.3
# (IMPLIES (AND (CONSP M)
#               (CONSP (CDR M))
#               (CONSP (CDDR M))
#               (TREEP (CADDR M))
#               (NOT (CDDDR M))
#               (NOT (RATIONALP M))
#               (NOT (SYMBOLP M))
#               (EQUAL (CAR M) 'PLUS)
#               (EQUAL (CADR M) 0)
#               (EQUAL (EXPR-EVAL-NAN (CADDR M) E)
#                      (EXPR-EVAL-NAN (REMOVE-PLUS-0 (CADDR M))
#                                     E))
#               (ENVP E)
#               (EQUAL (EXPR-EVAL-NAN 0 E) 'NAN))
#          (EQUAL 'NAN
#                 (EXPR-EVAL-NAN (CADDR M) E))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But simplification reduces this to T, using the :compound-recognizer
# rule ENVP-IMPLIES-TLP, the :definition EXPR-EVAL-NAN-DEFINITION-RULE
# and the :executable-counterparts of EQUAL, RATIONALP and TREEP.
#
# Subgoal *1/5.2
# (IMPLIES (AND (CONSP M)
#               (CONSP (CDR M))
#               (CONSP (CDDR M))
#               (TREEP (CADDR M))
#               (NOT (CDDDR M))
#               (NOT (RATIONALP M))
#               (NOT (SYMBOLP M))
#               (EQUAL (CAR M) 'PLUS)
#               (EQUAL (CADR M) 0)
#               (EQUAL (EXPR-EVAL-NAN (CADDR M) E)
#                      (EXPR-EVAL-NAN (REMOVE-PLUS-0 (CADDR M))
#                                     E))
#               (ENVP E)
#               (NOT (EQUAL (EXPR-EVAL-NAN 0 E) 'NAN))
#               (NOT (EQUAL (EXPR-EVAL-NAN (CADDR M) E)
#                           'NAN)))
#          (ACL2-NUMBERP (EXPR-EVAL-NAN (CADDR M) E))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But we reduce the conjecture to T, by the :executable-counterpart of
# TAU-SYSTEM.
#
# Subgoal *1/5.1
# (IMPLIES (AND (CONSP M)
#               (CONSP (CDR M))
#               (CONSP (CDDR M))
#               (TREEP (CADDR M))
#               (NOT (CDDDR M))
#               (NOT (RATIONALP M))
#               (NOT (SYMBOLP M))
#               (EQUAL (CAR M) 'PLUS)
#               (EQUAL (CADR M) 0)
#               (EQUAL (EXPR-EVAL-NAN (CADDR M) E)
#                      (EXPR-EVAL-NAN (REMOVE-PLUS-0 (CADDR M))
#                                     E))
#               (ENVP E)
#               (NOT (EQUAL (EXPR-EVAL-NAN 0 E) 'NAN))
#               (NOT (EQUAL (EXPR-EVAL-NAN (CADDR M) E)
#                           'NAN))
#               (ACL2-NUMBERP (EXPR-EVAL-NAN 0 E)))
#          (EQUAL (EXPR-EVAL-NAN 0 E) 0)).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But simplification reduces this to T, using the :compound-recognizer
# rule ENVP-IMPLIES-TLP, the :definition EXPR-EVAL-NAN-DEFINITION-RULE
# and the :executable-counterparts of ACL2-NUMBERP, EQUAL, RATIONALP
# and TREEP.
#
# Subgoal *1/4
# (IMPLIES (AND (TREEP M)
#               (NOT (OR (RATIONALP M) (SYMBOLP M)))
#               (EQUAL (CAR M) 'PLUS)
#               (EQUAL (CADR M) 0)
#               (NOT (TREEP (CADDR M)))
#               (ENVP E))
#          (EQUAL (EXPR-EVAL-NAN M E)
#                 (EXPR-EVAL-NAN (REMOVE-PLUS-0 M) E))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But simplification reduces this to T, using the :definition TREEP and
# the :executable-counterpart of EQUAL.
#
# Subgoal *1/3
# (IMPLIES (AND (TREEP M)
#               (NOT (OR (RATIONALP M) (SYMBOLP M)))
#               (EQUAL (CAR M) 'UMINUS)
#               (EQUAL (EXPR-EVAL-NAN (CADR M) E)
#                      (EXPR-EVAL-NAN (REMOVE-PLUS-0 (CADR M))
#                                     E))
#               (ENVP E))
#          (EQUAL (EXPR-EVAL-NAN M E)
#                 (EXPR-EVAL-NAN (REMOVE-PLUS-0 M) E))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But simplification reduces this to T, using the :compound-recognizer
# rule ENVP-IMPLIES-TLP, the :definitions EXPR-EVAL-NAN-DEFINITION-RULE,
# REMOVE-PLUS-0-DEFINITION-RULE, SYNP and TREEP, the :executable-counterparts
# of BINARY-+, CAR and EQUAL, primitive type reasoning, the :rewrite
# rules ACL2::|(+ 0 x)|, ACL2::|(+ x (if a b c))|, CAR-CONS, CDR-CONS,
# ACL2::DEFAULT-MINUS and REMOVE-PLUS-0-CONTRACT and the :type-prescription
# rule TREEP.
#
# Subgoal *1/2
# (IMPLIES (AND (TREEP M)
#               (NOT (OR (RATIONALP M) (SYMBOLP M)))
#               (EQUAL (CAR M) 'UMINUS)
#               (NOT (TREEP (CADR M)))
#               (ENVP E))
#          (EQUAL (EXPR-EVAL-NAN M E)
#                 (EXPR-EVAL-NAN (REMOVE-PLUS-0 M) E))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But simplification reduces this to T, using the :definition TREEP and
# the :executable-counterpart of EQUAL.
#
# Subgoal *1/1
# (IMPLIES (AND (TREEP M)
#               (OR (RATIONALP M) (SYMBOLP M))
#               (ENVP E))
#          (EQUAL (EXPR-EVAL-NAN M E)
#                 (EXPR-EVAL-NAN (REMOVE-PLUS-0 M) E))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But simplification reduces this to T, using the :compound-recognizer
# rule ENVP-IMPLIES-TLP, the :definitions EXPR-EVAL-NAN-DEFINITION-RULE,
# REMOVE-PLUS-0-DEFINITION-RULE and TREEP, primitive type reasoning and
# the :rewrite rule DEF=>TREE.
#
# That completes the proof of *1.
#
# Q.E.D.
#
# Summary
# Form:  ( THM ...)
# Rules: ((:COMPOUND-RECOGNIZER ENVP-IMPLIES-TLP)
#         (:DEFINITION EXPR-EVAL-NAN-DEFINITION-RULE)
#         (:DEFINITION NOT)
#         (:DEFINITION REMOVE-PLUS-0-DEFINITION-RULE)
#         (:DEFINITION SYNP)
#         (:DEFINITION TREEP)
#         (:EXECUTABLE-COUNTERPART ACL2-NUMBERP)
#         (:EXECUTABLE-COUNTERPART BINARY-+)
#         (:EXECUTABLE-COUNTERPART CAR)
#         (:EXECUTABLE-COUNTERPART EQUAL)
#         (:EXECUTABLE-COUNTERPART NOT)
#         (:EXECUTABLE-COUNTERPART RATIONALP)
#         (:EXECUTABLE-COUNTERPART TAU-SYSTEM)
#         (:EXECUTABLE-COUNTERPART TREEP)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:INDUCTION EXPR-EVAL-NAN)
#         (:INDUCTION EXPR-EVAL-NAN-INDUCTION-SCHEME)
#         (:INDUCTION REMOVE-PLUS-0)
#         (:INDUCTION REMOVE-PLUS-0-INDUCTION-SCHEME)
#         (:INDUCTION TREEP)
#         (:REWRITE ACL2::|(* 0 x)|)
#         (:REWRITE ACL2::|(* x (if a b c))|)
#         (:REWRITE ACL2::|(* y x)|)
#         (:REWRITE ACL2::|(+ 0 x)|)
#         (:REWRITE ACL2::|(+ x (- x))|)
#         (:REWRITE ACL2::|(+ x (if a b c))|)
#         (:REWRITE ACL2::|(+ y (+ x z))|)
#         (:REWRITE ACL2::|(+ y x)|)
#         (:REWRITE ACL2::|(equal (if a b c) x)|)
#         (:REWRITE ACL2::APPEND-OF-CONS)
#         (:REWRITE ACL2::APPEND-WHEN-NOT-CONSP)
#         (:REWRITE ACL2::BUBBLE-DOWN-+-MATCH-1)
#         (:REWRITE ACL2::BUBBLE-DOWN-+-MATCH-3)
#         (:REWRITE CAR-CONS)
#         (:REWRITE CDR-CONS)
#         (:REWRITE DEF=>TREE)
#         (:REWRITE ACL2::DEFAULT-DIVIDE)
#         (:REWRITE ACL2::DEFAULT-MINUS)
#         (:REWRITE ACL2::DEFAULT-PLUS-1)
#         (:REWRITE ACL2::DEFAULT-PLUS-2)
#         (:REWRITE ACL2::DEFAULT-TIMES-1)
#         (:REWRITE ACL2::DEFAULT-TIMES-2)
#         (:REWRITE ACL2::NORMALIZE-ADDENDS)
#         (:REWRITE REMOVE-PLUS-0-CONTRACT)
#         (:REWRITE ACL2::SIMPLIFY-SUMS-EQUAL)
#         (:TYPE-PRESCRIPTION TREEP))
# Splitter rules (see :DOC splitter):
#   if-intro: ((:DEFINITION EXPR-EVAL-NAN-DEFINITION-RULE)
#              (:DEFINITION TREEP)
#              (:REWRITE ACL2::|(equal (if a b c) x)|)
#              (:REWRITE ACL2::DEFAULT-PLUS-1)
#              (:REWRITE ACL2::DEFAULT-PLUS-2))
# Warnings:  Invariant-risk
# Time:  0.57 seconds (prove: 0.46, print: 0.01, other: 0.10)
# Prover steps counted:  26744
#
# **Summary of Cgen/testing**
# We tested 2000 examples across 1 subgoals, of which 1968 (1968 unique)
# satisfied the hypotheses, and found 0 counterexamples and 1968 witnesses.
#
# Cases in which the conjecture is true include:
#  [found in : "Goal"]
#  -- ((E '((BA -1))) (M 'BL))
#  -- ((E '((O -1/2))) (M '(UMINUS 0)))
#  -- ((E '((AAAD 0))) (M '(DIVIDE A 0)))
#
# Proof succeeded.

# %% [markdown]
# ## TODO-8 (10 points)
#
# Here is another opportunity for optimization. Consider the expression
#
#     (PLUS (TIMES 2 3) x)
#
# where `x` is **any** expression (not just the variable `x`). This is clearly the same as
#
#     (PLUS 6 x)
#
# Write a function `(fold-constants tree)` that removes all constant subexpressions from the given expression tree. A constant subexpression is one whose arguments are constant terms. For example,
#
#     (PLUS (TIMES 2 (MINUS 6 3)) (UMINUS 5)) ==> 1
#
# That's an extreme example where the entire expression was really a constant.

# %%
(defsnapshot todo-8)

(definec fold-constants (tree :tree) :tree
    (if (rationalp tree)
        tree
        (if (symbolp tree)
            tree  
            (if (or (equal (fold-constants (second tree)) 'NaN) (and (equal (fold-constants (third tree)) 'NaN) (not (equal (first tree) 'UMINUS))))
                'NaN   
                (if (and (equal (first tree) 'UMINUS) (not (rationalp (fold-constants (second tree)))))
                    (list 'UMINUS (second tree))
                         (if (equal (first tree) 'UMINUS)
                            (- 0 (fold-constants (second tree)))
                             (if (or (not (rationalp (fold-constants (second tree)))) (not (rationalp (fold-constants (third tree)))))
                                 (list (first tree) (fold-constants (second tree)) (fold-constants (third tree)))
                                 (if (not (rationalp (fold-constants (second tree))))
                                     (list (first tree) (second tree) (fold-constants (third tree)))
                                     (if (not (rationalp (fold-constants (third tree))))
                                        (list (first tree) (fold-constants (second tree)) (third tree))                       
                                        (if (equal (first tree) 'PLUS)
                                            (+ (fold-constants (second tree)) (fold-constants (third tree)))
                                            (if (equal (first tree) 'MINUS)
                                                (- (fold-constants (second tree)) (fold-constants (third tree)))
                                                (if (equal (first tree) 'TIMES)
                                                    (* (fold-constants (second tree)) (fold-constants (third tree)))
                                                    (if (equal (first tree) 'DIVIDE)
                                                        (if (equal (fold-constants (third tree)) 0)
                                                            'NaN
                                                            (/ (fold-constants (second tree)) (fold-constants (third tree)))
                                                        )
                                                        'NaN
                                                    )
                                                )
                                            )
                                        )
                                    )
                                )
                            )
                        )
                    )   
                )  
            )
        )   
    )



(check-expect (fold-constants (list 'PLUS (list 'TIMES 2 3) 'x)) (list 'PLUS 6 'x))
(check-expect (fold-constants (list 'PLUS (list 'MINUS 2 7) (list 'PLUS (list 'DIVIDE 1 7) 'x))) (list 'PLUS -5 (list 'PLUS 1/7 'x)))
(check-expect (fold-constants (list 'PLUS (list 'TIMES 2 3) (list 'TIMES (list 'DIVIDE 7 4) 'x))) (list 'PLUS 6 (list 'TIMES 7/4 'x)))
(check-expect (fold-constants (list 'PLUS (list 'TIMES 2 (list 'MINUS 6 3)) (list 'UMINUS 5))) 1)
(check-expect (fold-constants (list 'DIVIDE (list 'TIMES 2 3) 0)) 'NaN)
# Out:
# ACL2S !>>(DEFSNAPSHOT TODO-8)
#
# Summary
# Form:  ( DEFLABEL TODO-8 ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  TODO-8
# ACL2S !>>(DEFINEC
#           FOLD-CONSTANTS (TREE TREE)
#           TREE
#           (IF
#            (RATIONALP TREE)
#            TREE
#            (IF
#             (SYMBOLP TREE)
#             TREE
#             (IF
#              (OR (EQUAL (FOLD-CONSTANTS (SECOND TREE))
#                         'NAN)
#                  (AND (EQUAL (FOLD-CONSTANTS (THIRD TREE))
#                              'NAN)
#                       (NOT (EQUAL (FIRST TREE) 'UMINUS))))
#              'NAN
#              (IF
#               (AND (EQUAL (FIRST TREE) 'UMINUS)
#                    (NOT (RATIONALP (FOLD-CONSTANTS (SECOND TREE)))))
#               (LIST 'UMINUS (SECOND TREE))
#               (IF
#                (EQUAL (FIRST TREE) 'UMINUS)
#                (- 0 (FOLD-CONSTANTS (SECOND TREE)))
#                (IF
#                 (OR (NOT (RATIONALP (FOLD-CONSTANTS (SECOND TREE))))
#                     (NOT (RATIONALP (FOLD-CONSTANTS (THIRD TREE)))))
#                 (LIST (FIRST TREE)
#                       (FOLD-CONSTANTS (SECOND TREE))
#                       (FOLD-CONSTANTS (THIRD TREE)))
#                 (IF
#                  (NOT (RATIONALP (FOLD-CONSTANTS (SECOND TREE))))
#                  (LIST (FIRST TREE)
#                        (SECOND TREE)
#                        (FOLD-CONSTANTS (THIRD TREE)))
#                  (IF
#                   (NOT (RATIONALP (FOLD-CONSTANTS (THIRD TREE))))
#                   (LIST (FIRST TREE)
#                         (FOLD-CONSTANTS (SECOND TREE))
#                         (THIRD TREE))
#                   (IF (EQUAL (FIRST TREE) 'PLUS)
#                       (+ (FOLD-CONSTANTS (SECOND TREE))
#                          (FOLD-CONSTANTS (THIRD TREE)))
#                       (IF (EQUAL (FIRST TREE) 'MINUS)
#                           (- (FOLD-CONSTANTS (SECOND TREE))
#                              (FOLD-CONSTANTS (THIRD TREE)))
#                           (IF (EQUAL (FIRST TREE) 'TIMES)
#                               (* (FOLD-CONSTANTS (SECOND TREE))
#                                  (FOLD-CONSTANTS (THIRD TREE)))
#                               (IF (EQUAL (FIRST TREE) 'DIVIDE)
#                                   (IF (EQUAL (FOLD-CONSTANTS (THIRD TREE)) 0)
#                                       'NAN
#                                       (/ (FOLD-CONSTANTS (SECOND TREE))
#                                          (FOLD-CONSTANTS (THIRD TREE))))
#                                   'NAN)))))))))))))
#
# Form:  ( TEST-DEFINITION FOLD-CONSTANTS ... )
# Form:  ( TEST-BODY-CONTRACTS FOLD-CONSTANTS... )
# Form:  ( TEST-FUNCTION-CONTRACT FOLD-CONSTANTS ...)
# Testing: Done
# Elapsed Run Time: 10.32 seconds
# Form:  ( ADMIT-DEFINITION FOLD-CONSTANTS ... )
# Time:  1.71 seconds (prove: 1.59, print: 0.00, other: 0.13)
# Form:  ( PROVE-FUNCTION-CONTRACT FOLD-CONSTANTS ... )
# Time:  0.45 seconds (prove: 0.39, print: 0.00, other: 0.06)
# Form:  ( PROVE-BODY-CONTRACTS FOLD-CONSTANTS ... )
# Time:  0.36 seconds (prove: 0.10, print: 0.00, other: 0.25)
# Elapsed Run Time: 2.61 seconds
# Function Name : FOLD-CONSTANTS
# Termination proven -------- [*]
# Function Contract proven -- [*]
# Body Contracts proven ----- [*]
#  T
# ACL2S !>>(CHECK-EXPECT (FOLD-CONSTANTS (LIST 'PLUS (LIST 'TIMES 2 3) 'X))
#                        (LIST 'PLUS 6 'X))
#  :PASSED
# ACL2S !>>(CHECK-EXPECT
#               (FOLD-CONSTANTS (LIST 'PLUS
#                                     (LIST 'MINUS 2 7)
#                                     (LIST 'PLUS (LIST 'DIVIDE 1 7) 'X)))
#               (LIST 'PLUS -5 (LIST 'PLUS 1/7 'X)))
#  :PASSED
# ACL2S !>>(CHECK-EXPECT
#               (FOLD-CONSTANTS (LIST 'PLUS
#                                     (LIST 'TIMES 2 3)
#                                     (LIST 'TIMES (LIST 'DIVIDE 7 4) 'X)))
#               (LIST 'PLUS 6 (LIST 'TIMES 7/4 'X)))
#  :PASSED
# ACL2S !>>(CHECK-EXPECT
#               (FOLD-CONSTANTS (LIST 'PLUS
#                                     (LIST 'TIMES 2 (LIST 'MINUS 6 3))
#                                     (LIST 'UMINUS 5)))
#               1)
#  :PASSED
# ACL2S !>>(CHECK-EXPECT (FOLD-CONSTANTS (LIST 'DIVIDE (LIST 'TIMES 2 3) 0))
#                        'NAN)
#  :PASSED

# %% [markdown]
# ## TODO-9 (10 points)
#
# Let's make sure the program in TODO-8 works correctly. Use `test?` to verify the property that the value of an expression after folding constant terms does not change. E.g., the value of
#
#     (PLUS (TIMES 2 3) x)
#
# is the same as the value of
#
#     (PLUS 6 x)
#
# in any environment.

# %%
(defsnapshot todo-9)

(test? (implies (and (treep m) (envp e)) (equal (expr-eval-nan m e) (expr-eval-nan (fold-constants m) e))))
# Out:
# ACL2S !>>(DEFSNAPSHOT TODO-9)
#
# Summary
# Form:  ( DEFLABEL TODO-9 ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  TODO-9
# ACL2S !>>(TEST? (IMPLIES (AND (TREEP M) (ENVP E))
#                          (EQUAL (EXPR-EVAL-NAN M E)
#                                 (EXPR-EVAL-NAN (FOLD-CONSTANTS M) E))))
#
# **Summary of Cgen/testing**
# We tested 3000 examples across 2 subgoals, of which 2944 (2944 unique)
# satisfied the hypotheses, and found 0 counterexamples and 2944 witnesses.
#
# Cases in which the conjecture is true include:
#  [found in : "top"]
#  -- ((E '((AABAA -1) (A -1) (BA 0))) (M '(DIVIDE (PLUS 0 0) 0)))
#  -- ((E '((A 0) (A 0) (A 0))) (M '(UMINUS 0)))
#  -- ((E NIL) (M '(MINUS 0 0)))
#
# Test? succeeded. No counterexamples were found.

# %% [markdown]
# ## TODO-10 (10 points)
#
# Again, the automated testing should show no counterexamples, but the tests may not be terribly convincing, since it's not terribly likely that the random tree actually has something to optimize. So use `thm` to **prove** that `fold-constants` always returns an expression that evaluates to the same value.

# %%
(defsnapshot todo-10)


(thm (implies (and (treep m) (envp e)) (equal (expr-eval-nan m e) (expr-eval-nan (fold-constants m) e))))
# Out:
# ACL2S !>>(DEFSNAPSHOT TODO-10)
#
# Summary
# Form:  ( DEFLABEL TODO-10 ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  TODO-10
# ACL2S !>>(THM (IMPLIES (AND (TREEP M) (ENVP E))
#                        (EQUAL (EXPR-EVAL-NAN M E)
#                               (EXPR-EVAL-NAN (FOLD-CONSTANTS M) E))))
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# Name the formula above *1.
#
# Perhaps we can prove *1 by induction.  Six induction schemes are suggested
# by this conjecture.  Subsumption reduces that number to four.  These
# merge into two derived induction schemes.  However, one of these is
# flawed and so we are left with one viable candidate.
#
# We will induct according to a scheme suggested by (FOLD-CONSTANTS M),
# but modified to accommodate (EXPR-EVAL-NAN M E).  These suggestions
# were produced using the :induction rules EXPR-EVAL-NAN,
# EXPR-EVAL-NAN-INDUCTION-SCHEME, FOLD-CONSTANTS,
# FOLD-CONSTANTS-INDUCTION-SCHEME and TREEP.  If we let (:P E M) denote
# *1 above then the induction scheme we'll use is
# (AND (IMPLIES (NOT (TREEP M)) (:P E M))
#      (IMPLIES (AND (TREEP M)
#                    (NOT (RATIONALP M))
#                    (NOT (SYMBOLP M))
#                    (NOT (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN))
#                    (NOT (OR (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN)
#                             (AND (EQUAL (FOLD-CONSTANTS (CADDR M)) 'NAN)
#                                  (NOT (EQUAL (CAR M) 'UMINUS)))))
#                    (NOT (EQUAL (CAR M) 'UMINUS))
#                    (NOT (AND (EQUAL (CAR M) 'UMINUS)
#                              (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))))
#                    (RATIONALP (FOLD-CONSTANTS (CADR M)))
#                    (NOT (OR (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))
#                             (NOT (RATIONALP (FOLD-CONSTANTS (CADDR M))))))
#                    (RATIONALP (FOLD-CONSTANTS (CADDR M)))
#                    (NOT (EQUAL (CAR M) 'PLUS))
#                    (NOT (EQUAL (CAR M) 'MINUS))
#                    (NOT (EQUAL (CAR M) 'TIMES))
#                    (NOT (EQUAL (CAR M) 'DIVIDE))
#                    (:P E (CADR M))
#                    (:P E (CADDR M)))
#               (:P E M))
#      (IMPLIES (AND (TREEP M)
#                    (NOT (RATIONALP M))
#                    (NOT (SYMBOLP M))
#                    (NOT (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN))
#                    (NOT (OR (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN)
#                             (AND (EQUAL (FOLD-CONSTANTS (CADDR M)) 'NAN)
#                                  (NOT (EQUAL (CAR M) 'UMINUS)))))
#                    (NOT (AND (EQUAL (CAR M) 'UMINUS)
#                              (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))))
#                    (RATIONALP (FOLD-CONSTANTS (CADR M)))
#                    (NOT (OR (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))
#                             (NOT (RATIONALP (FOLD-CONSTANTS (CADDR M))))))
#                    (RATIONALP (FOLD-CONSTANTS (CADDR M)))
#                    (EQUAL (CAR M) 'DIVIDE)
#                    (NOT (EQUAL (FOLD-CONSTANTS (CADDR M)) 0))
#                    (:P E (CADR M))
#                    (:P E (CADDR M)))
#               (:P E M))
#      (IMPLIES (AND (TREEP M)
#                    (NOT (RATIONALP M))
#                    (NOT (SYMBOLP M))
#                    (NOT (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN))
#                    (NOT (OR (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN)
#                             (AND (EQUAL (FOLD-CONSTANTS (CADDR M)) 'NAN)
#                                  (NOT (EQUAL (CAR M) 'UMINUS)))))
#                    (NOT (AND (EQUAL (CAR M) 'UMINUS)
#                              (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))))
#                    (RATIONALP (FOLD-CONSTANTS (CADR M)))
#                    (NOT (OR (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))
#                             (NOT (RATIONALP (FOLD-CONSTANTS (CADDR M))))))
#                    (RATIONALP (FOLD-CONSTANTS (CADDR M)))
#                    (EQUAL (CAR M) 'DIVIDE)
#                    (EQUAL (FOLD-CONSTANTS (CADDR M)) 0)
#                    (:P E (CADR M))
#                    (:P E (CADDR M)))
#               (:P E M))
#      (IMPLIES (AND (TREEP M)
#                    (NOT (RATIONALP M))
#                    (NOT (SYMBOLP M))
#                    (NOT (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN))
#                    (NOT (OR (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN)
#                             (AND (EQUAL (FOLD-CONSTANTS (CADDR M)) 'NAN)
#                                  (NOT (EQUAL (CAR M) 'UMINUS)))))
#                    (NOT (AND (EQUAL (CAR M) 'UMINUS)
#                              (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))))
#                    (RATIONALP (FOLD-CONSTANTS (CADR M)))
#                    (NOT (OR (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))
#                             (NOT (RATIONALP (FOLD-CONSTANTS (CADDR M))))))
#                    (RATIONALP (FOLD-CONSTANTS (CADDR M)))
#                    (EQUAL (CAR M) 'TIMES)
#                    (:P E (CADR M))
#                    (:P E (CADDR M)))
#               (:P E M))
#      (IMPLIES (AND (TREEP M)
#                    (NOT (RATIONALP M))
#                    (NOT (SYMBOLP M))
#                    (NOT (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN))
#                    (NOT (OR (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN)
#                             (AND (EQUAL (FOLD-CONSTANTS (CADDR M)) 'NAN)
#                                  (NOT (EQUAL (CAR M) 'UMINUS)))))
#                    (NOT (AND (EQUAL (CAR M) 'UMINUS)
#                              (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))))
#                    (RATIONALP (FOLD-CONSTANTS (CADR M)))
#                    (NOT (OR (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))
#                             (NOT (RATIONALP (FOLD-CONSTANTS (CADDR M))))))
#                    (RATIONALP (FOLD-CONSTANTS (CADDR M)))
#                    (EQUAL (CAR M) 'MINUS)
#                    (:P E (CADR M))
#                    (:P E (CADDR M)))
#               (:P E M))
#      (IMPLIES (AND (TREEP M)
#                    (NOT (RATIONALP M))
#                    (NOT (SYMBOLP M))
#                    (NOT (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN))
#                    (NOT (OR (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN)
#                             (AND (EQUAL (FOLD-CONSTANTS (CADDR M)) 'NAN)
#                                  (NOT (EQUAL (CAR M) 'UMINUS)))))
#                    (NOT (AND (EQUAL (CAR M) 'UMINUS)
#                              (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))))
#                    (RATIONALP (FOLD-CONSTANTS (CADR M)))
#                    (NOT (OR (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))
#                             (NOT (RATIONALP (FOLD-CONSTANTS (CADDR M))))))
#                    (RATIONALP (FOLD-CONSTANTS (CADDR M)))
#                    (EQUAL (CAR M) 'PLUS)
#                    (:P E (CADR M))
#                    (:P E (CADDR M)))
#               (:P E M))
#      (IMPLIES (AND (TREEP M)
#                    (NOT (RATIONALP M))
#                    (NOT (SYMBOLP M))
#                    (NOT (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN))
#                    (NOT (OR (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN)
#                             (AND (EQUAL (FOLD-CONSTANTS (CADDR M)) 'NAN)
#                                  (NOT (EQUAL (CAR M) 'UMINUS)))))
#                    (NOT (EQUAL (CAR M) 'UMINUS))
#                    (NOT (AND (EQUAL (CAR M) 'UMINUS)
#                              (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))))
#                    (RATIONALP (FOLD-CONSTANTS (CADR M)))
#                    (NOT (OR (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))
#                             (NOT (RATIONALP (FOLD-CONSTANTS (CADDR M))))))
#                    (NOT (RATIONALP (FOLD-CONSTANTS (CADDR M))))
#                    (:P E (CADDR M))
#                    (:P E (CADR M)))
#               (:P E M))
#      (IMPLIES (AND (TREEP M)
#                    (NOT (RATIONALP M))
#                    (NOT (SYMBOLP M))
#                    (NOT (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN))
#                    (NOT (OR (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN)
#                             (AND (EQUAL (FOLD-CONSTANTS (CADDR M)) 'NAN)
#                                  (NOT (EQUAL (CAR M) 'UMINUS)))))
#                    (NOT (EQUAL (CAR M) 'UMINUS))
#                    (NOT (AND (EQUAL (CAR M) 'UMINUS)
#                              (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))))
#                    (RATIONALP (FOLD-CONSTANTS (CADR M)))
#                    (OR (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))
#                        (NOT (RATIONALP (FOLD-CONSTANTS (CADDR M)))))
#                    (:P E (CADR M))
#                    (:P E (CADDR M)))
#               (:P E M))
#      (IMPLIES (AND (TREEP M)
#                    (NOT (RATIONALP M))
#                    (NOT (SYMBOLP M))
#                    (NOT (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN))
#                    (NOT (OR (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN)
#                             (AND (EQUAL (FOLD-CONSTANTS (CADDR M)) 'NAN)
#                                  (NOT (EQUAL (CAR M) 'UMINUS)))))
#                    (NOT (EQUAL (CAR M) 'UMINUS))
#                    (NOT (AND (EQUAL (CAR M) 'UMINUS)
#                              (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))))
#                    (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))
#                    (NOT (OR (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))
#                             (NOT (RATIONALP (FOLD-CONSTANTS (CADDR M))))))
#                    (:P E (CADR M))
#                    (:P E (CADDR M)))
#               (:P E M))
#      (IMPLIES (AND (TREEP M)
#                    (NOT (RATIONALP M))
#                    (NOT (SYMBOLP M))
#                    (NOT (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN))
#                    (NOT (OR (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN)
#                             (AND (EQUAL (FOLD-CONSTANTS (CADDR M)) 'NAN)
#                                  (NOT (EQUAL (CAR M) 'UMINUS)))))
#                    (NOT (EQUAL (CAR M) 'UMINUS))
#                    (NOT (AND (EQUAL (CAR M) 'UMINUS)
#                              (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))))
#                    (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))
#                    (OR (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))
#                        (NOT (RATIONALP (FOLD-CONSTANTS (CADDR M)))))
#                    (:P E (CADR M))
#                    (:P E (CADDR M)))
#               (:P E M))
#      (IMPLIES (AND (TREEP M)
#                    (NOT (RATIONALP M))
#                    (NOT (SYMBOLP M))
#                    (NOT (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN))
#                    (NOT (OR (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN)
#                             (AND (EQUAL (FOLD-CONSTANTS (CADDR M)) 'NAN)
#                                  (NOT (EQUAL (CAR M) 'UMINUS)))))
#                    (NOT (EQUAL (CAR M) 'UMINUS))
#                    (AND (EQUAL (CAR M) 'UMINUS)
#                         (NOT (RATIONALP (FOLD-CONSTANTS (CADR M)))))
#                    (:P E (CADR M))
#                    (:P E (CADDR M)))
#               (:P E M))
#      (IMPLIES (AND (TREEP M)
#                    (NOT (RATIONALP M))
#                    (NOT (SYMBOLP M))
#                    (NOT (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN))
#                    (NOT (OR (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN)
#                             (AND (EQUAL (FOLD-CONSTANTS (CADDR M)) 'NAN)
#                                  (NOT (EQUAL (CAR M) 'UMINUS)))))
#                    (EQUAL (CAR M) 'UMINUS)
#                    (NOT (AND (EQUAL (CAR M) 'UMINUS)
#                              (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))))
#                    (:P E (CADDR M))
#                    (:P E (CADR M)))
#               (:P E M))
#      (IMPLIES (AND (TREEP M)
#                    (NOT (RATIONALP M))
#                    (NOT (SYMBOLP M))
#                    (NOT (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN))
#                    (NOT (OR (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN)
#                             (AND (EQUAL (FOLD-CONSTANTS (CADDR M)) 'NAN)
#                                  (NOT (EQUAL (CAR M) 'UMINUS)))))
#                    (EQUAL (CAR M) 'UMINUS)
#                    (AND (EQUAL (CAR M) 'UMINUS)
#                         (NOT (RATIONALP (FOLD-CONSTANTS (CADR M)))))
#                    (:P E (CADDR M))
#                    (:P E (CADR M)))
#               (:P E M))
#      (IMPLIES (AND (TREEP M)
#                    (NOT (RATIONALP M))
#                    (NOT (SYMBOLP M))
#                    (NOT (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN))
#                    (OR (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN)
#                        (AND (EQUAL (FOLD-CONSTANTS (CADDR M)) 'NAN)
#                             (NOT (EQUAL (CAR M) 'UMINUS))))
#                    (:P E (CADR M))
#                    (:P E (CADDR M)))
#               (:P E M))
#      (IMPLIES (AND (TREEP M)
#                    (NOT (RATIONALP M))
#                    (NOT (SYMBOLP M))
#                    (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN)
#                    (NOT (OR (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN)
#                             (AND (EQUAL (FOLD-CONSTANTS (CADDR M)) 'NAN)
#                                  (NOT (EQUAL (CAR M) 'UMINUS)))))
#                    (NOT (EQUAL (CAR M) 'UMINUS))
#                    (NOT (AND (EQUAL (CAR M) 'UMINUS)
#                              (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))))
#                    (RATIONALP (FOLD-CONSTANTS (CADR M)))
#                    (NOT (OR (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))
#                             (NOT (RATIONALP (FOLD-CONSTANTS (CADDR M))))))
#                    (RATIONALP (FOLD-CONSTANTS (CADDR M)))
#                    (NOT (EQUAL (CAR M) 'PLUS))
#                    (NOT (EQUAL (CAR M) 'MINUS))
#                    (NOT (EQUAL (CAR M) 'TIMES))
#                    (NOT (EQUAL (CAR M) 'DIVIDE))
#                    (:P E (CADR M))
#                    (:P E (CADDR M)))
#               (:P E M))
#      (IMPLIES (AND (TREEP M)
#                    (NOT (RATIONALP M))
#                    (NOT (SYMBOLP M))
#                    (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN)
#                    (NOT (OR (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN)
#                             (AND (EQUAL (FOLD-CONSTANTS (CADDR M)) 'NAN)
#                                  (NOT (EQUAL (CAR M) 'UMINUS)))))
#                    (NOT (EQUAL (CAR M) 'UMINUS))
#                    (NOT (AND (EQUAL (CAR M) 'UMINUS)
#                              (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))))
#                    (RATIONALP (FOLD-CONSTANTS (CADR M)))
#                    (NOT (OR (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))
#                             (NOT (RATIONALP (FOLD-CONSTANTS (CADDR M))))))
#                    (RATIONALP (FOLD-CONSTANTS (CADDR M)))
#                    (NOT (EQUAL (CAR M) 'PLUS))
#                    (NOT (EQUAL (CAR M) 'MINUS))
#                    (NOT (EQUAL (CAR M) 'TIMES))
#                    (EQUAL (CAR M) 'DIVIDE)
#                    (NOT (EQUAL (FOLD-CONSTANTS (CADDR M)) 0))
#                    (:P E (CADR M))
#                    (:P E (CADDR M)))
#               (:P E M))
#      (IMPLIES (AND (TREEP M)
#                    (NOT (RATIONALP M))
#                    (NOT (SYMBOLP M))
#                    (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN)
#                    (NOT (OR (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN)
#                             (AND (EQUAL (FOLD-CONSTANTS (CADDR M)) 'NAN)
#                                  (NOT (EQUAL (CAR M) 'UMINUS)))))
#                    (NOT (EQUAL (CAR M) 'UMINUS))
#                    (NOT (AND (EQUAL (CAR M) 'UMINUS)
#                              (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))))
#                    (RATIONALP (FOLD-CONSTANTS (CADR M)))
#                    (NOT (OR (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))
#                             (NOT (RATIONALP (FOLD-CONSTANTS (CADDR M))))))
#                    (RATIONALP (FOLD-CONSTANTS (CADDR M)))
#                    (NOT (EQUAL (CAR M) 'PLUS))
#                    (NOT (EQUAL (CAR M) 'MINUS))
#                    (NOT (EQUAL (CAR M) 'TIMES))
#                    (EQUAL (CAR M) 'DIVIDE)
#                    (EQUAL (FOLD-CONSTANTS (CADDR M)) 0)
#                    (:P E (CADR M))
#                    (:P E (CADDR M)))
#               (:P E M))
#      (IMPLIES (AND (TREEP M)
#                    (NOT (RATIONALP M))
#                    (NOT (SYMBOLP M))
#                    (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN)
#                    (NOT (OR (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN)
#                             (AND (EQUAL (FOLD-CONSTANTS (CADDR M)) 'NAN)
#                                  (NOT (EQUAL (CAR M) 'UMINUS)))))
#                    (NOT (EQUAL (CAR M) 'UMINUS))
#                    (NOT (AND (EQUAL (CAR M) 'UMINUS)
#                              (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))))
#                    (RATIONALP (FOLD-CONSTANTS (CADR M)))
#                    (NOT (OR (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))
#                             (NOT (RATIONALP (FOLD-CONSTANTS (CADDR M))))))
#                    (RATIONALP (FOLD-CONSTANTS (CADDR M)))
#                    (NOT (EQUAL (CAR M) 'PLUS))
#                    (NOT (EQUAL (CAR M) 'MINUS))
#                    (EQUAL (CAR M) 'TIMES)
#                    (:P E (CADR M))
#                    (:P E (CADDR M)))
#               (:P E M))
#      (IMPLIES (AND (TREEP M)
#                    (NOT (RATIONALP M))
#                    (NOT (SYMBOLP M))
#                    (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN)
#                    (NOT (OR (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN)
#                             (AND (EQUAL (FOLD-CONSTANTS (CADDR M)) 'NAN)
#                                  (NOT (EQUAL (CAR M) 'UMINUS)))))
#                    (NOT (EQUAL (CAR M) 'UMINUS))
#                    (NOT (AND (EQUAL (CAR M) 'UMINUS)
#                              (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))))
#                    (RATIONALP (FOLD-CONSTANTS (CADR M)))
#                    (NOT (OR (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))
#                             (NOT (RATIONALP (FOLD-CONSTANTS (CADDR M))))))
#                    (RATIONALP (FOLD-CONSTANTS (CADDR M)))
#                    (NOT (EQUAL (CAR M) 'PLUS))
#                    (EQUAL (CAR M) 'MINUS)
#                    (:P E (CADR M))
#                    (:P E (CADDR M)))
#               (:P E M))
#      (IMPLIES (AND (TREEP M)
#                    (NOT (RATIONALP M))
#                    (NOT (SYMBOLP M))
#                    (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN)
#                    (NOT (OR (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN)
#                             (AND (EQUAL (FOLD-CONSTANTS (CADDR M)) 'NAN)
#                                  (NOT (EQUAL (CAR M) 'UMINUS)))))
#                    (NOT (EQUAL (CAR M) 'UMINUS))
#                    (NOT (AND (EQUAL (CAR M) 'UMINUS)
#                              (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))))
#                    (RATIONALP (FOLD-CONSTANTS (CADR M)))
#                    (NOT (OR (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))
#                             (NOT (RATIONALP (FOLD-CONSTANTS (CADDR M))))))
#                    (RATIONALP (FOLD-CONSTANTS (CADDR M)))
#                    (EQUAL (CAR M) 'PLUS)
#                    (:P E (CADR M))
#                    (:P E (CADDR M)))
#               (:P E M))
#      (IMPLIES (AND (TREEP M)
#                    (NOT (RATIONALP M))
#                    (NOT (SYMBOLP M))
#                    (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN)
#                    (NOT (OR (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN)
#                             (AND (EQUAL (FOLD-CONSTANTS (CADDR M)) 'NAN)
#                                  (NOT (EQUAL (CAR M) 'UMINUS)))))
#                    (NOT (EQUAL (CAR M) 'UMINUS))
#                    (NOT (AND (EQUAL (CAR M) 'UMINUS)
#                              (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))))
#                    (RATIONALP (FOLD-CONSTANTS (CADR M)))
#                    (NOT (OR (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))
#                             (NOT (RATIONALP (FOLD-CONSTANTS (CADDR M))))))
#                    (NOT (RATIONALP (FOLD-CONSTANTS (CADDR M))))
#                    (:P E (CADDR M))
#                    (:P E (CADR M)))
#               (:P E M))
#      (IMPLIES (AND (TREEP M)
#                    (NOT (RATIONALP M))
#                    (NOT (SYMBOLP M))
#                    (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN)
#                    (NOT (OR (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN)
#                             (AND (EQUAL (FOLD-CONSTANTS (CADDR M)) 'NAN)
#                                  (NOT (EQUAL (CAR M) 'UMINUS)))))
#                    (NOT (EQUAL (CAR M) 'UMINUS))
#                    (NOT (AND (EQUAL (CAR M) 'UMINUS)
#                              (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))))
#                    (RATIONALP (FOLD-CONSTANTS (CADR M)))
#                    (OR (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))
#                        (NOT (RATIONALP (FOLD-CONSTANTS (CADDR M)))))
#                    (:P E (CADR M))
#                    (:P E (CADDR M)))
#               (:P E M))
#      (IMPLIES (AND (TREEP M)
#                    (NOT (RATIONALP M))
#                    (NOT (SYMBOLP M))
#                    (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN)
#                    (NOT (OR (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN)
#                             (AND (EQUAL (FOLD-CONSTANTS (CADDR M)) 'NAN)
#                                  (NOT (EQUAL (CAR M) 'UMINUS)))))
#                    (NOT (EQUAL (CAR M) 'UMINUS))
#                    (NOT (AND (EQUAL (CAR M) 'UMINUS)
#                              (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))))
#                    (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))
#                    (NOT (OR (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))
#                             (NOT (RATIONALP (FOLD-CONSTANTS (CADDR M))))))
#                    (:P E (CADR M))
#                    (:P E (CADDR M)))
#               (:P E M))
#      (IMPLIES (AND (TREEP M)
#                    (NOT (RATIONALP M))
#                    (NOT (SYMBOLP M))
#                    (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN)
#                    (NOT (OR (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN)
#                             (AND (EQUAL (FOLD-CONSTANTS (CADDR M)) 'NAN)
#                                  (NOT (EQUAL (CAR M) 'UMINUS)))))
#                    (NOT (EQUAL (CAR M) 'UMINUS))
#                    (NOT (AND (EQUAL (CAR M) 'UMINUS)
#                              (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))))
#                    (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))
#                    (OR (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))
#                        (NOT (RATIONALP (FOLD-CONSTANTS (CADDR M)))))
#                    (:P E (CADR M))
#                    (:P E (CADDR M)))
#               (:P E M))
#      (IMPLIES (AND (TREEP M)
#                    (NOT (RATIONALP M))
#                    (NOT (SYMBOLP M))
#                    (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN)
#                    (NOT (OR (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN)
#                             (AND (EQUAL (FOLD-CONSTANTS (CADDR M)) 'NAN)
#                                  (NOT (EQUAL (CAR M) 'UMINUS)))))
#                    (NOT (EQUAL (CAR M) 'UMINUS))
#                    (AND (EQUAL (CAR M) 'UMINUS)
#                         (NOT (RATIONALP (FOLD-CONSTANTS (CADR M)))))
#                    (:P E (CADR M)))
#               (:P E M))
#      (IMPLIES (AND (TREEP M)
#                    (NOT (RATIONALP M))
#                    (NOT (SYMBOLP M))
#                    (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN)
#                    (NOT (OR (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN)
#                             (AND (EQUAL (FOLD-CONSTANTS (CADDR M)) 'NAN)
#                                  (NOT (EQUAL (CAR M) 'UMINUS)))))
#                    (EQUAL (CAR M) 'UMINUS)
#                    (NOT (AND (EQUAL (CAR M) 'UMINUS)
#                              (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))))
#                    (:P E (CADR M)))
#               (:P E M))
#      (IMPLIES (AND (TREEP M)
#                    (NOT (RATIONALP M))
#                    (NOT (SYMBOLP M))
#                    (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN)
#                    (NOT (OR (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN)
#                             (AND (EQUAL (FOLD-CONSTANTS (CADDR M)) 'NAN)
#                                  (NOT (EQUAL (CAR M) 'UMINUS)))))
#                    (EQUAL (CAR M) 'UMINUS)
#                    (AND (EQUAL (CAR M) 'UMINUS)
#                         (NOT (RATIONALP (FOLD-CONSTANTS (CADR M)))))
#                    (:P E (CADR M)))
#               (:P E M))
#      (IMPLIES (AND (TREEP M)
#                    (NOT (RATIONALP M))
#                    (NOT (SYMBOLP M))
#                    (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN)
#                    (OR (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN)
#                        (AND (EQUAL (FOLD-CONSTANTS (CADDR M)) 'NAN)
#                             (NOT (EQUAL (CAR M) 'UMINUS))))
#                    (:P E (CADR M)))
#               (:P E M))
#      (IMPLIES (AND (TREEP M)
#                    (NOT (RATIONALP M))
#                    (SYMBOLP M))
#               (:P E M))
#      (IMPLIES (AND (TREEP M) (RATIONALP M))
#               (:P E M))).
# This induction is justified by the same argument used to admit
# FOLD-CONSTANTS.  When applied to the goal at hand the above induction
# scheme produces 31 nontautological subgoals.  However, to achieve this
# relatively small number of cases we had to fold *1 into a single IF-
# expression.  Had we left it as a set of clauses this induction would
# have produced approximately 231 cases!  Chances are that this proof
# attempt is about to blow up in your face (and all over our memory boards).
#
# Subgoal *1/31
# (IMPLIES (NOT (TREEP M))
#          (OR (NOT (TREEP M))
#              (NOT (ENVP E))
#              (EQUAL (EXPR-EVAL-NAN M E)
#                     (EXPR-EVAL-NAN (FOLD-CONSTANTS M) E)))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But we reduce the conjecture to T, by case analysis.
#
# Subgoal *1/30
# (IMPLIES (AND (TREEP M)
#               (NOT (RATIONALP M))
#               (NOT (SYMBOLP M))
#               (NOT (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN))
#               (NOT (OR (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN)
#                        (AND (EQUAL (FOLD-CONSTANTS (CADDR M)) 'NAN)
#                             (NOT (EQUAL (CAR M) 'UMINUS)))))
#               (NOT (EQUAL (CAR M) 'UMINUS))
#               (NOT (AND (EQUAL (CAR M) 'UMINUS)
#                         (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))))
#               (RATIONALP (FOLD-CONSTANTS (CADR M)))
#               (NOT (OR (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))
#                        (NOT (RATIONALP (FOLD-CONSTANTS (CADDR M))))))
#               (RATIONALP (FOLD-CONSTANTS (CADDR M)))
#               (NOT (EQUAL (CAR M) 'PLUS))
#               (NOT (EQUAL (CAR M) 'MINUS))
#               (NOT (EQUAL (CAR M) 'TIMES))
#               (NOT (EQUAL (CAR M) 'DIVIDE))
#               (OR (NOT (TREEP (CADR M)))
#                   (NOT (ENVP E))
#                   (EQUAL (EXPR-EVAL-NAN (CADR M) E)
#                          (EXPR-EVAL-NAN (FOLD-CONSTANTS (CADR M))
#                                         E)))
#               (OR (NOT (TREEP (CADDR M)))
#                   (NOT (ENVP E))
#                   (EQUAL (EXPR-EVAL-NAN (CADDR M) E)
#                          (EXPR-EVAL-NAN (FOLD-CONSTANTS (CADDR M))
#                                         E))))
#          (OR (NOT (TREEP M))
#              (NOT (ENVP E))
#              (EQUAL (EXPR-EVAL-NAN M E)
#                     (EXPR-EVAL-NAN (FOLD-CONSTANTS M) E)))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# By case analysis we reduce the conjecture to
#
# Subgoal *1/30'
# (IMPLIES (AND (TREEP M)
#               (NOT (RATIONALP M))
#               (NOT (SYMBOLP M))
#               (NOT (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN))
#               (NOT (OR (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN)
#                        (AND (EQUAL (FOLD-CONSTANTS (CADDR M)) 'NAN)
#                             (NOT (EQUAL (CAR M) 'UMINUS)))))
#               (NOT (EQUAL (CAR M) 'UMINUS))
#               (NOT (AND (EQUAL (CAR M) 'UMINUS)
#                         (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))))
#               (RATIONALP (FOLD-CONSTANTS (CADR M)))
#               (NOT (OR (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))
#                        (NOT (RATIONALP (FOLD-CONSTANTS (CADDR M))))))
#               (RATIONALP (FOLD-CONSTANTS (CADDR M)))
#               (NOT (EQUAL (CAR M) 'PLUS))
#               (NOT (EQUAL (CAR M) 'MINUS))
#               (NOT (EQUAL (CAR M) 'TIMES))
#               (NOT (EQUAL (CAR M) 'DIVIDE))
#               (OR (NOT (TREEP (CADR M)))
#                   (NOT (ENVP E))
#                   (EQUAL (EXPR-EVAL-NAN (CADR M) E)
#                          (EXPR-EVAL-NAN (FOLD-CONSTANTS (CADR M))
#                                         E)))
#               (OR (NOT (TREEP (CADDR M)))
#                   (NOT (ENVP E))
#                   (EQUAL (EXPR-EVAL-NAN (CADDR M) E)
#                          (EXPR-EVAL-NAN (FOLD-CONSTANTS (CADDR M))
#                                         E)))
#               (ENVP E))
#          (EQUAL (EXPR-EVAL-NAN M E)
#                 (EXPR-EVAL-NAN (FOLD-CONSTANTS M) E))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But simplification reduces this to T, using the :definition TREEP.
#
# Subgoal *1/29
# (IMPLIES (AND (TREEP M)
#               (NOT (RATIONALP M))
#               (NOT (SYMBOLP M))
#               (NOT (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN))
#               (NOT (OR (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN)
#                        (AND (EQUAL (FOLD-CONSTANTS (CADDR M)) 'NAN)
#                             (NOT (EQUAL (CAR M) 'UMINUS)))))
#               (NOT (AND (EQUAL (CAR M) 'UMINUS)
#                         (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))))
#               (RATIONALP (FOLD-CONSTANTS (CADR M)))
#               (NOT (OR (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))
#                        (NOT (RATIONALP (FOLD-CONSTANTS (CADDR M))))))
#               (RATIONALP (FOLD-CONSTANTS (CADDR M)))
#               (EQUAL (CAR M) 'DIVIDE)
#               (NOT (EQUAL (FOLD-CONSTANTS (CADDR M)) 0))
#               (OR (NOT (TREEP (CADR M)))
#                   (NOT (ENVP E))
#                   (EQUAL (EXPR-EVAL-NAN (CADR M) E)
#                          (EXPR-EVAL-NAN (FOLD-CONSTANTS (CADR M))
#                                         E)))
#               (OR (NOT (TREEP (CADDR M)))
#                   (NOT (ENVP E))
#                   (EQUAL (EXPR-EVAL-NAN (CADDR M) E)
#                          (EXPR-EVAL-NAN (FOLD-CONSTANTS (CADDR M))
#                                         E))))
#          (OR (NOT (TREEP M))
#              (NOT (ENVP E))
#              (EQUAL (EXPR-EVAL-NAN M E)
#                     (EXPR-EVAL-NAN (FOLD-CONSTANTS M) E)))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# By case analysis we reduce the conjecture to
#
# Subgoal *1/29'
# (IMPLIES (AND (TREEP M)
#               (NOT (RATIONALP M))
#               (NOT (SYMBOLP M))
#               (NOT (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN))
#               (NOT (OR (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN)
#                        (AND (EQUAL (FOLD-CONSTANTS (CADDR M)) 'NAN)
#                             (NOT (EQUAL (CAR M) 'UMINUS)))))
#               (NOT (AND (EQUAL (CAR M) 'UMINUS)
#                         (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))))
#               (RATIONALP (FOLD-CONSTANTS (CADR M)))
#               (NOT (OR (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))
#                        (NOT (RATIONALP (FOLD-CONSTANTS (CADDR M))))))
#               (RATIONALP (FOLD-CONSTANTS (CADDR M)))
#               (EQUAL (CAR M) 'DIVIDE)
#               (NOT (EQUAL (FOLD-CONSTANTS (CADDR M)) 0))
#               (OR (NOT (TREEP (CADR M)))
#                   (NOT (ENVP E))
#                   (EQUAL (EXPR-EVAL-NAN (CADR M) E)
#                          (EXPR-EVAL-NAN (FOLD-CONSTANTS (CADR M))
#                                         E)))
#               (OR (NOT (TREEP (CADDR M)))
#                   (NOT (ENVP E))
#                   (EQUAL (EXPR-EVAL-NAN (CADDR M) E)
#                          (EXPR-EVAL-NAN (FOLD-CONSTANTS (CADDR M))
#                                         E)))
#               (ENVP E))
#          (EQUAL (EXPR-EVAL-NAN M E)
#                 (EXPR-EVAL-NAN (FOLD-CONSTANTS M) E))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But simplification reduces this to T, using the :compound-recognizer
# rule ENVP-IMPLIES-TLP, the :definitions EXPR-EVAL-NAN-DEFINITION-RULE,
# FOLD-CONSTANTS-DEFINITION-RULE and TREEP, the :executable-counterparts
# of EQUAL and NOT, primitive type reasoning, the :rewrite rule DEF=>TREE
# and the :type-prescription rules FOLD-CONSTANTS-CONTRACT-TP and TREEP.
#
# Subgoal *1/28
# (IMPLIES (AND (TREEP M)
#               (NOT (RATIONALP M))
#               (NOT (SYMBOLP M))
#               (NOT (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN))
#               (NOT (OR (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN)
#                        (AND (EQUAL (FOLD-CONSTANTS (CADDR M)) 'NAN)
#                             (NOT (EQUAL (CAR M) 'UMINUS)))))
#               (NOT (AND (EQUAL (CAR M) 'UMINUS)
#                         (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))))
#               (RATIONALP (FOLD-CONSTANTS (CADR M)))
#               (NOT (OR (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))
#                        (NOT (RATIONALP (FOLD-CONSTANTS (CADDR M))))))
#               (RATIONALP (FOLD-CONSTANTS (CADDR M)))
#               (EQUAL (CAR M) 'DIVIDE)
#               (EQUAL (FOLD-CONSTANTS (CADDR M)) 0)
#               (OR (NOT (TREEP (CADR M)))
#                   (NOT (ENVP E))
#                   (EQUAL (EXPR-EVAL-NAN (CADR M) E)
#                          (EXPR-EVAL-NAN (FOLD-CONSTANTS (CADR M))
#                                         E)))
#               (OR (NOT (TREEP (CADDR M)))
#                   (NOT (ENVP E))
#                   (EQUAL (EXPR-EVAL-NAN (CADDR M) E)
#                          (EXPR-EVAL-NAN (FOLD-CONSTANTS (CADDR M))
#                                         E))))
#          (OR (NOT (TREEP M))
#              (NOT (ENVP E))
#              (EQUAL (EXPR-EVAL-NAN M E)
#                     (EXPR-EVAL-NAN (FOLD-CONSTANTS M) E)))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# By case analysis we reduce the conjecture to
#
# Subgoal *1/28'
# (IMPLIES (AND (TREEP M)
#               (NOT (RATIONALP M))
#               (NOT (SYMBOLP M))
#               (NOT (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN))
#               (NOT (OR (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN)
#                        (AND (EQUAL (FOLD-CONSTANTS (CADDR M)) 'NAN)
#                             (NOT (EQUAL (CAR M) 'UMINUS)))))
#               (NOT (AND (EQUAL (CAR M) 'UMINUS)
#                         (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))))
#               (RATIONALP (FOLD-CONSTANTS (CADR M)))
#               (NOT (OR (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))
#                        (NOT (RATIONALP (FOLD-CONSTANTS (CADDR M))))))
#               (RATIONALP (FOLD-CONSTANTS (CADDR M)))
#               (EQUAL (CAR M) 'DIVIDE)
#               (EQUAL (FOLD-CONSTANTS (CADDR M)) 0)
#               (OR (NOT (TREEP (CADR M)))
#                   (NOT (ENVP E))
#                   (EQUAL (EXPR-EVAL-NAN (CADR M) E)
#                          (EXPR-EVAL-NAN (FOLD-CONSTANTS (CADR M))
#                                         E)))
#               (OR (NOT (TREEP (CADDR M)))
#                   (NOT (ENVP E))
#                   (EQUAL (EXPR-EVAL-NAN (CADDR M) E)
#                          (EXPR-EVAL-NAN (FOLD-CONSTANTS (CADDR M))
#                                         E)))
#               (ENVP E))
#          (EQUAL (EXPR-EVAL-NAN M E)
#                 (EXPR-EVAL-NAN (FOLD-CONSTANTS M) E))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But simplification reduces this to T, using the :compound-recognizer
# rule ENVP-IMPLIES-TLP, the :definitions EXPR-EVAL-NAN-DEFINITION-RULE,
# FOLD-CONSTANTS-DEFINITION-RULE and TREEP, the :executable-counterparts
# of EQUAL, NOT, RATIONALP and TREEP, primitive type reasoning and the
# :type-prescription rules FOLD-CONSTANTS-CONTRACT-TP and TREEP.
#
# Subgoal *1/27
# (IMPLIES (AND (TREEP M)
#               (NOT (RATIONALP M))
#               (NOT (SYMBOLP M))
#               (NOT (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN))
#               (NOT (OR (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN)
#                        (AND (EQUAL (FOLD-CONSTANTS (CADDR M)) 'NAN)
#                             (NOT (EQUAL (CAR M) 'UMINUS)))))
#               (NOT (AND (EQUAL (CAR M) 'UMINUS)
#                         (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))))
#               (RATIONALP (FOLD-CONSTANTS (CADR M)))
#               (NOT (OR (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))
#                        (NOT (RATIONALP (FOLD-CONSTANTS (CADDR M))))))
#               (RATIONALP (FOLD-CONSTANTS (CADDR M)))
#               (EQUAL (CAR M) 'TIMES)
#               (OR (NOT (TREEP (CADR M)))
#                   (NOT (ENVP E))
#                   (EQUAL (EXPR-EVAL-NAN (CADR M) E)
#                          (EXPR-EVAL-NAN (FOLD-CONSTANTS (CADR M))
#                                         E)))
#               (OR (NOT (TREEP (CADDR M)))
#                   (NOT (ENVP E))
#                   (EQUAL (EXPR-EVAL-NAN (CADDR M) E)
#                          (EXPR-EVAL-NAN (FOLD-CONSTANTS (CADDR M))
#                                         E))))
#          (OR (NOT (TREEP M))
#              (NOT (ENVP E))
#              (EQUAL (EXPR-EVAL-NAN M E)
#                     (EXPR-EVAL-NAN (FOLD-CONSTANTS M) E)))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# By case analysis we reduce the conjecture to
#
# Subgoal *1/27'
# (IMPLIES (AND (TREEP M)
#               (NOT (RATIONALP M))
#               (NOT (SYMBOLP M))
#               (NOT (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN))
#               (NOT (OR (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN)
#                        (AND (EQUAL (FOLD-CONSTANTS (CADDR M)) 'NAN)
#                             (NOT (EQUAL (CAR M) 'UMINUS)))))
#               (NOT (AND (EQUAL (CAR M) 'UMINUS)
#                         (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))))
#               (RATIONALP (FOLD-CONSTANTS (CADR M)))
#               (NOT (OR (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))
#                        (NOT (RATIONALP (FOLD-CONSTANTS (CADDR M))))))
#               (RATIONALP (FOLD-CONSTANTS (CADDR M)))
#               (EQUAL (CAR M) 'TIMES)
#               (OR (NOT (TREEP (CADR M)))
#                   (NOT (ENVP E))
#                   (EQUAL (EXPR-EVAL-NAN (CADR M) E)
#                          (EXPR-EVAL-NAN (FOLD-CONSTANTS (CADR M))
#                                         E)))
#               (OR (NOT (TREEP (CADDR M)))
#                   (NOT (ENVP E))
#                   (EQUAL (EXPR-EVAL-NAN (CADDR M) E)
#                          (EXPR-EVAL-NAN (FOLD-CONSTANTS (CADDR M))
#                                         E)))
#               (ENVP E))
#          (EQUAL (EXPR-EVAL-NAN M E)
#                 (EXPR-EVAL-NAN (FOLD-CONSTANTS M) E))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But simplification reduces this to T, using the :compound-recognizer
# rule ENVP-IMPLIES-TLP, the :definitions EXPR-EVAL-NAN-DEFINITION-RULE,
# FOLD-CONSTANTS-DEFINITION-RULE and TREEP, the :executable-counterparts
# of EQUAL and NOT, primitive type reasoning, the :rewrite rule DEF=>TREE
# and the :type-prescription rules FOLD-CONSTANTS-CONTRACT-TP and TREEP.
#
# Subgoal *1/26
# (IMPLIES (AND (TREEP M)
#               (NOT (RATIONALP M))
#               (NOT (SYMBOLP M))
#               (NOT (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN))
#               (NOT (OR (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN)
#                        (AND (EQUAL (FOLD-CONSTANTS (CADDR M)) 'NAN)
#                             (NOT (EQUAL (CAR M) 'UMINUS)))))
#               (NOT (AND (EQUAL (CAR M) 'UMINUS)
#                         (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))))
#               (RATIONALP (FOLD-CONSTANTS (CADR M)))
#               (NOT (OR (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))
#                        (NOT (RATIONALP (FOLD-CONSTANTS (CADDR M))))))
#               (RATIONALP (FOLD-CONSTANTS (CADDR M)))
#               (EQUAL (CAR M) 'MINUS)
#               (OR (NOT (TREEP (CADR M)))
#                   (NOT (ENVP E))
#                   (EQUAL (EXPR-EVAL-NAN (CADR M) E)
#                          (EXPR-EVAL-NAN (FOLD-CONSTANTS (CADR M))
#                                         E)))
#               (OR (NOT (TREEP (CADDR M)))
#                   (NOT (ENVP E))
#                   (EQUAL (EXPR-EVAL-NAN (CADDR M) E)
#                          (EXPR-EVAL-NAN (FOLD-CONSTANTS (CADDR M))
#                                         E))))
#          (OR (NOT (TREEP M))
#              (NOT (ENVP E))
#              (EQUAL (EXPR-EVAL-NAN M E)
#                     (EXPR-EVAL-NAN (FOLD-CONSTANTS M) E)))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# By case analysis we reduce the conjecture to
#
# Subgoal *1/26'
# (IMPLIES (AND (TREEP M)
#               (NOT (RATIONALP M))
#               (NOT (SYMBOLP M))
#               (NOT (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN))
#               (NOT (OR (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN)
#                        (AND (EQUAL (FOLD-CONSTANTS (CADDR M)) 'NAN)
#                             (NOT (EQUAL (CAR M) 'UMINUS)))))
#               (NOT (AND (EQUAL (CAR M) 'UMINUS)
#                         (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))))
#               (RATIONALP (FOLD-CONSTANTS (CADR M)))
#               (NOT (OR (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))
#                        (NOT (RATIONALP (FOLD-CONSTANTS (CADDR M))))))
#               (RATIONALP (FOLD-CONSTANTS (CADDR M)))
#               (EQUAL (CAR M) 'MINUS)
#               (OR (NOT (TREEP (CADR M)))
#                   (NOT (ENVP E))
#                   (EQUAL (EXPR-EVAL-NAN (CADR M) E)
#                          (EXPR-EVAL-NAN (FOLD-CONSTANTS (CADR M))
#                                         E)))
#               (OR (NOT (TREEP (CADDR M)))
#                   (NOT (ENVP E))
#                   (EQUAL (EXPR-EVAL-NAN (CADDR M) E)
#                          (EXPR-EVAL-NAN (FOLD-CONSTANTS (CADDR M))
#                                         E)))
#               (ENVP E))
#          (EQUAL (EXPR-EVAL-NAN M E)
#                 (EXPR-EVAL-NAN (FOLD-CONSTANTS M) E))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But simplification reduces this to T, using the :compound-recognizer
# rule ENVP-IMPLIES-TLP, the :definitions EXPR-EVAL-NAN-DEFINITION-RULE,
# FOLD-CONSTANTS-DEFINITION-RULE and TREEP, the :executable-counterparts
# of EQUAL and NOT, primitive type reasoning, the :rewrite rule DEF=>TREE
# and the :type-prescription rules FOLD-CONSTANTS-CONTRACT-TP and TREEP.
#
# Subgoal *1/25
# (IMPLIES (AND (TREEP M)
#               (NOT (RATIONALP M))
#               (NOT (SYMBOLP M))
#               (NOT (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN))
#               (NOT (OR (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN)
#                        (AND (EQUAL (FOLD-CONSTANTS (CADDR M)) 'NAN)
#                             (NOT (EQUAL (CAR M) 'UMINUS)))))
#               (NOT (AND (EQUAL (CAR M) 'UMINUS)
#                         (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))))
#               (RATIONALP (FOLD-CONSTANTS (CADR M)))
#               (NOT (OR (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))
#                        (NOT (RATIONALP (FOLD-CONSTANTS (CADDR M))))))
#               (RATIONALP (FOLD-CONSTANTS (CADDR M)))
#               (EQUAL (CAR M) 'PLUS)
#               (OR (NOT (TREEP (CADR M)))
#                   (NOT (ENVP E))
#                   (EQUAL (EXPR-EVAL-NAN (CADR M) E)
#                          (EXPR-EVAL-NAN (FOLD-CONSTANTS (CADR M))
#                                         E)))
#               (OR (NOT (TREEP (CADDR M)))
#                   (NOT (ENVP E))
#                   (EQUAL (EXPR-EVAL-NAN (CADDR M) E)
#                          (EXPR-EVAL-NAN (FOLD-CONSTANTS (CADDR M))
#                                         E))))
#          (OR (NOT (TREEP M))
#              (NOT (ENVP E))
#              (EQUAL (EXPR-EVAL-NAN M E)
#                     (EXPR-EVAL-NAN (FOLD-CONSTANTS M) E)))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# By case analysis we reduce the conjecture to
#
# Subgoal *1/25'
# (IMPLIES (AND (TREEP M)
#               (NOT (RATIONALP M))
#               (NOT (SYMBOLP M))
#               (NOT (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN))
#               (NOT (OR (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN)
#                        (AND (EQUAL (FOLD-CONSTANTS (CADDR M)) 'NAN)
#                             (NOT (EQUAL (CAR M) 'UMINUS)))))
#               (NOT (AND (EQUAL (CAR M) 'UMINUS)
#                         (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))))
#               (RATIONALP (FOLD-CONSTANTS (CADR M)))
#               (NOT (OR (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))
#                        (NOT (RATIONALP (FOLD-CONSTANTS (CADDR M))))))
#               (RATIONALP (FOLD-CONSTANTS (CADDR M)))
#               (EQUAL (CAR M) 'PLUS)
#               (OR (NOT (TREEP (CADR M)))
#                   (NOT (ENVP E))
#                   (EQUAL (EXPR-EVAL-NAN (CADR M) E)
#                          (EXPR-EVAL-NAN (FOLD-CONSTANTS (CADR M))
#                                         E)))
#               (OR (NOT (TREEP (CADDR M)))
#                   (NOT (ENVP E))
#                   (EQUAL (EXPR-EVAL-NAN (CADDR M) E)
#                          (EXPR-EVAL-NAN (FOLD-CONSTANTS (CADDR M))
#                                         E)))
#               (ENVP E))
#          (EQUAL (EXPR-EVAL-NAN M E)
#                 (EXPR-EVAL-NAN (FOLD-CONSTANTS M) E))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But simplification reduces this to T, using the :compound-recognizer
# rule ENVP-IMPLIES-TLP, the :definitions EXPR-EVAL-NAN-DEFINITION-RULE,
# FOLD-CONSTANTS-DEFINITION-RULE and TREEP, the :executable-counterparts
# of EQUAL and NOT, primitive type reasoning, the :rewrite rule DEF=>TREE
# and the :type-prescription rules FOLD-CONSTANTS-CONTRACT-TP and TREEP.
#
# Subgoal *1/24
# (IMPLIES (AND (TREEP M)
#               (NOT (RATIONALP M))
# ...
#               (NOT (OR (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))
#                        (NOT (RATIONALP (FOLD-CONSTANTS (CADDR M))))))
#               (NOT (RATIONALP (FOLD-CONSTANTS (CADDR M))))
#               (OR (NOT (TREEP (CADDR M)))
#                   (NOT (ENVP E))
#                   (EQUAL (EXPR-EVAL-NAN (CADDR M) E)
#                          (EXPR-EVAL-NAN (FOLD-CONSTANTS (CADDR M))
#                                         E)))
#               (OR (NOT (TREEP (CADR M)))
#                   (NOT (ENVP E))
#                   (EQUAL (EXPR-EVAL-NAN (CADR M) E)
#                          (EXPR-EVAL-NAN (FOLD-CONSTANTS (CADR M))
#                                         E))))
#          (OR (NOT (TREEP M))
#              (NOT (ENVP E))
#              (EQUAL (EXPR-EVAL-NAN M E)
#                     (EXPR-EVAL-NAN (FOLD-CONSTANTS M) E)))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But we reduce the conjecture to T, by primitive type reasoning.
#
# Subgoal *1/9
# (IMPLIES (AND (TREEP M)
#               (NOT (RATIONALP M))
#               (NOT (SYMBOLP M))
#               (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN)
#               (NOT (OR (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN)
#                        (AND (EQUAL (FOLD-CONSTANTS (CADDR M)) 'NAN)
#                             (NOT (EQUAL (CAR M) 'UMINUS)))))
#               (NOT (EQUAL (CAR M) 'UMINUS))
#               (NOT (AND (EQUAL (CAR M) 'UMINUS)
#                         (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))))
#               (RATIONALP (FOLD-CONSTANTS (CADR M)))
#               (OR (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))
#                   (NOT (RATIONALP (FOLD-CONSTANTS (CADDR M)))))
#               (OR (NOT (TREEP (CADR M)))
#                   (NOT (ENVP E))
#                   (EQUAL (EXPR-EVAL-NAN (CADR M) E)
#                          (EXPR-EVAL-NAN (FOLD-CONSTANTS (CADR M))
#                                         E)))
#               (OR (NOT (TREEP (CADDR M)))
#                   (NOT (ENVP E))
#                   (EQUAL (EXPR-EVAL-NAN (CADDR M) E)
#                          (EXPR-EVAL-NAN (FOLD-CONSTANTS (CADDR M))
#                                         E))))
#          (OR (NOT (TREEP M))
#              (NOT (ENVP E))
#              (EQUAL (EXPR-EVAL-NAN M E)
#                     (EXPR-EVAL-NAN (FOLD-CONSTANTS M) E)))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But we reduce the conjecture to T, by primitive type reasoning.
#
# Subgoal *1/8
# (IMPLIES (AND (TREEP M)
#               (NOT (RATIONALP M))
#               (NOT (SYMBOLP M))
#               (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN)
#               (NOT (OR (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN)
#                        (AND (EQUAL (FOLD-CONSTANTS (CADDR M)) 'NAN)
#                             (NOT (EQUAL (CAR M) 'UMINUS)))))
#               (NOT (EQUAL (CAR M) 'UMINUS))
#               (NOT (AND (EQUAL (CAR M) 'UMINUS)
#                         (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))))
#               (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))
#               (NOT (OR (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))
#                        (NOT (RATIONALP (FOLD-CONSTANTS (CADDR M))))))
#               (OR (NOT (TREEP (CADR M)))
#                   (NOT (ENVP E))
#                   (EQUAL (EXPR-EVAL-NAN (CADR M) E)
#                          (EXPR-EVAL-NAN (FOLD-CONSTANTS (CADR M))
#                                         E)))
#               (OR (NOT (TREEP (CADDR M)))
#                   (NOT (ENVP E))
#                   (EQUAL (EXPR-EVAL-NAN (CADDR M) E)
#                          (EXPR-EVAL-NAN (FOLD-CONSTANTS (CADDR M))
#                                         E))))
#          (OR (NOT (TREEP M))
#              (NOT (ENVP E))
#              (EQUAL (EXPR-EVAL-NAN M E)
#                     (EXPR-EVAL-NAN (FOLD-CONSTANTS M) E)))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But we reduce the conjecture to T, by primitive type reasoning.
#
# Subgoal *1/7
# (IMPLIES (AND (TREEP M)
#               (NOT (RATIONALP M))
#               (NOT (SYMBOLP M))
#               (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN)
#               (NOT (OR (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN)
#                        (AND (EQUAL (FOLD-CONSTANTS (CADDR M)) 'NAN)
#                             (NOT (EQUAL (CAR M) 'UMINUS)))))
#               (NOT (EQUAL (CAR M) 'UMINUS))
#               (NOT (AND (EQUAL (CAR M) 'UMINUS)
#                         (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))))
#               (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))
#               (OR (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))
#                   (NOT (RATIONALP (FOLD-CONSTANTS (CADDR M)))))
#               (OR (NOT (TREEP (CADR M)))
#                   (NOT (ENVP E))
#                   (EQUAL (EXPR-EVAL-NAN (CADR M) E)
#                          (EXPR-EVAL-NAN (FOLD-CONSTANTS (CADR M))
#                                         E)))
#               (OR (NOT (TREEP (CADDR M)))
#                   (NOT (ENVP E))
#                   (EQUAL (EXPR-EVAL-NAN (CADDR M) E)
#                          (EXPR-EVAL-NAN (FOLD-CONSTANTS (CADDR M))
#                                         E))))
#          (OR (NOT (TREEP M))
#              (NOT (ENVP E))
#              (EQUAL (EXPR-EVAL-NAN M E)
#                     (EXPR-EVAL-NAN (FOLD-CONSTANTS M) E)))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But we reduce the conjecture to T, by primitive type reasoning.
#
# Subgoal *1/6
# (IMPLIES (AND (TREEP M)
#               (NOT (RATIONALP M))
#               (NOT (SYMBOLP M))
#               (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN)
#               (NOT (OR (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN)
#                        (AND (EQUAL (FOLD-CONSTANTS (CADDR M)) 'NAN)
#                             (NOT (EQUAL (CAR M) 'UMINUS)))))
#               (NOT (EQUAL (CAR M) 'UMINUS))
#               (AND (EQUAL (CAR M) 'UMINUS)
#                    (NOT (RATIONALP (FOLD-CONSTANTS (CADR M)))))
#               (OR (NOT (TREEP (CADR M)))
#                   (NOT (ENVP E))
#                   (EQUAL (EXPR-EVAL-NAN (CADR M) E)
#                          (EXPR-EVAL-NAN (FOLD-CONSTANTS (CADR M))
#                                         E))))
#          (OR (NOT (TREEP M))
#              (NOT (ENVP E))
#              (EQUAL (EXPR-EVAL-NAN M E)
#                     (EXPR-EVAL-NAN (FOLD-CONSTANTS M) E)))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But we reduce the conjecture to T, by primitive type reasoning.
#
# Subgoal *1/5
# (IMPLIES (AND (TREEP M)
#               (NOT (RATIONALP M))
#               (NOT (SYMBOLP M))
#               (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN)
#               (NOT (OR (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN)
#                        (AND (EQUAL (FOLD-CONSTANTS (CADDR M)) 'NAN)
#                             (NOT (EQUAL (CAR M) 'UMINUS)))))
#               (EQUAL (CAR M) 'UMINUS)
#               (NOT (AND (EQUAL (CAR M) 'UMINUS)
#                         (NOT (RATIONALP (FOLD-CONSTANTS (CADR M))))))
#               (OR (NOT (TREEP (CADR M)))
#                   (NOT (ENVP E))
#                   (EQUAL (EXPR-EVAL-NAN (CADR M) E)
#                          (EXPR-EVAL-NAN (FOLD-CONSTANTS (CADR M))
#                                         E))))
#          (OR (NOT (TREEP M))
#              (NOT (ENVP E))
#              (EQUAL (EXPR-EVAL-NAN M E)
#                     (EXPR-EVAL-NAN (FOLD-CONSTANTS M) E)))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But we reduce the conjecture to T, by primitive type reasoning.
#
# Subgoal *1/4
# (IMPLIES (AND (TREEP M)
#               (NOT (RATIONALP M))
#               (NOT (SYMBOLP M))
#               (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN)
#               (NOT (OR (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN)
#                        (AND (EQUAL (FOLD-CONSTANTS (CADDR M)) 'NAN)
#                             (NOT (EQUAL (CAR M) 'UMINUS)))))
#               (EQUAL (CAR M) 'UMINUS)
#               (AND (EQUAL (CAR M) 'UMINUS)
#                    (NOT (RATIONALP (FOLD-CONSTANTS (CADR M)))))
#               (OR (NOT (TREEP (CADR M)))
#                   (NOT (ENVP E))
#                   (EQUAL (EXPR-EVAL-NAN (CADR M) E)
#                          (EXPR-EVAL-NAN (FOLD-CONSTANTS (CADR M))
#                                         E))))
#          (OR (NOT (TREEP M))
#              (NOT (ENVP E))
#              (EQUAL (EXPR-EVAL-NAN M E)
#                     (EXPR-EVAL-NAN (FOLD-CONSTANTS M) E)))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But we reduce the conjecture to T, by primitive type reasoning.
#
# Subgoal *1/3
# (IMPLIES (AND (TREEP M)
#               (NOT (RATIONALP M))
#               (NOT (SYMBOLP M))
#               (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN)
#               (OR (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN)
#                   (AND (EQUAL (FOLD-CONSTANTS (CADDR M)) 'NAN)
#                        (NOT (EQUAL (CAR M) 'UMINUS))))
#               (OR (NOT (TREEP (CADR M)))
#                   (NOT (ENVP E))
#                   (EQUAL (EXPR-EVAL-NAN (CADR M) E)
#                          (EXPR-EVAL-NAN (FOLD-CONSTANTS (CADR M))
#                                         E))))
#          (OR (NOT (TREEP M))
#              (NOT (ENVP E))
#              (EQUAL (EXPR-EVAL-NAN M E)
#                     (EXPR-EVAL-NAN (FOLD-CONSTANTS M) E)))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# By case analysis we reduce the conjecture to
#
# Subgoal *1/3'
# (IMPLIES (AND (TREEP M)
#               (NOT (RATIONALP M))
#               (NOT (SYMBOLP M))
#               (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN)
#               (OR (EQUAL (FOLD-CONSTANTS (CADR M)) 'NAN)
#                   (AND (EQUAL (FOLD-CONSTANTS (CADDR M)) 'NAN)
#                        (NOT (EQUAL (CAR M) 'UMINUS))))
#               (OR (NOT (TREEP (CADR M)))
#                   (NOT (ENVP E))
#                   (EQUAL (EXPR-EVAL-NAN (CADR M) E)
#                          (EXPR-EVAL-NAN (FOLD-CONSTANTS (CADR M))
#                                         E)))
#               (ENVP E))
#          (EQUAL (EXPR-EVAL-NAN M E)
#                 (EXPR-EVAL-NAN (FOLD-CONSTANTS M) E))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But simplification reduces this to T, using the :compound-recognizer
# rule ENVP-IMPLIES-TLP, the :definitions EXPR-EVAL-NAN-DEFINITION-RULE,
# FOLD-CONSTANTS-DEFINITION-RULE and TREEP, the :executable-counterparts
# of EQUAL, NOT, RATIONALP and TREEP, primitive type reasoning and the
# :type-prescription rule TREEP.
#
# Subgoal *1/2
# (IMPLIES (AND (TREEP M)
#               (NOT (RATIONALP M))
#               (SYMBOLP M))
#          (OR (NOT (TREEP M))
#              (NOT (ENVP E))
#              (EQUAL (EXPR-EVAL-NAN M E)
#                     (EXPR-EVAL-NAN (FOLD-CONSTANTS M) E)))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# By case analysis we reduce the conjecture to
#
# Subgoal *1/2'
# (IMPLIES (AND (TREEP M)
#               (NOT (RATIONALP M))
#               (SYMBOLP M)
#               (ENVP E))
#          (EQUAL (EXPR-EVAL-NAN M E)
#                 (EXPR-EVAL-NAN (FOLD-CONSTANTS M) E))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But simplification reduces this to T, using the :compound-recognizer
# rule ENVP-IMPLIES-TLP, the :definitions EXPR-EVAL-NAN-DEFINITION-RULE
# and FOLD-CONSTANTS-DEFINITION-RULE, primitive type reasoning and the
# :rewrite rule DEF=>TREE.
#
# Subgoal *1/1
# (IMPLIES (AND (TREEP M) (RATIONALP M))
#          (OR (NOT (TREEP M))
#              (NOT (ENVP E))
#              (EQUAL (EXPR-EVAL-NAN M E)
#                     (EXPR-EVAL-NAN (FOLD-CONSTANTS M) E)))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# By case analysis we reduce the conjecture to
#
# Subgoal *1/1'
# (IMPLIES (AND (TREEP M) (RATIONALP M) (ENVP E))
#          (EQUAL (EXPR-EVAL-NAN M E)
#                 (EXPR-EVAL-NAN (FOLD-CONSTANTS M) E))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But simplification reduces this to T, using the :compound-recognizer
# rule ENVP-IMPLIES-TLP, the :definitions EXPR-EVAL-NAN-DEFINITION-RULE
# and FOLD-CONSTANTS-DEFINITION-RULE, primitive type reasoning and the
# :rewrite rule DEF=>TREE.
#
# That completes the proof of *1.
#
# Q.E.D.
#
# Summary
# Form:  ( THM ...)
# Rules: ((:COMPOUND-RECOGNIZER ENVP-IMPLIES-TLP)
#         (:DEFINITION EXPR-EVAL-NAN-DEFINITION-RULE)
#         (:DEFINITION FOLD-CONSTANTS-DEFINITION-RULE)
#         (:DEFINITION NOT)
#         (:DEFINITION SYNP)
#         (:DEFINITION TREEP)
#         (:EXECUTABLE-COUNTERPART BINARY-+)
#         (:EXECUTABLE-COUNTERPART CAR)
#         (:EXECUTABLE-COUNTERPART EQUAL)
#         (:EXECUTABLE-COUNTERPART NOT)
#         (:EXECUTABLE-COUNTERPART RATIONALP)
#         (:EXECUTABLE-COUNTERPART TREEP)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:INDUCTION EXPR-EVAL-NAN)
#         (:INDUCTION EXPR-EVAL-NAN-INDUCTION-SCHEME)
#         (:INDUCTION FOLD-CONSTANTS)
#         (:INDUCTION FOLD-CONSTANTS-INDUCTION-SCHEME)
#         (:INDUCTION TREEP)
#         (:REWRITE ACL2::|(* 0 x)|)
#         (:REWRITE ACL2::|(* x (if a b c))|)
#         (:REWRITE ACL2::|(* y x)|)
#         (:REWRITE ACL2::|(+ 0 x)|)
#         (:REWRITE ACL2::|(+ x (if a b c))|)
#         (:REWRITE ACL2::|(+ y x)|)
#         (:REWRITE CAR-CONS)
#         (:REWRITE CDR-CONS)
#         (:REWRITE DEF=>TREE)
#         (:REWRITE ACL2::DEFAULT-DIVIDE)
#         (:REWRITE ACL2::DEFAULT-MINUS)
#         (:REWRITE ACL2::DEFAULT-PLUS-1)
#         (:REWRITE ACL2::DEFAULT-PLUS-2)
#         (:REWRITE ACL2::DEFAULT-TIMES-1)
#         (:REWRITE ACL2::DEFAULT-TIMES-2)
#         (:REWRITE FOLD-CONSTANTS-CONTRACT)
#         (:TYPE-PRESCRIPTION FOLD-CONSTANTS-CONTRACT-TP)
#         (:TYPE-PRESCRIPTION TREEP))
# Warnings:  Invariant-risk
# Time:  0.68 seconds (prove: 0.52, print: 0.06, other: 0.10)
# Prover steps counted:  34890
#
# **Summary of Cgen/testing**
# We tested 2000 examples across 1 subgoals, of which 1995 (1995 unique)
# satisfied the hypotheses, and found 0 counterexamples and 1995 witnesses.
#
# Cases in which the conjecture is true include:
#  [found in : "Goal"]
#  -- ((E '((BA 0))) (M 'A))
#  -- ((E '((A 0) (A -1))) (M -1/49))
#  -- ((E '((BA 0))) (M 0))
#
# Proof succeeded.

# %% [markdown]
# ## On Optimizing Compilers
#
# We have two different optimizations now, so you can think of building a full-fledged optimizer by running `fold-constants` and then `remove-plus-0`. Or should it be first `remove-plus-0` and then `fold-constants`?
#
# As things stand, `fold-constants` may produce a 0 that can then be removed by `remove-plus-0`, but there's no way for `remove-plus-0` to start with a non-constant expression and return a constant expression that `fold-constants` can work with. In other words, folding constants first, then removing zeros is the best strategy.
#
# But let's think about adding some more optimizations, for example `(MINUS x x)` is the same as 0, right? This optimization can create a 0 that can then be removed by `remove-plus-0` or folded into another constant by `fold-constants`. Then again, we may need to run `remove-plus-0` to realize that two arguments to `MINUS` are the same! So in fact, there is no optimal ordering here, and a good optimizing compiler will keep trying the different optimizations until the expression is as optimized as it can get.
#
# I won't ask you to build the global optimizer that keeps trying all the little optimizations until it's done, but I will give you the opportunity to try out some more local optimizations for extra credit.
#
# ## Extra Credit 2 (Up to 90 points)
#
# Implement some other optimizations. Here are some ideas to get you started:
#
# * `(MINUS x x)`
# * `(TIMES x 1)`
# * `(TIMES x 0)`
# * `(DIVIDE x 1)`
# * `(UMINUS (UMINUS x))`
# * ...
#
# For each one, write the function that performs the optimization, use `test?` to make sure the optimization is correct, and use `thm` to prove that the optimization is correct. 30 points per optimization (up to 90 points, total).

# %%
(defsnapshot ec-2)
(definec remove-minus-double (tree :tree) :tree
    (if (or (rationalp tree) (symbolp tree))
        tree
        (if (or (equal (second tree) 'NaN) (equal (third tree) 'NaN))
            'NaN
            (if (equal (first tree) 'UMINUS)
                (cons (first tree) (list (remove-minus-double (second tree))))
                (if (equal (first tree) 'MINUS)
                    (if (and (and (or (symbolp (second tree)) (rationalp (second tree))) (or (symbolp (third tree)) (rationalp (third tree)))) (equal (second tree) (third tree)))
                        0
                        (append (cons (first tree) (list (remove-minus-double (second tree)))) (list (remove-minus-double (third tree))))
                    ) 
                    (append (cons (first tree) (list (remove-minus-double (second tree)))) (list (remove-minus-double (third tree))))
                )     
            ) 
        )
    )
)
(check-expect (remove-minus-double (list 'PLUS (list 'MINUS 'x 'x) 4)) (list 'PLUS 0 4))
(check-expect (remove-minus-double (list 'PLUS (list 'MINUS 9 9) 14)) (list 'PLUS 0 14))
(check-expect (remove-minus-double (list 'DIVIDE (list 'MINUS 'y 'y) 4)) (list 'DIVIDE 0 4))
(check-expect (remove-minus-double (list 'PLUS (list 'MINUS '6 'x) 4)) (list 'PLUS (list 'MINUS '6 'x) 4))
(check-expect (remove-minus-double (list 'PLUS (list 'MINUS 'x 'x) (list 'DIVIDE 15 (list 'MINUS (list 'MINUS 'y 'y) 5)))) (list 'PLUS 0 (list 'DIVIDE 15 (list 'MINUS 0 5))))

(test? (implies (and (treep m) (envp e)) (equal (expr-eval-nan m e) (expr-eval-nan (remove-minus-double m) e))))
(thm (implies (and (treep m) (envp e))  (equal (expr-eval-nan m e) (expr-eval-nan (remove-minus-double m) e))))

;/////////////////////////////////////////////////////////////////////////////////////////////////////////////////////

(definec remove-times-1 (tree :tree) :tree
    (if (or (rationalp tree) (symbolp tree))
        tree
        (if (equal (first tree) 'UMINUS)
            (cons (first tree) (list (remove-times-1 (second tree))))
            (if (equal (first tree) 'TIMES)
                (if (equal (second tree) 1)
                    (remove-times-1 (third tree))
                    (if (equal (third tree) 1)
                        (remove-times-1 (second tree))
                        (append (cons (first tree) (list (remove-times-1 (second tree)))) (list (remove-times-1 (third tree))))
                    )
                )  
                (append (cons (first tree) (list (remove-times-1 (second tree)))) (list (remove-times-1 (third tree))))
            )     
        ) 
    )
)
(check-expect (remove-times-1 (list 'MINUS (list 'TIMES 'x 1) 7)) (list 'MINUS 'x 7))
(check-expect (remove-times-1 (list 'MINUS (list 'TIMES 1 'x) 7)) (list 'MINUS 'x 7))
(check-expect (remove-times-1 (list 'TIMES (list 'DIVIDE 'x 1) 1)) (list 'DIVIDE 'x 1))
(check-expect (remove-times-1 (list 'MINUS (list 'TIMES 'x 1) (list 'TIMES 1 'y))) (list 'MINUS 'x 'y))
(check-expect (remove-times-1 (list 'TIMES (list 'TIMES 'z 1) 7)) (list 'TIMES 'z 7))

(test? (implies (and (treep m) (envp e)) (equal (expr-eval-nan m e) (expr-eval-nan (remove-times-1 m) e))))
(thm (implies (and (treep m) (envp e))  (equal (expr-eval-nan m e) (expr-eval-nan (remove-times-1 m) e))))

;/////////////////////////////////////////////////////////////////////////////////////////////////////////////////////

(definec remove-divide-1 (tree :tree) :tree
    (if (or (rationalp tree) (symbolp tree))
        tree
        (if (equal (first tree) 'UMINUS)
            (cons (first tree) (list (remove-divide-1 (second tree))))
            (if (equal (first tree) 'DIVIDE)
                (if (equal (third tree) 1)
                    (remove-divide-1 (second tree))
                    (append (cons (first tree) (list (remove-divide-1 (second tree)))) (list (remove-divide-1 (third tree))))
                )   
                (append (cons (first tree) (list (remove-divide-1 (second tree)))) (list (remove-divide-1 (third tree))))
            )     
        ) 
    )
)
(check-expect (remove-divide-1 (list 'DIVIDE (list 'TIMES 'x 1) 1)) (list 'TIMES 'x 1))
(check-expect (remove-divide-1 (list 'MINUS (list 'DIVIDE 1 'x) 7)) (list 'MINUS (list 'DIVIDE 1 'x) 7))
(check-expect (remove-divide-1 (list 'TIMES (list 'DIVIDE 'x 1) 1)) (list 'TIMES 'x 1))
(check-expect (remove-divide-1 (list 'MINUS (list 'DIVIDE 'x 1) (list 'DIVIDE 'y 1))) (list 'MINUS 'x 'y))
(check-expect (remove-divide-1 (list 'TIMES (list 'DIVIDE 'z 1) 7)) (list 'TIMES 'z 7))

(test? (implies (and (treep m) (envp e)) (equal (expr-eval-nan m e) (expr-eval-nan (remove-divide-1 m) e))))
(thm (implies (and (treep m) (envp e))  (equal (expr-eval-nan m e) (expr-eval-nan (remove-divide-1 m) e))))
# Out:
# ACL2S !>>(DEFSNAPSHOT EC-2)
#
# Summary
# Form:  ( DEFLABEL EC-2 ...)
# Rules: NIL
# Time:  0.00 seconds (prove: 0.00, print: 0.00, other: 0.00)
#  EC-2
# ACL2S !>>(DEFINEC
#           REMOVE-MINUS-DOUBLE (TREE TREE)
#           TREE
#           (IF
#            (OR (RATIONALP TREE) (SYMBOLP TREE))
#            TREE
#            (IF
#             (OR (EQUAL (SECOND TREE) 'NAN)
#                 (EQUAL (THIRD TREE) 'NAN))
#             'NAN
#             (IF
#              (EQUAL (FIRST TREE) 'UMINUS)
#              (CONS (FIRST TREE)
#                    (LIST (REMOVE-MINUS-DOUBLE (SECOND TREE))))
#              (IF
#                 (EQUAL (FIRST TREE) 'MINUS)
#                 (IF (AND (AND (OR (SYMBOLP (SECOND TREE))
#                                   (RATIONALP (SECOND TREE)))
#                               (OR (SYMBOLP (THIRD TREE))
#                                   (RATIONALP (THIRD TREE))))
#                          (EQUAL (SECOND TREE) (THIRD TREE)))
#                     0
#                     (APPEND (CONS (FIRST TREE)
#                                   (LIST (REMOVE-MINUS-DOUBLE (SECOND TREE))))
#                             (LIST (REMOVE-MINUS-DOUBLE (THIRD TREE)))))
#                 (APPEND (CONS (FIRST TREE)
#                               (LIST (REMOVE-MINUS-DOUBLE (SECOND TREE))))
#                         (LIST (REMOVE-MINUS-DOUBLE (THIRD TREE)))))))))
#
# Form:  ( TEST-DEFINITION REMOVE-MINUS-DOUBLE ... )
# Form:  ( TEST-BODY-CONTRACTS REMOVE-MINUS-DOUBLE... )
# Form:  ( TEST-FUNCTION-CONTRACT REMOVE-MINUS-DOUBLE ...)
# Testing: Done
# Elapsed Run Time: 4.41 seconds
# Form:  ( ADMIT-DEFINITION REMOVE-MINUS-DOUBLE ... )
# Time:  0.36 seconds (prove: 0.32, print: 0.00, other: 0.04)
# Form:  ( PROVE-FUNCTION-CONTRACT REMOVE-MINUS-DOUBLE ... )
# Time:  0.26 seconds (prove: 0.20, print: 0.00, other: 0.05)
# Form:  ( PROVE-BODY-CONTRACTS REMOVE-MINUS-DOUBLE ... )
# Time:  0.23 seconds (prove: 0.06, print: 0.00, other: 0.17)
# Elapsed Run Time: 0.91 seconds
# Function Name : REMOVE-MINUS-DOUBLE
# Termination proven -------- [*]
# Function Contract proven -- [*]
# Body Contracts proven ----- [*]
#  T
# ACL2S !>>(CHECK-EXPECT
#               (REMOVE-MINUS-DOUBLE (LIST 'PLUS (LIST 'MINUS 'X 'X) 4))
#               (LIST 'PLUS 0 4))
#  :PASSED
# ACL2S !>>(CHECK-EXPECT
#               (REMOVE-MINUS-DOUBLE (LIST 'PLUS (LIST 'MINUS 9 9) 14))
#               (LIST 'PLUS 0 14))
#  :PASSED
# ACL2S !>>(CHECK-EXPECT
#               (REMOVE-MINUS-DOUBLE (LIST 'DIVIDE (LIST 'MINUS 'Y 'Y) 4))
#               (LIST 'DIVIDE 0 4))
#  :PASSED
# ACL2S !>>(CHECK-EXPECT
#               (REMOVE-MINUS-DOUBLE (LIST 'PLUS (LIST 'MINUS '6 'X) 4))
#               (LIST 'PLUS (LIST 'MINUS '6 'X) 4))
#  :PASSED
# ACL2S !>>(CHECK-EXPECT
#               (REMOVE-MINUS-DOUBLE
#                    (LIST 'PLUS
#                          (LIST 'MINUS 'X 'X)
#                          (LIST 'DIVIDE
#                                15
#                                (LIST 'MINUS (LIST 'MINUS 'Y 'Y) 5))))
#               (LIST 'PLUS
#                     0 (LIST 'DIVIDE 15 (LIST 'MINUS 0 5))))
#  :PASSED
# ACL2S !>>(TEST? (IMPLIES (AND (TREEP M) (ENVP E))
#                          (EQUAL (EXPR-EVAL-NAN M E)
#                                 (EXPR-EVAL-NAN (REMOVE-MINUS-DOUBLE M)
#                                                E))))
#
# **Summary of Cgen/testing**
# We tested 3000 examples across 2 subgoals, of which 2963 (2963 unique)
# satisfied the hypotheses, and found 0 counterexamples and 2963 witnesses.
#
# Cases in which the conjecture is true include:
#  [found in : "top"]
#  -- ((E NIL) (M 0))
#  -- ((E NIL) (M '(DIVIDE A 0)))
#  -- ((E '((A -1) (BA 0) (A 0))) (M -3/2))
#
# Test? succeeded. No counterexamples were found.
# ACL2S !>>(THM (IMPLIES (AND (TREEP M) (ENVP E))
#                        (EQUAL (EXPR-EVAL-NAN M E)
#                               (EXPR-EVAL-NAN (REMOVE-MINUS-DOUBLE M)
#                                              E))))
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# Name the formula above *1.
#
# Perhaps we can prove *1 by induction.  Six induction schemes are suggested
# by this conjecture.  Subsumption reduces that number to four.  These
# merge into two derived induction schemes.  However, one of these is
# flawed and so we are left with one viable candidate.
#
# We will induct according to a scheme suggested by (REMOVE-MINUS-DOUBLE M),
# but modified to accommodate (EXPR-EVAL-NAN M E).  These suggestions
# were produced using the :induction rules EXPR-EVAL-NAN,
# EXPR-EVAL-NAN-INDUCTION-SCHEME, REMOVE-MINUS-DOUBLE,
# REMOVE-MINUS-DOUBLE-INDUCTION-SCHEME and TREEP.  If we let (:P E M)
# denote *1 above then the induction scheme we'll use is
# (AND (IMPLIES (NOT (TREEP M)) (:P E M))
#      (IMPLIES (AND (TREEP M)
#                    (NOT (OR (RATIONALP M) (SYMBOLP M)))
#                    (NOT (OR (EQUAL (CADR M) 'NAN)
#                             (EQUAL (CADDR M) 'NAN)))
#                    (NOT (EQUAL (CAR M) 'UMINUS))
#                    (NOT (EQUAL (CAR M) 'MINUS))
#                    (:P E (CADR M))
#                    (:P E (CADDR M)))
#               (:P E M))
#      (IMPLIES (AND (TREEP M)
#                    (NOT (OR (RATIONALP M) (SYMBOLP M)))
#                    (NOT (OR (EQUAL (CADR M) 'NAN)
#                             (EQUAL (CADDR M) 'NAN)))
#                    (EQUAL (CAR M) 'MINUS)
#                    (NOT (AND (AND (OR (SYMBOLP (CADR M))
#                                       (RATIONALP (CADR M)))
#                                   (OR (SYMBOLP (CADDR M))
#                                       (RATIONALP (CADDR M))))
#                              (EQUAL (CADR M) (CADDR M))))
#                    (:P E (CADR M))
#                    (:P E (CADDR M)))
#               (:P E M))
#      (IMPLIES (AND (TREEP M)
#                    (NOT (OR (RATIONALP M) (SYMBOLP M)))
#                    (NOT (OR (EQUAL (CADR M) 'NAN)
#                             (EQUAL (CADDR M) 'NAN)))
#                    (EQUAL (CAR M) 'MINUS)
#                    (AND (AND (OR (SYMBOLP (CADR M))
#                                  (RATIONALP (CADR M)))
#                              (OR (SYMBOLP (CADDR M))
#                                  (RATIONALP (CADDR M))))
#                         (EQUAL (CADR M) (CADDR M))))
#               (:P E M))
#      (IMPLIES (AND (TREEP M)
#                    (NOT (OR (RATIONALP M) (SYMBOLP M)))
#                    (NOT (OR (EQUAL (CADR M) 'NAN)
#                             (EQUAL (CADDR M) 'NAN)))
#                    (EQUAL (CAR M) 'UMINUS)
#                    (:P E (CADR M)))
#               (:P E M))
#      (IMPLIES (AND (TREEP M)
#                    (NOT (OR (RATIONALP M) (SYMBOLP M)))
#                    (OR (EQUAL (CADR M) 'NAN)
#                        (EQUAL (CADDR M) 'NAN)))
#               (:P E M))
#      (IMPLIES (AND (TREEP M)
#                    (OR (RATIONALP M) (SYMBOLP M)))
#               (:P E M))).
# This induction is justified by the same argument used to admit
# REMOVE-MINUS-DOUBLE.  When applied to the goal at hand the above induction
# scheme produces thirteen nontautological subgoals.
#
# Subgoal *1/13
# (IMPLIES (AND (TREEP M)
#               (NOT (OR (RATIONALP M) (SYMBOLP M)))
#               (NOT (OR (EQUAL (CADR M) 'NAN)
#                        (EQUAL (CADDR M) 'NAN)))
#               (NOT (EQUAL (CAR M) 'UMINUS))
#               (NOT (EQUAL (CAR M) 'MINUS))
#               (EQUAL (EXPR-EVAL-NAN (CADR M) E)
#                      (EXPR-EVAL-NAN (REMOVE-MINUS-DOUBLE (CADR M))
#                                     E))
#               (EQUAL (EXPR-EVAL-NAN (CADDR M) E)
#                      (EXPR-EVAL-NAN (REMOVE-MINUS-DOUBLE (CADDR M))
#                                     E))
#               (ENVP E))
#          (EQUAL (EXPR-EVAL-NAN M E)
#                 (EXPR-EVAL-NAN (REMOVE-MINUS-DOUBLE M)
#                                E))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But simplification reduces this to T, using the :compound-recognizer
# rule ENVP-IMPLIES-TLP, the :definitions EXPR-EVAL-NAN-DEFINITION-RULE,
# REMOVE-MINUS-DOUBLE-DEFINITION-RULE, SYNP and TREEP, the :executable-
# counterpart of EQUAL, primitive type reasoning, the :rewrite rules
# ACL2::|(* 0 x)|, ACL2::|(* x (if a b c))|, ACL2::|(* y x)|,
# ACL2::APPEND-OF-CONS, ACL2::APPEND-WHEN-NOT-CONSP, CAR-CONS, CDR-CONS,
# ACL2::DEFAULT-DIVIDE, ACL2::DEFAULT-PLUS-1, ACL2::DEFAULT-PLUS-2,
# ACL2::DEFAULT-TIMES-1, ACL2::DEFAULT-TIMES-2 and
# REMOVE-MINUS-DOUBLE-CONTRACT and the :type-prescription rule TREEP.
#
# Subgoal *1/12
# (IMPLIES (AND (TREEP M)
#               (NOT (OR (RATIONALP M) (SYMBOLP M)))
#               (NOT (OR (EQUAL (CADR M) 'NAN)
#                        (EQUAL (CADDR M) 'NAN)))
#               (NOT (EQUAL (CAR M) 'UMINUS))
#               (NOT (EQUAL (CAR M) 'MINUS))
#               (NOT (TREEP (CADR M)))
#               (EQUAL (EXPR-EVAL-NAN (CADDR M) E)
#                      (EXPR-EVAL-NAN (REMOVE-MINUS-DOUBLE (CADDR M))
#                                     E))
#               (ENVP E))
#          (EQUAL (EXPR-EVAL-NAN M E)
#                 (EXPR-EVAL-NAN (REMOVE-MINUS-DOUBLE M)
#                                E))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But simplification reduces this to T, using the :definition TREEP.
#
# Subgoal *1/11
# (IMPLIES (AND (TREEP M)
#               (NOT (OR (RATIONALP M) (SYMBOLP M)))
#               (NOT (OR (EQUAL (CADR M) 'NAN)
#                        (EQUAL (CADDR M) 'NAN)))
#               (NOT (EQUAL (CAR M) 'UMINUS))
#               (NOT (EQUAL (CAR M) 'MINUS))
#               (EQUAL (EXPR-EVAL-NAN (CADR M) E)
#                      (EXPR-EVAL-NAN (REMOVE-MINUS-DOUBLE (CADR M))
#                                     E))
#               (NOT (TREEP (CADDR M)))
#               (ENVP E))
#          (EQUAL (EXPR-EVAL-NAN M E)
#                 (EXPR-EVAL-NAN (REMOVE-MINUS-DOUBLE M)
#                                E))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But simplification reduces this to T, using the :definition TREEP.
#
# Subgoal *1/10
# (IMPLIES (AND (TREEP M)
#               (NOT (OR (RATIONALP M) (SYMBOLP M)))
#               (NOT (OR (EQUAL (CADR M) 'NAN)
#                        (EQUAL (CADDR M) 'NAN)))
#               (NOT (EQUAL (CAR M) 'UMINUS))
#               (NOT (EQUAL (CAR M) 'MINUS))
#               (NOT (TREEP (CADR M)))
#               (NOT (TREEP (CADDR M)))
#               (ENVP E))
#          (EQUAL (EXPR-EVAL-NAN M E)
#                 (EXPR-EVAL-NAN (REMOVE-MINUS-DOUBLE M)
#                                E))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But simplification reduces this to T, using the :definition TREEP.
#
# Subgoal *1/9
# (IMPLIES (AND (TREEP M)
#               (NOT (OR (RATIONALP M) (SYMBOLP M)))
#               (NOT (OR (EQUAL (CADR M) 'NAN)
#                        (EQUAL (CADDR M) 'NAN)))
#               (EQUAL (CAR M) 'MINUS)
#               (NOT (AND (AND (OR (SYMBOLP (CADR M))
#                                  (RATIONALP (CADR M)))
#                              (OR (SYMBOLP (CADDR M))
#                                  (RATIONALP (CADDR M))))
#                         (EQUAL (CADR M) (CADDR M))))
#               (EQUAL (EXPR-EVAL-NAN (CADR M) E)
#                      (EXPR-EVAL-NAN (REMOVE-MINUS-DOUBLE (CADR M))
#                                     E))
#               (EQUAL (EXPR-EVAL-NAN (CADDR M) E)
#                      (EXPR-EVAL-NAN (REMOVE-MINUS-DOUBLE (CADDR M))
#                                     E))
#               (ENVP E))
#          (EQUAL (EXPR-EVAL-NAN M E)
#                 (EXPR-EVAL-NAN (REMOVE-MINUS-DOUBLE M)
#                                E))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But simplification reduces this to T, using the :compound-recognizer
# rule ENVP-IMPLIES-TLP, the :definitions EXPR-EVAL-NAN-DEFINITION-RULE,
# REMOVE-MINUS-DOUBLE-DEFINITION-RULE, SYNP and TREEP, the :executable-
# counterpart of EQUAL, primitive type reasoning, the :rewrite rules
# ACL2::|(+ 0 x)|, ACL2::|(+ x (if a b c))|, ACL2::|(+ y x)|,
# ACL2::APPEND-OF-CONS, ACL2::APPEND-WHEN-NOT-CONSP, CAR-CONS, CDR-CONS,
# ACL2::DEFAULT-MINUS, ACL2::DEFAULT-PLUS-1 and REMOVE-MINUS-DOUBLE-CONTRACT
# and the :type-prescription rule TREEP.
#
# Subgoal *1/8
# (IMPLIES (AND (TREEP M)
#               (NOT (OR (RATIONALP M) (SYMBOLP M)))
#               (NOT (OR (EQUAL (CADR M) 'NAN)
#                        (EQUAL (CADDR M) 'NAN)))
#               (EQUAL (CAR M) 'MINUS)
#               (NOT (AND (AND (OR (SYMBOLP (CADR M))
#                                  (RATIONALP (CADR M)))
#                              (OR (SYMBOLP (CADDR M))
#                                  (RATIONALP (CADDR M))))
#                         (EQUAL (CADR M) (CADDR M))))
#               (NOT (TREEP (CADR M)))
#               (EQUAL (EXPR-EVAL-NAN (CADDR M) E)
#                      (EXPR-EVAL-NAN (REMOVE-MINUS-DOUBLE (CADDR M))
#                                     E))
#               (ENVP E))
#          (EQUAL (EXPR-EVAL-NAN M E)
#                 (EXPR-EVAL-NAN (REMOVE-MINUS-DOUBLE M)
#                                E))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But simplification reduces this to T, using the :definition TREEP and
# the :executable-counterpart of EQUAL.
#
# Subgoal *1/7
# (IMPLIES (AND (TREEP M)
#               (NOT (OR (RATIONALP M) (SYMBOLP M)))
#               (NOT (OR (EQUAL (CADR M) 'NAN)
#                        (EQUAL (CADDR M) 'NAN)))
#               (EQUAL (CAR M) 'MINUS)
#               (NOT (AND (AND (OR (SYMBOLP (CADR M))
#                                  (RATIONALP (CADR M)))
#                              (OR (SYMBOLP (CADDR M))
#                                  (RATIONALP (CADDR M))))
#                         (EQUAL (CADR M) (CADDR M))))
#               (EQUAL (EXPR-EVAL-NAN (CADR M) E)
#                      (EXPR-EVAL-NAN (REMOVE-MINUS-DOUBLE (CADR M))
#                                     E))
#               (NOT (TREEP (CADDR M)))
#               (ENVP E))
#          (EQUAL (EXPR-EVAL-NAN M E)
#                 (EXPR-EVAL-NAN (REMOVE-MINUS-DOUBLE M)
#                                E))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But simplification reduces this to T, using the :definition TREEP and
# the :executable-counterpart of EQUAL.
#
# Subgoal *1/6
# (IMPLIES (AND (TREEP M)
#               (NOT (OR (RATIONALP M) (SYMBOLP M)))
#               (NOT (OR (EQUAL (CADR M) 'NAN)
#                        (EQUAL (CADDR M) 'NAN)))
#               (EQUAL (CAR M) 'MINUS)
#               (NOT (AND (AND (OR (SYMBOLP (CADR M))
#                                  (RATIONALP (CADR M)))
#                              (OR (SYMBOLP (CADDR M))
#                                  (RATIONALP (CADDR M))))
#                         (EQUAL (CADR M) (CADDR M))))
#               (NOT (TREEP (CADR M)))
#               (NOT (TREEP (CADDR M)))
#               (ENVP E))
#          (EQUAL (EXPR-EVAL-NAN M E)
#                 (EXPR-EVAL-NAN (REMOVE-MINUS-DOUBLE M)
#                                E))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But simplification reduces this to T, using the :definition TREEP and
# the :executable-counterpart of EQUAL.
#
# Subgoal *1/5
# (IMPLIES (AND (TREEP M)
#               (NOT (OR (RATIONALP M) (SYMBOLP M)))
#               (NOT (OR (EQUAL (CADR M) 'NAN)
#                        (EQUAL (CADDR M) 'NAN)))
#               (EQUAL (CAR M) 'MINUS)
#               (AND (AND (OR (SYMBOLP (CADR M))
#                             (RATIONALP (CADR M)))
#                         (OR (SYMBOLP (CADDR M))
#                             (RATIONALP (CADDR M))))
#                    (EQUAL (CADR M) (CADDR M)))
#               (ENVP E))
#          (EQUAL (EXPR-EVAL-NAN M E)
#                 (EXPR-EVAL-NAN (REMOVE-MINUS-DOUBLE M)
#                                E))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# By case analysis we reduce the conjecture to
#
# Subgoal *1/5'
# (IMPLIES (AND (TREEP M)
#               (NOT (OR (RATIONALP M) (SYMBOLP M)))
#               (NOT (OR (EQUAL (CADR M) 'NAN)
#                        (EQUAL (CADDR M) 'NAN)))
#               (EQUAL (CAR M) 'MINUS)
#               (OR (SYMBOLP (CADR M))
#                   (RATIONALP (CADR M)))
#               (OR (SYMBOLP (CADDR M))
#                   (RATIONALP (CADDR M)))
#               (EQUAL (CADR M) (CADDR M))
#               (ENVP E))
#          (EQUAL (EXPR-EVAL-NAN M E)
#                 (EXPR-EVAL-NAN (REMOVE-MINUS-DOUBLE M)
#                                E))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# This simplifies, using the :compound-recognizer rule ENVP-IMPLIES-TLP,
# the :definitions EXPR-EVAL-NAN-DEFINITION-RULE (if-intro),
# REMOVE-MINUS-DOUBLE-DEFINITION-RULE, SYNP and TREEP (if-intro), the
# :executable-counterparts of EQUAL, RATIONALP, TREEP and UNARY--, primitive
# type reasoning, the :rewrite rules ACL2::|(+ 0 x)|, ACL2::|(+ x (- x))|,
# ACL2::|(+ x (if a b c))| (if-intro), ACL2::|(+ y (+ x z))|, ACL2::|(+ y x)|,
# ACL2::|(- (- x))|, ACL2::|(equal (- x) c)|, ACL2::|(equal (if a b c) x)|
# (if-intro), ACL2::BUBBLE-DOWN-+-MATCH-1, ACL2::DEFAULT-MINUS (if-intro),
# ACL2::DEFAULT-PLUS-1 (if-intro), ACL2::NORMALIZE-ADDENDS and
# ACL2::PREFER-POSITIVE-ADDENDS-EQUAL and the :type-prescription rule
# TREEP, to the following ten conjectures.
#
# Subgoal *1/5.10
# (IMPLIES (AND (CONSP M)
#               (CONSP (CDR M))
#               (TREEP (CADR M))
#               (CONSP (CDDR M))
#               (TREEP (CADDR M))
#               (NOT (CDDDR M))
#               (NOT (RATIONALP M))
#               (NOT (SYMBOLP M))
#               (NOT (EQUAL (CADR M) 'NAN))
#               (EQUAL (CAR M) 'MINUS)
#               (SYMBOLP (CADR M))
#               (SYMBOLP (CADDR M))
#               (EQUAL (CADR M) (CADDR M))
#               (ENVP E))
#          (NOT (EQUAL (EXPR-EVAL-NAN (CADR M) E)
#                      'NAN))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But simplification reduces this to T, using the :compound-recognizer
# rule ENVP-IMPLIES-TLP, the :definition EXPR-EVAL-NAN-DEFINITION-RULE,
# primitive type reasoning, the :rewrite rule DEF=>TREE and the :type-
# prescription rule LOOKUP-CONTRACT-TP.
#
# Subgoal *1/5.9
# (IMPLIES (AND (CONSP M)
#               (CONSP (CDR M))
#               (TREEP (CADR M))
#               (CONSP (CDDR M))
#               (TREEP (CADDR M))
#               (NOT (CDDDR M))
#               (NOT (RATIONALP M))
#               (NOT (SYMBOLP M))
#               (NOT (EQUAL (CADR M) 'NAN))
#               (EQUAL (CAR M) 'MINUS)
#               (SYMBOLP (CADR M))
#               (SYMBOLP (CADDR M))
#               (EQUAL (CADR M) (CADDR M))
#               (ENVP E))
#          (NOT (EQUAL (EXPR-EVAL-NAN (CADDR M) E)
#                      'NAN))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But simplification reduces this to T, using the :compound-recognizer
# rule ENVP-IMPLIES-TLP, the :definition EXPR-EVAL-NAN-DEFINITION-RULE,
# primitive type reasoning, the :rewrite rule DEF=>TREE and the :type-
# prescription rule LOOKUP-CONTRACT-TP.
#
# Subgoal *1/5.8
# (IMPLIES (AND (CONSP M)
#               (CONSP (CDR M))
#               (TREEP (CADR M))
#               (CONSP (CDDR M))
#               (TREEP (CADDR M))
#               (NOT (CDDDR M))
#               (NOT (RATIONALP M))
#               (NOT (SYMBOLP M))
#               (NOT (EQUAL (CADR M) 'NAN))
#               (EQUAL (CAR M) 'MINUS)
#               (SYMBOLP (CADR M))
#               (SYMBOLP (CADDR M))
#               (EQUAL (CADR M) (CADDR M))
#               (ENVP E)
#               (NOT (ACL2-NUMBERP (EXPR-EVAL-NAN (CADR M) E)))
#               (ACL2-NUMBERP (EXPR-EVAL-NAN (CADDR M) E)))
#          (EQUAL (EXPR-EVAL-NAN (CADDR M) E) 0)).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But simplification reduces this to T, using the :compound-recognizer
# rule ENVP-IMPLIES-TLP, the :definition EXPR-EVAL-NAN-DEFINITION-RULE,
# primitive type reasoning, the :rewrite rule DEF=>TREE and the :type-
# prescription rule LOOKUP-CONTRACT-TP.
#
# Subgoal *1/5.7
# (IMPLIES (AND (CONSP M)
#               (CONSP (CDR M))
#               (TREEP (CADR M))
#               (CONSP (CDDR M))
#               (TREEP (CADDR M))
#               (NOT (CDDDR M))
#               (NOT (RATIONALP M))
#               (NOT (SYMBOLP M))
#               (NOT (EQUAL (CADR M) 'NAN))
#               (EQUAL (CAR M) 'MINUS)
#               (SYMBOLP (CADR M))
#               (SYMBOLP (CADDR M))
#               (EQUAL (CADR M) (CADDR M))
#               (ENVP E)
#               (ACL2-NUMBERP (EXPR-EVAL-NAN (CADR M) E))
#               (ACL2-NUMBERP (EXPR-EVAL-NAN (CADDR M) E)))
#          (EQUAL (EXPR-EVAL-NAN (CADR M) E)
#                 (EXPR-EVAL-NAN (CADDR M) E))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But simplification reduces this to T, using the :compound-recognizer
# rule ENVP-IMPLIES-TLP, the :definition EXPR-EVAL-NAN-DEFINITION-RULE,
# primitive type reasoning, the :rewrite rule DEF=>TREE and the :type-
# prescription rule LOOKUP-CONTRACT-TP.
#
# Subgoal *1/5.6
# (IMPLIES (AND (CONSP M)
#               (CONSP (CDR M))
#               (TREEP (CADR M))
#               (CONSP (CDDR M))
#               (TREEP (CADDR M))
#               (NOT (CDDDR M))
#               (NOT (RATIONALP M))
#               (NOT (SYMBOLP M))
#               (NOT (EQUAL (CADR M) 'NAN))
#               (EQUAL (CAR M) 'MINUS)
#               (SYMBOLP (CADR M))
#               (SYMBOLP (CADDR M))
#               (EQUAL (CADR M) (CADDR M))
#               (ENVP E)
#               (ACL2-NUMBERP (EXPR-EVAL-NAN (CADR M) E))
#               (NOT (ACL2-NUMBERP (EXPR-EVAL-NAN (CADDR M) E))))
#          (EQUAL (EXPR-EVAL-NAN (CADR M) E) 0)).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But simplification reduces this to T, using the :compound-recognizer
# rule ENVP-IMPLIES-TLP, the :definition EXPR-EVAL-NAN-DEFINITION-RULE,
# primitive type reasoning, the :rewrite rule DEF=>TREE and the :type-
# prescription rule LOOKUP-CONTRACT-TP.
#
# Subgoal *1/5.5
# (IMPLIES (AND (CONSP M)
#               (CONSP (CDR M))
#               (TREEP (CADR M))
#               (CONSP (CDDR M))
#               (TREEP (CADDR M))
#               (NOT (CDDDR M))
#               (NOT (RATIONALP M))
#               (NOT (SYMBOLP M))
#               (NOT (EQUAL (CADR M) 'NAN))
#               (EQUAL (CAR M) 'MINUS)
#               (RATIONALP (CADR M))
#               (RATIONALP (CADDR M))
#               (EQUAL (CADR M) (CADDR M))
#               (ENVP E))
#          (NOT (EQUAL (EXPR-EVAL-NAN (CADR M) E)
#                      'NAN))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But simplification reduces this to T, using the :compound-recognizer
# rule ENVP-IMPLIES-TLP, the :definition EXPR-EVAL-NAN-DEFINITION-RULE,
# primitive type reasoning and the :rewrite rule DEF=>TREE.
#
# Subgoal *1/5.4
# (IMPLIES (AND (CONSP M)
#               (CONSP (CDR M))
#               (TREEP (CADR M))
#               (CONSP (CDDR M))
#               (TREEP (CADDR M))
#               (NOT (CDDDR M))
#               (NOT (RATIONALP M))
#               (NOT (SYMBOLP M))
#               (NOT (EQUAL (CADR M) 'NAN))
#               (EQUAL (CAR M) 'MINUS)
#               (RATIONALP (CADR M))
#               (RATIONALP (CADDR M))
#               (EQUAL (CADR M) (CADDR M))
#               (ENVP E))
#          (NOT (EQUAL (EXPR-EVAL-NAN (CADDR M) E)
#                      'NAN))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But simplification reduces this to T, using the :compound-recognizer
# rule ENVP-IMPLIES-TLP, the :definition EXPR-EVAL-NAN-DEFINITION-RULE,
# primitive type reasoning and the :rewrite rule DEF=>TREE.
#
# Subgoal *1/5.3
# (IMPLIES (AND (CONSP M)
#               (CONSP (CDR M))
#               (TREEP (CADR M))
#               (CONSP (CDDR M))
#               (TREEP (CADDR M))
#               (NOT (CDDDR M))
#               (NOT (RATIONALP M))
#               (NOT (SYMBOLP M))
#               (NOT (EQUAL (CADR M) 'NAN))
#               (EQUAL (CAR M) 'MINUS)
#               (RATIONALP (CADR M))
#               (RATIONALP (CADDR M))
#               (EQUAL (CADR M) (CADDR M))
#               (ENVP E)
#               (NOT (ACL2-NUMBERP (EXPR-EVAL-NAN (CADR M) E)))
#               (ACL2-NUMBERP (EXPR-EVAL-NAN (CADDR M) E)))
#          (EQUAL (EXPR-EVAL-NAN (CADDR M) E) 0)).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But simplification reduces this to T, using the :compound-recognizer
# rule ENVP-IMPLIES-TLP, the :definition EXPR-EVAL-NAN-DEFINITION-RULE,
# primitive type reasoning and the :rewrite rule DEF=>TREE.
#
# Subgoal *1/5.2
# (IMPLIES (AND (CONSP M)
#               (CONSP (CDR M))
#               (TREEP (CADR M))
#               (CONSP (CDDR M))
#               (TREEP (CADDR M))
#               (NOT (CDDDR M))
#               (NOT (RATIONALP M))
#               (NOT (SYMBOLP M))
#               (NOT (EQUAL (CADR M) 'NAN))
#               (EQUAL (CAR M) 'MINUS)
#               (RATIONALP (CADR M))
#               (RATIONALP (CADDR M))
#               (EQUAL (CADR M) (CADDR M))
#               (ENVP E)
#               (ACL2-NUMBERP (EXPR-EVAL-NAN (CADR M) E))
#               (ACL2-NUMBERP (EXPR-EVAL-NAN (CADDR M) E)))
#          (EQUAL (EXPR-EVAL-NAN (CADR M) E)
#                 (EXPR-EVAL-NAN (CADDR M) E))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But simplification reduces this to T, using the :compound-recognizer
# rule ENVP-IMPLIES-TLP, the :definition EXPR-EVAL-NAN-DEFINITION-RULE,
# primitive type reasoning and the :rewrite rule DEF=>TREE.
#
# Subgoal *1/5.1
# (IMPLIES (AND (CONSP M)
#               (CONSP (CDR M))
#               (TREEP (CADR M))
#               (CONSP (CDDR M))
#               (TREEP (CADDR M))
#               (NOT (CDDDR M))
#               (NOT (RATIONALP M))
#               (NOT (SYMBOLP M))
#               (NOT (EQUAL (CADR M) 'NAN))
#               (EQUAL (CAR M) 'MINUS)
#               (RATIONALP (CADR M))
#               (RATIONALP (CADDR M))
#               (EQUAL (CADR M) (CADDR M))
#               (ENVP E)
#               (ACL2-NUMBERP (EXPR-EVAL-NAN (CADR M) E))
#               (NOT (ACL2-NUMBERP (EXPR-EVAL-NAN (CADDR M) E))))
#          (EQUAL (EXPR-EVAL-NAN (CADR M) E) 0)).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But simplification reduces this to T, using the :compound-recognizer
# rule ENVP-IMPLIES-TLP, the :definition EXPR-EVAL-NAN-DEFINITION-RULE,
# primitive type reasoning and the :rewrite rule DEF=>TREE.
#
# Subgoal *1/4
# (IMPLIES (AND (TREEP M)
#               (NOT (OR (RATIONALP M) (SYMBOLP M)))
#               (NOT (OR (EQUAL (CADR M) 'NAN)
#                        (EQUAL (CADDR M) 'NAN)))
#               (EQUAL (CAR M) 'UMINUS)
#               (EQUAL (EXPR-EVAL-NAN (CADR M) E)
#                      (EXPR-EVAL-NAN (REMOVE-MINUS-DOUBLE (CADR M))
#                                     E))
#               (ENVP E))
#          (EQUAL (EXPR-EVAL-NAN M E)
#                 (EXPR-EVAL-NAN (REMOVE-MINUS-DOUBLE M)
#                                E))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But simplification reduces this to T, using the :compound-recognizer
# rule ENVP-IMPLIES-TLP, the :definitions EXPR-EVAL-NAN-DEFINITION-RULE,
# REMOVE-MINUS-DOUBLE-DEFINITION-RULE, SYNP and TREEP, the :executable-
# counterparts of BINARY-+, CAR and EQUAL, primitive type reasoning,
# the :rewrite rules ACL2::|(+ 0 x)|, ACL2::|(+ x (if a b c))|, CAR-CONS,
# CDR-CONS, ACL2::DEFAULT-MINUS and REMOVE-MINUS-DOUBLE-CONTRACT and
# the :type-prescription rule TREEP.
#
# Subgoal *1/3
# (IMPLIES (AND (TREEP M)
#               (NOT (OR (RATIONALP M) (SYMBOLP M)))
#               (NOT (OR (EQUAL (CADR M) 'NAN)
#                        (EQUAL (CADDR M) 'NAN)))
#               (EQUAL (CAR M) 'UMINUS)
#               (NOT (TREEP (CADR M)))
#               (ENVP E))
#          (EQUAL (EXPR-EVAL-NAN M E)
#                 (EXPR-EVAL-NAN (REMOVE-MINUS-DOUBLE M)
#                                E))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But simplification reduces this to T, using the :definition TREEP and
# the :executable-counterpart of EQUAL.
#
# Subgoal *1/2
# (IMPLIES (AND (TREEP M)
#               (NOT (OR (RATIONALP M) (SYMBOLP M)))
#               (OR (EQUAL (CADR M) 'NAN)
#                   (EQUAL (CADDR M) 'NAN))
#               (ENVP E))
#          (EQUAL (EXPR-EVAL-NAN M E)
#                 (EXPR-EVAL-NAN (REMOVE-MINUS-DOUBLE M)
#                                E))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# This simplifies, using the :compound-recognizer rule ENVP-IMPLIES-TLP,
# the :definitions EXPR-EVAL-NAN-DEFINITION-RULE (if-intro),
# REMOVE-MINUS-DOUBLE-DEFINITION-RULE, SYNP and TREEP (if-intro), the
# :executable-counterparts of BINARY-+, CAR, EQUAL, NOT, RATIONALP and
# TREEP, primitive type reasoning, the :rewrite rules ACL2::|(* 0 x)|,
# ACL2::|(* x (if a b c))| (if-intro), ACL2::|(* y x)|, ACL2::|(+ 0 x)|,
# ACL2::|(+ x (if a b c))| (if-intro), ACL2::|(+ y x)|,
# ACL2::|(equal (if a b c) x)| (if-intro), DEF=>TREE, ACL2::DEFAULT-DIVIDE
# (if-intro), ACL2::DEFAULT-MINUS (if-intro), ACL2::DEFAULT-PLUS-1 (if-
# intro), ACL2::DEFAULT-PLUS-2 (if-intro), ACL2::DEFAULT-TIMES-1 (if-
# intro) and ACL2::DEFAULT-TIMES-2 (if-intro) and the :type-prescription
# rule TREEP, to the following nine conjectures.
#
# Subgoal *1/2.9
# (IMPLIES (AND (CONSP M)
#               (EQUAL (CAR M) 'UMINUS)
#               (CONSP (CDR M))
#               (NOT (CDDR M))
#               (NOT (RATIONALP M))
#               (NOT (SYMBOLP M))
#               (EQUAL (CADR M) 'NAN)
#               (ENVP E))
#          (EQUAL (EXPR-EVAL-NAN 'NAN E) 'NAN)).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But simplification reduces this to T, using the :compound-recognizer
# rule ENVP-IMPLIES-TLP, the :definition EXPR-EVAL-NAN-DEFINITION-RULE
# and the :executable-counterparts of EQUAL, RATIONALP and TREEP.
#
# Subgoal *1/2.8
# (IMPLIES (AND (CONSP M)
#               (EQUAL (CAR M) 'PLUS)
#               (CONSP (CDR M))
#               (CONSP (CDDR M))
#               (TREEP (CADDR M))
#               (NOT (CDDDR M))
#               (NOT (RATIONALP M))
#               (NOT (SYMBOLP M))
#               (EQUAL (CADR M) 'NAN)
#               (ENVP E)
#               (NOT (EQUAL (EXPR-EVAL-NAN 'NAN E) 'NAN)))
#          (EQUAL (EXPR-EVAL-NAN (CADDR M) E)
#                 'NAN)).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But simplification reduces this to T, using the :compound-recognizer
# rule ENVP-IMPLIES-TLP, the :definition EXPR-EVAL-NAN-DEFINITION-RULE
# and the :executable-counterparts of EQUAL, RATIONALP and TREEP.
#
# Subgoal *1/2.7
# (IMPLIES (AND (CONSP M)
#               (EQUAL (CAR M) 'PLUS)
#               (CONSP (CDR M))
#               (TREEP (CADR M))
#               (CONSP (CDDR M))
#               (NOT (CDDDR M))
#               (NOT (RATIONALP M))
#               (NOT (SYMBOLP M))
#               (EQUAL (CADDR M) 'NAN)
#               (ENVP E)
#               (NOT (EQUAL (EXPR-EVAL-NAN (CADR M) E)
#                           'NAN)))
#          (EQUAL (EXPR-EVAL-NAN 'NAN E) 'NAN)).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But simplification reduces this to T, using the :compound-recognizer
# rule ENVP-IMPLIES-TLP, the :definition EXPR-EVAL-NAN-DEFINITION-RULE
# and the :executable-counterparts of EQUAL, RATIONALP and TREEP.
#
# Subgoal *1/2.6
# (IMPLIES (AND (CONSP M)
#               (EQUAL (CAR M) 'TIMES)
#               (CONSP (CDR M))
#               (CONSP (CDDR M))
#               (TREEP (CADDR M))
#               (NOT (CDDDR M))
#               (NOT (RATIONALP M))
#               (NOT (SYMBOLP M))
#               (EQUAL (CADR M) 'NAN)
#               (ENVP E)
#               (NOT (EQUAL (EXPR-EVAL-NAN 'NAN E) 'NAN)))
#          (EQUAL (EXPR-EVAL-NAN (CADDR M) E)
#                 'NAN)).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But simplification reduces this to T, using the :compound-recognizer
# rule ENVP-IMPLIES-TLP, the :definition EXPR-EVAL-NAN-DEFINITION-RULE
# and the :executable-counterparts of EQUAL, RATIONALP and TREEP.
#
# Subgoal *1/2.5
# (IMPLIES (AND (CONSP M)
#               (EQUAL (CAR M) 'TIMES)
#               (CONSP (CDR M))
#               (TREEP (CADR M))
#               (CONSP (CDDR M))
#               (NOT (CDDDR M))
#               (NOT (RATIONALP M))
#               (NOT (SYMBOLP M))
#               (EQUAL (CADDR M) 'NAN)
#               (ENVP E)
#               (NOT (EQUAL (EXPR-EVAL-NAN (CADR M) E)
#                           'NAN)))
#          (EQUAL (EXPR-EVAL-NAN 'NAN E) 'NAN)).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But simplification reduces this to T, using the :compound-recognizer
# rule ENVP-IMPLIES-TLP, the :definition EXPR-EVAL-NAN-DEFINITION-RULE
# and the :executable-counterparts of EQUAL, RATIONALP and TREEP.
#
# Subgoal *1/2.4
# (IMPLIES (AND (CONSP M)
#               (EQUAL (CAR M) 'MINUS)
#               (CONSP (CDR M))
#               (CONSP (CDDR M))
#               (TREEP (CADDR M))
#               (NOT (CDDDR M))
#               (NOT (RATIONALP M))
#               (NOT (SYMBOLP M))
#               (EQUAL (CADR M) 'NAN)
#               (ENVP E)
#               (NOT (EQUAL (EXPR-EVAL-NAN 'NAN E) 'NAN)))
#          (EQUAL (EXPR-EVAL-NAN (CADDR M) E)
#                 'NAN)).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But simplification reduces this to T, using the :compound-recognizer
# rule ENVP-IMPLIES-TLP, the :definition EXPR-EVAL-NAN-DEFINITION-RULE
# and the :executable-counterparts of EQUAL, RATIONALP and TREEP.
#
# Subgoal *1/2.3
# (IMPLIES (AND (CONSP M)
#               (EQUAL (CAR M) 'MINUS)
#               (CONSP (CDR M))
#               (TREEP (CADR M))
#               (CONSP (CDDR M))
#               (NOT (CDDDR M))
#               (NOT (RATIONALP M))
#               (NOT (SYMBOLP M))
#               (EQUAL (CADDR M) 'NAN)
#               (ENVP E)
#               (NOT (EQUAL (EXPR-EVAL-NAN (CADR M) E)
#                           'NAN)))
#          (EQUAL (EXPR-EVAL-NAN 'NAN E) 'NAN)).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But simplification reduces this to T, using the :compound-recognizer
# rule ENVP-IMPLIES-TLP, the :definition EXPR-EVAL-NAN-DEFINITION-RULE
# and the :executable-counterparts of EQUAL, RATIONALP and TREEP.
#
# Subgoal *1/2.2
# (IMPLIES (AND (CONSP M)
#               (EQUAL (CAR M) 'DIVIDE)
#               (CONSP (CDR M))
#               (CONSP (CDDR M))
#               (TREEP (CADDR M))
#               (NOT (CDDDR M))
#               (NOT (RATIONALP M))
#               (NOT (SYMBOLP M))
#               (EQUAL (CADR M) 'NAN)
#               (ENVP E)
#               (NOT (EQUAL (EXPR-EVAL-NAN 'NAN E) 'NAN))
#               (NOT (EQUAL (EXPR-EVAL-NAN (CADDR M) E)
#                           'NAN)))
#          (EQUAL (EXPR-EVAL-NAN (CADDR M) E) 0)).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But simplification reduces this to T, using the :compound-recognizer
# rule ENVP-IMPLIES-TLP, the :definition EXPR-EVAL-NAN-DEFINITION-RULE
# and the :executable-counterparts of EQUAL, RATIONALP and TREEP.
#
# Subgoal *1/2.1
# (IMPLIES (AND (CONSP M)
#               (EQUAL (CAR M) 'DIVIDE)
#               (CONSP (CDR M))
#               (TREEP (CADR M))
#               (CONSP (CDDR M))
#               (NOT (CDDDR M))
#               (NOT (RATIONALP M))
#               (NOT (SYMBOLP M))
#               (EQUAL (CADDR M) 'NAN)
#               (ENVP E)
#               (NOT (EQUAL (EXPR-EVAL-NAN (CADR M) E) 'NAN))
#               (NOT (EQUAL (EXPR-EVAL-NAN 'NAN E) 'NAN)))
#          (EQUAL (EXPR-EVAL-NAN 'NAN E) 0)).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But simplification reduces this to T, using the :compound-recognizer
# rule ENVP-IMPLIES-TLP, the :definition EXPR-EVAL-NAN-DEFINITION-RULE
# and the :executable-counterparts of EQUAL, RATIONALP and TREEP.
#
# Subgoal *1/1
# (IMPLIES (AND (TREEP M)
#               (OR (RATIONALP M) (SYMBOLP M))
#               (ENVP E))
#          (EQUAL (EXPR-EVAL-NAN M E)
#                 (EXPR-EVAL-NAN (REMOVE-MINUS-DOUBLE M)
#                                E))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But simplification reduces this to T, using the :compound-recognizer
# rule ENVP-IMPLIES-TLP, the :definitions EXPR-EVAL-NAN-DEFINITION-RULE,
# REMOVE-MINUS-DOUBLE-DEFINITION-RULE and TREEP, primitive type reasoning
# and the :rewrite rule DEF=>TREE.
#
# That completes the proof of *1.
#
# Q.E.D.
#
# Summary
# Form:  ( THM ...)
# Rules: ((:COMPOUND-RECOGNIZER ENVP-IMPLIES-TLP)
#         (:DEFINITION EXPR-EVAL-NAN-DEFINITION-RULE)
#         (:DEFINITION NOT)
#         (:DEFINITION REMOVE-MINUS-DOUBLE-DEFINITION-RULE)
#         (:DEFINITION SYNP)
#         (:DEFINITION TREEP)
#         (:EXECUTABLE-COUNTERPART BINARY-+)
#         (:EXECUTABLE-COUNTERPART CAR)
#         (:EXECUTABLE-COUNTERPART EQUAL)
#         (:EXECUTABLE-COUNTERPART NOT)
#         (:EXECUTABLE-COUNTERPART RATIONALP)
#         (:EXECUTABLE-COUNTERPART TREEP)
#         (:EXECUTABLE-COUNTERPART UNARY--)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:INDUCTION EXPR-EVAL-NAN)
#         (:INDUCTION EXPR-EVAL-NAN-INDUCTION-SCHEME)
#         (:INDUCTION REMOVE-MINUS-DOUBLE)
#         (:INDUCTION REMOVE-MINUS-DOUBLE-INDUCTION-SCHEME)
#         (:INDUCTION TREEP)
#         (:REWRITE ACL2::|(* 0 x)|)
#         (:REWRITE ACL2::|(* x (if a b c))|)
#         (:REWRITE ACL2::|(* y x)|)
#         (:REWRITE ACL2::|(+ 0 x)|)
#         (:REWRITE ACL2::|(+ x (- x))|)
#         (:REWRITE ACL2::|(+ x (if a b c))|)
#         (:REWRITE ACL2::|(+ y (+ x z))|)
#         (:REWRITE ACL2::|(+ y x)|)
#         (:REWRITE ACL2::|(- (- x))|)
#         (:REWRITE ACL2::|(equal (- x) c)|)
#         (:REWRITE ACL2::|(equal (if a b c) x)|)
#         (:REWRITE ACL2::APPEND-OF-CONS)
#         (:REWRITE ACL2::APPEND-WHEN-NOT-CONSP)
#         (:REWRITE ACL2::BUBBLE-DOWN-+-MATCH-1)
#         (:REWRITE CAR-CONS)
#         (:REWRITE CDR-CONS)
#         (:REWRITE DEF=>TREE)
#         (:REWRITE ACL2::DEFAULT-DIVIDE)
#         (:REWRITE ACL2::DEFAULT-MINUS)
#         (:REWRITE ACL2::DEFAULT-PLUS-1)
#         (:REWRITE ACL2::DEFAULT-PLUS-2)
#         (:REWRITE ACL2::DEFAULT-TIMES-1)
#         (:REWRITE ACL2::DEFAULT-TIMES-2)
#         (:REWRITE ACL2::NORMALIZE-ADDENDS)
#         (:REWRITE ACL2::PREFER-POSITIVE-ADDENDS-EQUAL)
#         (:REWRITE REMOVE-MINUS-DOUBLE-CONTRACT)
#         (:TYPE-PRESCRIPTION LOOKUP-CONTRACT-TP)
#         (:TYPE-PRESCRIPTION TREEP))
# Splitter rules (see :DOC splitter):
#   if-intro: ((:DEFINITION EXPR-EVAL-NAN-DEFINITION-RULE)
#              (:DEFINITION TREEP)
#              (:REWRITE ACL2::|(* x (if a b c))|)
#              (:REWRITE ACL2::|(+ x (if a b c))|)
#              (:REWRITE ACL2::|(equal (if a b c) x)|)
#              (:REWRITE ACL2::DEFAULT-DIVIDE)
#              (:REWRITE ACL2::DEFAULT-MINUS)
#              (:REWRITE ACL2::DEFAULT-PLUS-1)
#              (:REWRITE ACL2::DEFAULT-PLUS-2)
#              (:REWRITE ACL2::DEFAULT-TIMES-1)
#              (:REWRITE ACL2::DEFAULT-TIMES-2))
# Warnings:  Invariant-risk
# Time:  0.79 seconds (prove: 0.66, print: 0.03, other: 0.10)
# Prover steps counted:  32346
#
# **Summary of Cgen/testing**
# We tested 2000 examples across 1 subgoals, of which 1998 (1998 unique)
# satisfied the hypotheses, and found 0 counterexamples and 1998 witnesses.
#
# Cases in which the conjecture is true include:
#  [found in : "Goal"]
#  -- ((E '((ABA -1) (BA 0) (A 0))) (M 'BDECJAE))
#  -- ((E '((BA 0) (BA 0) (A 0))) (M 'C))
#  -- ((E NIL) (M 286/17))
#
# Proof succeeded.
# ACL2S !>>(DEFINEC
#           REMOVE-TIMES-1 (TREE TREE)
#           TREE
#           (IF
#            (OR (RATIONALP TREE) (SYMBOLP TREE))
#            TREE
#            (IF
#              (EQUAL (FIRST TREE) 'UMINUS)
#              (CONS (FIRST TREE)
#                    (LIST (REMOVE-TIMES-1 (SECOND TREE))))
#              (IF (EQUAL (FIRST TREE) 'TIMES)
#                  (IF (EQUAL (SECOND TREE) 1)
#                      (REMOVE-TIMES-1 (THIRD TREE))
#                      (IF (EQUAL (THIRD TREE) 1)
#                          (REMOVE-TIMES-1 (SECOND TREE))
#                          (APPEND (CONS (FIRST TREE)
#                                        (LIST (REMOVE-TIMES-1 (SECOND TREE))))
#                                  (LIST (REMOVE-TIMES-1 (THIRD TREE))))))
#                  (APPEND (CONS (FIRST TREE)
#                                (LIST (REMOVE-TIMES-1 (SECOND TREE))))
#                          (LIST (REMOVE-TIMES-1 (THIRD TREE))))))))
#
# Form:  ( TEST-DEFINITION REMOVE-TIMES-1 ... )
# Form:  ( TEST-BODY-CONTRACTS REMOVE-TIMES-1... )
# Form:  ( TEST-FUNCTION-CONTRACT REMOVE-TIMES-1 ...)
# Testing: Done
# Elapsed Run Time: 2.65 seconds
# Form:  ( ADMIT-DEFINITION REMOVE-TIMES-1 ... )
# Time:  0.60 seconds (prove: 0.56, print: 0.00, other: 0.04)
# Form:  ( PROVE-FUNCTION-CONTRACT REMOVE-TIMES-1 ... )
# Time:  0.20 seconds (prove: 0.14, print: 0.00, other: 0.06)
# Form:  ( PROVE-BODY-CONTRACTS REMOVE-TIMES-1 ... )
# Time:  0.13 seconds (prove: 0.05, print: 0.00, other: 0.08)
# Elapsed Run Time: 1.00 seconds
# Function Name : REMOVE-TIMES-1
# Termination proven -------- [*]
# Function Contract proven -- [*]
# Body Contracts proven ----- [*]
#  T
# ACL2S !>>(CHECK-EXPECT (REMOVE-TIMES-1 (LIST 'MINUS (LIST 'TIMES 'X 1) 7))
#                        (LIST 'MINUS 'X 7))
#  :PASSED
# ACL2S !>>(CHECK-EXPECT (REMOVE-TIMES-1 (LIST 'MINUS (LIST 'TIMES 1 'X) 7))
#                        (LIST 'MINUS 'X 7))
#  :PASSED
# ACL2S !>>(CHECK-EXPECT (REMOVE-TIMES-1 (LIST 'TIMES (LIST 'DIVIDE 'X 1) 1))
#                        (LIST 'DIVIDE 'X 1))
#  :PASSED
# ACL2S !>>(CHECK-EXPECT (REMOVE-TIMES-1 (LIST 'MINUS
#                                              (LIST 'TIMES 'X 1)
#                                              (LIST 'TIMES 1 'Y)))
#                        (LIST 'MINUS 'X 'Y))
#  :PASSED
# ACL2S !>>(CHECK-EXPECT (REMOVE-TIMES-1 (LIST 'TIMES (LIST 'TIMES 'Z 1) 7))
#                        (LIST 'TIMES 'Z 7))
#  :PASSED
# ACL2S !>>(TEST? (IMPLIES (AND (TREEP M) (ENVP E))
#                          (EQUAL (EXPR-EVAL-NAN M E)
#                                 (EXPR-EVAL-NAN (REMOVE-TIMES-1 M) E))))
#
# **Summary of Cgen/testing**
# We tested 3000 examples across 2 subgoals, of which 2955 (2955 unique)
# satisfied the hypotheses, and found 0 counterexamples and 2955 witnesses.
#
# Cases in which the conjecture is true include:
#  [found in : "top"]
#  -- ((E '((ABBAAAA 0) (A 0))) (M '(UMINUS A)))
#  -- ((E '((BABAAA -1))) (M 54/469))
#  -- ((E '((A 0))) (M '(UMINUS (UMINUS 0))))
#
# Test? succeeded. No counterexamples were found.
# ACL2S !>>(THM (IMPLIES (AND (TREEP M) (ENVP E))
#                        (EQUAL (EXPR-EVAL-NAN M E)
#                               (EXPR-EVAL-NAN (REMOVE-TIMES-1 M) E))))
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# Name the formula above *1.
#
# Perhaps we can prove *1 by induction.  Six induction schemes are suggested
# ...
#
# Subgoal *1/9
# (IMPLIES (AND (TREEP M)
#               (NOT (OR (RATIONALP M) (SYMBOLP M)))
#               (EQUAL (CAR M) 'DIVIDE)
#               (NOT (EQUAL (CADDR M) 1))
#               (EQUAL (EXPR-EVAL-NAN (CADR M) E)
#                      (EXPR-EVAL-NAN (REMOVE-DIVIDE-1 (CADR M))
#                                     E))
#               (EQUAL (EXPR-EVAL-NAN (CADDR M) E)
#                      (EXPR-EVAL-NAN (REMOVE-DIVIDE-1 (CADDR M))
#                                     E))
#               (ENVP E))
#          (EQUAL (EXPR-EVAL-NAN M E)
#                 (EXPR-EVAL-NAN (REMOVE-DIVIDE-1 M) E))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But simplification reduces this to T, using the :compound-recognizer
# rule ENVP-IMPLIES-TLP, the :definitions EXPR-EVAL-NAN-DEFINITION-RULE,
# REMOVE-DIVIDE-1-DEFINITION-RULE, SYNP and TREEP, the :executable-counterpart
# of EQUAL, primitive type reasoning, the :rewrite rules ACL2::|(* 0 x)|,
# ACL2::|(* x (if a b c))|, ACL2::|(* y x)|, ACL2::APPEND-OF-CONS,
# ACL2::APPEND-WHEN-NOT-CONSP, CAR-CONS, CDR-CONS, ACL2::DEFAULT-DIVIDE,
# ACL2::DEFAULT-TIMES-1 and REMOVE-DIVIDE-1-CONTRACT and the :type-prescription
# rule TREEP.
#
# Subgoal *1/8
# (IMPLIES (AND (TREEP M)
#               (NOT (OR (RATIONALP M) (SYMBOLP M)))
#               (EQUAL (CAR M) 'DIVIDE)
#               (NOT (EQUAL (CADDR M) 1))
#               (NOT (TREEP (CADR M)))
#               (EQUAL (EXPR-EVAL-NAN (CADDR M) E)
#                      (EXPR-EVAL-NAN (REMOVE-DIVIDE-1 (CADDR M))
#                                     E))
#               (ENVP E))
#          (EQUAL (EXPR-EVAL-NAN M E)
#                 (EXPR-EVAL-NAN (REMOVE-DIVIDE-1 M) E))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But simplification reduces this to T, using the :definition TREEP and
# the :executable-counterpart of EQUAL.
#
# Subgoal *1/7
# (IMPLIES (AND (TREEP M)
#               (NOT (OR (RATIONALP M) (SYMBOLP M)))
#               (EQUAL (CAR M) 'DIVIDE)
#               (NOT (EQUAL (CADDR M) 1))
#               (EQUAL (EXPR-EVAL-NAN (CADR M) E)
#                      (EXPR-EVAL-NAN (REMOVE-DIVIDE-1 (CADR M))
#                                     E))
#               (NOT (TREEP (CADDR M)))
#               (ENVP E))
#          (EQUAL (EXPR-EVAL-NAN M E)
#                 (EXPR-EVAL-NAN (REMOVE-DIVIDE-1 M) E))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But simplification reduces this to T, using the :definition TREEP and
# the :executable-counterpart of EQUAL.
#
# Subgoal *1/6
# (IMPLIES (AND (TREEP M)
#               (NOT (OR (RATIONALP M) (SYMBOLP M)))
#               (EQUAL (CAR M) 'DIVIDE)
#               (NOT (EQUAL (CADDR M) 1))
#               (NOT (TREEP (CADR M)))
#               (NOT (TREEP (CADDR M)))
#               (ENVP E))
#          (EQUAL (EXPR-EVAL-NAN M E)
#                 (EXPR-EVAL-NAN (REMOVE-DIVIDE-1 M) E))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But simplification reduces this to T, using the :definition TREEP and
# the :executable-counterpart of EQUAL.
#
# Subgoal *1/5
# (IMPLIES (AND (TREEP M)
#               (NOT (OR (RATIONALP M) (SYMBOLP M)))
#               (EQUAL (CAR M) 'DIVIDE)
#               (EQUAL (CADDR M) 1)
#               (EQUAL (EXPR-EVAL-NAN (CADR M) E)
#                      (EXPR-EVAL-NAN (REMOVE-DIVIDE-1 (CADR M))
#                                     E))
#               (ENVP E))
#          (EQUAL (EXPR-EVAL-NAN M E)
#                 (EXPR-EVAL-NAN (REMOVE-DIVIDE-1 M) E))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# This simplifies, using the :compound-recognizer rule ENVP-IMPLIES-TLP,
# the :definitions EXPR-EVAL-NAN-DEFINITION-RULE (if-intro),
# REMOVE-DIVIDE-1-DEFINITION-RULE, SYNP and TREEP (if-intro), the :executable-
# counterparts of EQUAL, NOT and TREEP, primitive type reasoning, the
# :rewrite rules ACL2::|(* 0 x)|, ACL2::|(* x (if a b c))| (if-intro),
# ACL2::|(* y x)|, ACL2::|(equal (if a b c) x)| (if-intro), DEF=>TREE,
# ACL2::DEFAULT-DIVIDE (if-intro) and ACL2::DEFAULT-TIMES-1 (if-intro)
# and the :type-prescription rule TREEP, to the following five conjectures.
#
# Subgoal *1/5.5
# (IMPLIES (AND (CONSP M)
#               (CONSP (CDR M))
#               (TREEP (CADR M))
#               (CONSP (CDDR M))
#               (NOT (CDDDR M))
#               (NOT (RATIONALP M))
#               (NOT (SYMBOLP M))
#               (EQUAL (CAR M) 'DIVIDE)
#               (EQUAL (CADDR M) 1)
#               (EQUAL (EXPR-EVAL-NAN (CADR M) E)
#                      (EXPR-EVAL-NAN (REMOVE-DIVIDE-1 (CADR M))
#                                     E))
#               (ENVP E)
#               (NOT (EQUAL (EXPR-EVAL-NAN (CADR M) E)
#                           'NAN)))
#          (NOT (EQUAL (EXPR-EVAL-NAN 1 E) 'NAN))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But simplification reduces this to T, using the :compound-recognizer
# rule ENVP-IMPLIES-TLP, the :definition EXPR-EVAL-NAN-DEFINITION-RULE
# and the :executable-counterparts of EQUAL, RATIONALP and TREEP.
#
# Subgoal *1/5.4
# (IMPLIES (AND (CONSP M)
#               (CONSP (CDR M))
#               (TREEP (CADR M))
#               (CONSP (CDDR M))
#               (NOT (CDDDR M))
#               (NOT (RATIONALP M))
#               (NOT (SYMBOLP M))
#               (EQUAL (CAR M) 'DIVIDE)
#               (EQUAL (CADDR M) 1)
#               (EQUAL (EXPR-EVAL-NAN (CADR M) E)
#                      (EXPR-EVAL-NAN (REMOVE-DIVIDE-1 (CADR M))
#                                     E))
#               (ENVP E)
#               (NOT (EQUAL (EXPR-EVAL-NAN (CADR M) E)
#                           'NAN)))
#          (NOT (EQUAL (EXPR-EVAL-NAN 1 E) 0))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But simplification reduces this to T, using the :compound-recognizer
# rule ENVP-IMPLIES-TLP, the :definition EXPR-EVAL-NAN-DEFINITION-RULE
# and the :executable-counterparts of EQUAL, RATIONALP and TREEP.
#
# Subgoal *1/5.3
# (IMPLIES (AND (CONSP M)
#               (CONSP (CDR M))
#               (TREEP (CADR M))
#               (CONSP (CDDR M))
#               (NOT (CDDDR M))
#               (NOT (RATIONALP M))
#               (NOT (SYMBOLP M))
#               (EQUAL (CAR M) 'DIVIDE)
#               (EQUAL (CADDR M) 1)
#               (EQUAL (EXPR-EVAL-NAN (CADR M) E)
#                      (EXPR-EVAL-NAN (REMOVE-DIVIDE-1 (CADR M))
#                                     E))
#               (ENVP E)
#               (NOT (EQUAL (EXPR-EVAL-NAN (CADR M) E)
#                           'NAN)))
#          (ACL2-NUMBERP (EXPR-EVAL-NAN (CADR M) E))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But we reduce the conjecture to T, by the :executable-counterpart of
# TAU-SYSTEM.
#
# Subgoal *1/5.2
# (IMPLIES (AND (CONSP M)
#               (CONSP (CDR M))
#               (TREEP (CADR M))
#               (CONSP (CDDR M))
#               (NOT (CDDDR M))
#               (NOT (RATIONALP M))
#               (NOT (SYMBOLP M))
#               (EQUAL (CAR M) 'DIVIDE)
#               (EQUAL (CADDR M) 1)
#               (EQUAL (EXPR-EVAL-NAN (CADR M) E)
#                      (EXPR-EVAL-NAN (REMOVE-DIVIDE-1 (CADR M))
#                                     E))
#               (ENVP E)
#               (NOT (EQUAL (EXPR-EVAL-NAN (CADR M) E) 'NAN))
#               (NOT (ACL2-NUMBERP (EXPR-EVAL-NAN 1 E))))
#          (EQUAL 0 (EXPR-EVAL-NAN (CADR M) E))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But simplification reduces this to T, using the :compound-recognizer
# rule ENVP-IMPLIES-TLP, the :definition EXPR-EVAL-NAN-DEFINITION-RULE
# and the :executable-counterparts of ACL2-NUMBERP, RATIONALP and TREEP.
#
# Subgoal *1/5.1
# (IMPLIES (AND (CONSP M)
#               (CONSP (CDR M))
#               (TREEP (CADR M))
#               (CONSP (CDDR M))
#               (NOT (CDDDR M))
#               (NOT (RATIONALP M))
#               (NOT (SYMBOLP M))
#               (EQUAL (CAR M) 'DIVIDE)
#               (EQUAL (CADDR M) 1)
#               (EQUAL (EXPR-EVAL-NAN (CADR M) E)
#                      (EXPR-EVAL-NAN (REMOVE-DIVIDE-1 (CADR M))
#                                     E))
#               (ENVP E)
#               (NOT (EQUAL (EXPR-EVAL-NAN (CADR M) E) 'NAN))
#               (ACL2-NUMBERP (EXPR-EVAL-NAN 1 E)))
#          (EQUAL (* (EXPR-EVAL-NAN (CADR M) E)
#                    (/ (EXPR-EVAL-NAN 1 E)))
#                 (EXPR-EVAL-NAN (CADR M) E))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But simplification reduces this to T, using the :compound-recognizer
# rule ENVP-IMPLIES-TLP, the :definition EXPR-EVAL-NAN-DEFINITION-RULE,
# the :executable-counterparts of ACL2-NUMBERP, RATIONALP, TREEP and
# UNARY-/, primitive type reasoning, the :forward-chaining rules
# EXPR-EVAL-NAN-CONTRACT and ACL2::RETURN=>DEF, the :rewrite rules
# ACL2::|(* 1 x)| and ACL2::|(* y x)| and the :type-prescription rules
# EXPR-EVAL-NAN-CONTRACT-TP and RETURNP.
#
# Subgoal *1/4
# (IMPLIES (AND (TREEP M)
#               (NOT (OR (RATIONALP M) (SYMBOLP M)))
#               (EQUAL (CAR M) 'DIVIDE)
#               (EQUAL (CADDR M) 1)
#               (NOT (TREEP (CADR M)))
#               (ENVP E))
#          (EQUAL (EXPR-EVAL-NAN M E)
#                 (EXPR-EVAL-NAN (REMOVE-DIVIDE-1 M) E))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But simplification reduces this to T, using the :definition TREEP and
# the :executable-counterpart of EQUAL.
#
# Subgoal *1/3
# (IMPLIES (AND (TREEP M)
#               (NOT (OR (RATIONALP M) (SYMBOLP M)))
#               (EQUAL (CAR M) 'UMINUS)
#               (EQUAL (EXPR-EVAL-NAN (CADR M) E)
#                      (EXPR-EVAL-NAN (REMOVE-DIVIDE-1 (CADR M))
#                                     E))
#               (ENVP E))
#          (EQUAL (EXPR-EVAL-NAN M E)
#                 (EXPR-EVAL-NAN (REMOVE-DIVIDE-1 M) E))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But simplification reduces this to T, using the :compound-recognizer
# rule ENVP-IMPLIES-TLP, the :definitions EXPR-EVAL-NAN-DEFINITION-RULE,
# REMOVE-DIVIDE-1-DEFINITION-RULE, SYNP and TREEP, the :executable-counterparts
# of BINARY-+, CAR and EQUAL, primitive type reasoning, the :rewrite
# rules ACL2::|(+ 0 x)|, ACL2::|(+ x (if a b c))|, CAR-CONS, CDR-CONS,
# ACL2::DEFAULT-MINUS and REMOVE-DIVIDE-1-CONTRACT and the :type-prescription
# rule TREEP.
#
# Subgoal *1/2
# (IMPLIES (AND (TREEP M)
#               (NOT (OR (RATIONALP M) (SYMBOLP M)))
#               (EQUAL (CAR M) 'UMINUS)
#               (NOT (TREEP (CADR M)))
#               (ENVP E))
#          (EQUAL (EXPR-EVAL-NAN M E)
#                 (EXPR-EVAL-NAN (REMOVE-DIVIDE-1 M) E))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But simplification reduces this to T, using the :definition TREEP and
# the :executable-counterpart of EQUAL.
#
# Subgoal *1/1
# (IMPLIES (AND (TREEP M)
#               (OR (RATIONALP M) (SYMBOLP M))
#               (ENVP E))
#          (EQUAL (EXPR-EVAL-NAN M E)
#                 (EXPR-EVAL-NAN (REMOVE-DIVIDE-1 M) E))).
#
# ACL2 Warning [Invariant-risk] in ACL2::TEST-CHECKPOINT:  Invariant-
# risk has been detected for a call of function ACL2::TEST-CHECKPOINT
# (as possibly leading to an ill-guarded call of CGEN::UI); see :DOC
# invariant-risk.
#
#
# But simplification reduces this to T, using the :compound-recognizer
# rule ENVP-IMPLIES-TLP, the :definitions EXPR-EVAL-NAN-DEFINITION-RULE,
# REMOVE-DIVIDE-1-DEFINITION-RULE and TREEP, primitive type reasoning
# and the :rewrite rule DEF=>TREE.
#
# That completes the proof of *1.
#
# Q.E.D.
#
# Summary
# Form:  ( THM ...)
# Rules: ((:COMPOUND-RECOGNIZER ENVP-IMPLIES-TLP)
#         (:DEFINITION EXPR-EVAL-NAN-DEFINITION-RULE)
#         (:DEFINITION NOT)
#         (:DEFINITION REMOVE-DIVIDE-1-DEFINITION-RULE)
#         (:DEFINITION SYNP)
#         (:DEFINITION TREEP)
#         (:EXECUTABLE-COUNTERPART ACL2-NUMBERP)
#         (:EXECUTABLE-COUNTERPART BINARY-+)
#         (:EXECUTABLE-COUNTERPART CAR)
#         (:EXECUTABLE-COUNTERPART EQUAL)
#         (:EXECUTABLE-COUNTERPART NOT)
#         (:EXECUTABLE-COUNTERPART RATIONALP)
#         (:EXECUTABLE-COUNTERPART TAU-SYSTEM)
#         (:EXECUTABLE-COUNTERPART TREEP)
#         (:EXECUTABLE-COUNTERPART UNARY-/)
#         (:FAKE-RUNE-FOR-TYPE-SET NIL)
#         (:FORWARD-CHAINING EXPR-EVAL-NAN-CONTRACT)
#         (:FORWARD-CHAINING ACL2::RETURN=>DEF)
#         (:INDUCTION EXPR-EVAL-NAN)
#         (:INDUCTION EXPR-EVAL-NAN-INDUCTION-SCHEME)
#         (:INDUCTION REMOVE-DIVIDE-1)
#         (:INDUCTION REMOVE-DIVIDE-1-INDUCTION-SCHEME)
#         (:INDUCTION TREEP)
#         (:REWRITE ACL2::|(* 0 x)|)
#         (:REWRITE ACL2::|(* 1 x)|)
#         (:REWRITE ACL2::|(* x (if a b c))|)
#         (:REWRITE ACL2::|(* y x)|)
#         (:REWRITE ACL2::|(+ 0 x)|)
#         (:REWRITE ACL2::|(+ x (if a b c))|)
#         (:REWRITE ACL2::|(+ y x)|)
#         (:REWRITE ACL2::|(equal (if a b c) x)|)
#         (:REWRITE ACL2::APPEND-OF-CONS)
#         (:REWRITE ACL2::APPEND-WHEN-NOT-CONSP)
#         (:REWRITE CAR-CONS)
#         (:REWRITE CDR-CONS)
#         (:REWRITE DEF=>TREE)
#         (:REWRITE ACL2::DEFAULT-DIVIDE)
#         (:REWRITE ACL2::DEFAULT-MINUS)
#         (:REWRITE ACL2::DEFAULT-PLUS-1)
#         (:REWRITE ACL2::DEFAULT-PLUS-2)
#         (:REWRITE ACL2::DEFAULT-TIMES-1)
#         (:REWRITE ACL2::DEFAULT-TIMES-2)
#         (:REWRITE REMOVE-DIVIDE-1-CONTRACT)
#         (:TYPE-PRESCRIPTION EXPR-EVAL-NAN-CONTRACT-TP)
#         (:TYPE-PRESCRIPTION RETURNP)
#         (:TYPE-PRESCRIPTION TREEP))
# Splitter rules (see :DOC splitter):
#   if-intro: ((:DEFINITION EXPR-EVAL-NAN-DEFINITION-RULE)
#              (:DEFINITION TREEP)
#              (:REWRITE ACL2::|(* x (if a b c))|)
#              (:REWRITE ACL2::|(equal (if a b c) x)|)
#              (:REWRITE ACL2::DEFAULT-DIVIDE)
#              (:REWRITE ACL2::DEFAULT-TIMES-1))
# Warnings:  Invariant-risk
# Time:  0.57 seconds (prove: 0.46, print: 0.01, other: 0.09)
# Prover steps counted:  26235
#
# **Summary of Cgen/testing**
# We tested 2000 examples across 1 subgoals, of which 1957 (1957 unique)
# satisfied the hypotheses, and found 0 counterexamples and 1957 witnesses.
#
# Cases in which the conjecture is true include:
#  [found in : "Goal"]
#  -- ((E '((BABAAA 0))) (M '(UMINUS (PLUS 0 0))))
#  -- ((E '((BABAAA -1/2) (A 0) (BA 0))) (M 'ABA))
#  -- ((E NIL) (M '|xoc|))
#
# Proof succeeded.
